# %% [markdown]
# # Exploratory Data Analysis with Python
#
# We will explore the NYC MTA turnstile data set.

# %% [markdown]
# ## Exercise 1
#
# - Download a few [MTA turnstile data files](http://web.mta.info/developers/turnstile.html)
# - Open up a file, use csv reader to read it, make a python dict where there is a key for each (C/A, UNIT, SCP, STATION). These are the first four columns. The value for this key should be a list of lists. Each list in the list is the rest of the columns in a row. For example, one key-value pair should look like
#
#
#         {    ('A002','R051','02-00-00','LEXINGTON AVE'):
#              [
#                ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'],
#                  ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'],
#                 ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'],
#               ...
#          ]
#         }

# %%
url_template = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_%s.txt'
for date in ['150124', '150117', '150110', '150103']:
    url = url_template % date
    # !wget {url}
# Out:
# --2017-01-21 18:18:23--  http://web.mta.info/developers/data/nyct/turnstile/turnstile_150124.txt
# Resolving web.mta.info... 23.67.251.41, 23.67.251.74
# Connecting to web.mta.info|23.67.251.41|:80... connected.
# HTTP request sent, awaiting response...
#   HTTP/1.1 200 OK
#   Server: Oracle-iPlanet-Web-Server/7.0
#   Content-Type: text/plain
#   Last-Modified: Sat, 24 Jan 2015 10:12:04 GMT
#   ETag: W/"1818a44-54c36ff4"
#   Vary: Accept-Encoding
#   Date: Sat, 21 Jan 2017 23:18:25 GMT
#   Transfer-Encoding:  chunked
#   Connection: keep-alive
#   Connection: Transfer-Encoding
# Length: unspecified [text/plain]
# Saving to: ‘turnstile_150124.txt’
#
# turnstile_150124.tx     [               <=>  ]  24.10M  8.54MB/s    in 2.8s
#
# 2017-01-21 18:18:27 (8.54 MB/s) - ‘turnstile_150124.txt’ saved [25266756]
#
# --2017-01-21 18:18:28--  http://web.mta.info/developers/data/nyct/turnstile/turnstile_150117.txt
# Resolving web.mta.info... 23.67.251.41, 23.67.251.74
# Connecting to web.mta.info|23.67.251.41|:80... connected.
# HTTP request sent, awaiting response...
#   HTTP/1.1 200 OK
#   Server: Oracle-iPlanet-Web-Server/7.0
#   Content-Type: text/plain
#   Last-Modified: Sat, 17 Jan 2015 10:08:38 GMT
#   ETag: W/"192403c-54ba34a6"
#   Vary: Accept-Encoding
#   Date: Sat, 21 Jan 2017 23:18:28 GMT
#   Transfer-Encoding:  chunked
#   Connection: keep-alive
#   Connection: Transfer-Encoding
# Length: unspecified [text/plain]
# Saving to: ‘turnstile_150117.txt’
#
# turnstile_150117.tx     [         <=>        ]  25.14M  1.53MB/s    in 17s
#
# 2017-01-21 18:18:45 (1.49 MB/s) - ‘turnstile_150117.txt’ saved [26361916]
#
# --2017-01-21 18:18:45--  http://web.mta.info/developers/data/nyct/turnstile/turnstile_150110.txt
# Resolving web.mta.info... 162.216.59.40, 162.216.59.48
# Connecting to web.mta.info|162.216.59.40|:80... connected.
# HTTP request sent, awaiting response...
#   HTTP/1.1 200 OK
#   Server: Oracle-iPlanet-Web-Server/7.0
#   Content-Type: text/plain
#   Last-Modified: Sat, 10 Jan 2015 10:06:09 GMT
#   ETag: W/"186ca8d-54b0f991"
#   Vary: Accept-Encoding
#   Date: Sat, 21 Jan 2017 23:18:46 GMT
#   Transfer-Encoding:  chunked
#   Connection: keep-alive
#   Connection: Transfer-Encoding
# Length: unspecified [text/plain]
# Saving to: ‘turnstile_150110.txt’
#
# turnstile_150110.tx     [          <=>       ]  24.42M  1.51MB/s    in 17s
#
# 2017-01-21 18:19:02 (1.47 MB/s) - ‘turnstile_150110.txt’ saved [25610893]
#
# --2017-01-21 18:19:03--  http://web.mta.info/developers/data/nyct/turnstile/turnstile_150103.txt
# Resolving web.mta.info... 162.216.59.40, 162.216.59.48
# Connecting to web.mta.info|162.216.59.40|:80... connected.
# HTTP request sent, awaiting response...
#   HTTP/1.1 200 OK
#   Server: Oracle-iPlanet-Web-Server/7.0
#   Content-Type: text/plain
#   Last-Modified: Thu, 08 Jan 2015 16:35:54 GMT
#   ETag: W/"18403c6-54aeb1ea"
#   Vary: Accept-Encoding
#   Date: Sat, 21 Jan 2017 23:19:03 GMT
#   Transfer-Encoding:  chunked
#   Connection: keep-alive
#   Connection: Transfer-Encoding
# Length: unspecified [text/plain]
# Saving to: ‘turnstile_150103.txt’
#
# turnstile_150103.tx     [           <=>      ]  24.25M  1.50MB/s    in 16s
#
# 2017-01-21 18:19:20 (1.48 MB/s) - ‘turnstile_150103.txt’ saved [25428934]

# %%
import csv, glob
from collections import defaultdict

def read_csv(csv_file_name):

    turnstile_to_count_reading = defaultdict(list)
    with open(csv_file_name, 'r') as csv_file:
        mta_reader = csv.reader(csv_file)
        for i, row in enumerate(mta_reader):
            # skip the first row, it's just header strings
            if i == 0:
                continue
            # read the rest
            turnstile_info = tuple(row[:4])
            count_reading = row[4:]
            turnstile_to_count_reading[turnstile_info].append(count_reading)
    return turnstile_to_count_reading


#A) List comprehension
weekly_data_dicts = [read_csv(csvfile) for csvfile in glob.glob("turnstile_*.txt")]

#B) Alternatively, map
# data_files = glob.glob("turnstile_*.txt")
# weekly_data_dicts = map(read_csv, data_files)

#C) Alternatively, separating the steps on multiple lines
#weekly_data_dicts = []
#for data_file in glob.glob("turnstile_*.txt"):
#    print 'Processing %s' % data_file
#    weekly_data_dicts.append(read_csv(data_file))
    
#(Choose the approach you find more readable)

# %%
from pprint import pprint
# just get 2 keys from the first dict to now overwhelm the output
sample_dict = list(weekly_data_dicts[0].items())[:2]
pprint(sample_dict)
# Out:
# [(('R208', 'R014', '03-00-00', 'FULTON ST'),
#   [['2345ACJZ',
#     'IRT',
#     '12/27/2014',
#     '00:00:00',
#     'REGULAR',
#     '0010282065',
#     '0006891794                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/27/2014',
#     '04:00:00',
#     'REGULAR',
#     '0010282066',
#     '0006891795                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/27/2014',
#     '08:00:00',
#     'REGULAR',
#     '0010282066',
#     '0006891802                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/27/2014',
#     '12:00:00',
#     'REGULAR',
#     '0010282073',
#     '0006891861                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/27/2014',
#     '16:00:00',
#     'REGULAR',
#     '0010282086',
#     '0006891911                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/27/2014',
#     '20:00:00',
#     'REGULAR',
#     '0010282086',
#     '0006891911                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/28/2014',
#     '00:00:00',
#     'REGULAR',
#     '0010282086',
#     '0006891911                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/28/2014',
#     '04:00:00',
#     'REGULAR',
#     '0010282086',
#     '0006891911                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/28/2014',
#     '08:00:00',
#     'REGULAR',
#     '0010282086',
#     '0006891911                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/28/2014',
#     '12:00:00',
#     'REGULAR',
#     '0010282087',
#     '0006891937                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/28/2014',
#     '16:00:00',
#     'REGULAR',
#     '0010282096',
#     '0006891977                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/28/2014',
#     '20:00:00',
#     'REGULAR',
#     '0010282103',
#     '0006891997                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/29/2014',
#     '00:00:00',
#     'REGULAR',
#     '0010282105',
#     '0006892000                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/29/2014',
#     '04:00:00',
#     'REGULAR',
#     '0010282105',
#     '0006892001                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/29/2014',
#     '08:00:00',
#     'REGULAR',
#     '0010282111',
#     '0006892031                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/29/2014',
#     '12:00:00',
#     'REGULAR',
#     '0010282126',
#     '0006892187                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/29/2014',
#     '16:00:00',
#     'REGULAR',
#     '0010282152',
#     '0006892293                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/29/2014',
#     '20:00:00',
#     'REGULAR',
#     '0010282190',
#     '0006892385                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/30/2014',
#     '00:00:00',
#     'REGULAR',
#     '0010282192',
#     '0006892399                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/30/2014',
#     '04:00:00',
#     'REGULAR',
#     '0010282192',
#     '0006892404                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/30/2014',
#     '08:00:00',
#     'REGULAR',
#     '0010282204',
#     '0006892447                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/30/2014',
#     '12:00:00',
#     'REGULAR',
#     '0010282219',
#     '0006892575                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/30/2014',
#     '16:00:00',
#     'REGULAR',
#     '0010282240',
#     '0006892652                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/30/2014',
#     '20:00:00',
#     'REGULAR',
#     '0010282265',
#     '0006892752                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/31/2014',
#     '00:00:00',
#     'REGULAR',
#     '0010282273',
#     '0006892765                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/31/2014',
#     '04:00:00',
#     'REGULAR',
#     '0010282275',
#     '0006892766                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/31/2014',
#     '08:00:00',
#     'REGULAR',
#     '0010282278',
#     '0006892798                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/31/2014',
#     '12:00:00',
#     'REGULAR',
#     '0010282290',
#     '0006892897                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/31/2014',
#     '16:00:00',
#     'REGULAR',
#     '0010282318',
#     '0006892960                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '12/31/2014',
#     '20:00:00',
#     'REGULAR',
#     '0010282340',
#     '0006893028                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/01/2015',
#     '00:00:00',
#     'REGULAR',
#     '0010282344',
#     '0006893066                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/01/2015',
#     '04:00:00',
#     'REGULAR',
#     '0010282344',
#     '0006893078                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/01/2015',
#     '08:00:00',
#     'REGULAR',
#     '0010282344',
#     '0006893084                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/01/2015',
#     '12:00:00',
#     'REGULAR',
#     '0010282347',
#     '0006893104                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/01/2015',
#     '16:00:00',
#     'REGULAR',
#     '0010282356',
#     '0006893148                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/01/2015',
#     '20:00:00',
#     'REGULAR',
#     '0010282361',
#     '0006893182                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/02/2015',
#     '00:00:00',
#     'REGULAR',
#     '0010282366',
#     '0006893190                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/02/2015',
#     '04:00:00',
#     'REGULAR',
#     '0010282367',
#     '0006893192                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/02/2015',
#     '08:00:00',
#     'REGULAR',
#     '0010282368',
#     '0006893218                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/02/2015',
#     '12:00:00',
#     'REGULAR',
#     '0010282393',
#     '0006893335                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/02/2015',
#     '16:00:00',
#     'REGULAR',
#     '0010282411',
#     '0006893418                                       '],
#    ['2345ACJZ',
#     'IRT',
#     '01/02/2015',
#     '20:00:00',
#     'REGULAR',
#     '0010282425',
#     '0006893483                                       ']]),
#  (('N112A', 'R284', '01-00-01', 'CLINTON-WASH AV'),
#   [['C',
#     'IND',
#     '12/27/2014',
#     '03:00:00',
#     'REGULAR',
#     '0000307917',
#     '0001027633                                       '],
#    ['C',
#     'IND',
#     '12/27/2014',
#     '07:00:00',
#     'REGULAR',
#     '0000307924',
#     '0001027646                                       '],
#    ['C',
#     'IND',
#     '12/27/2014',
#     '11:00:00',
#     'REGULAR',
#     '0000307939',
#     '0001027673                                       '],
#    ['C',
#     'IND',
#     '12/27/2014',
#     '15:00:00',
#     'REGULAR',
#     '0000307964',
#     '0001027743                                       '],
#    ['C',
#     'IND',
#     '12/27/2014',
#     '19:00:00',
#     'REGULAR',
#     '0000308006',
#     '0001027862                                       '],
#    ['C',
#     'IND',
#     '12/27/2014',
#     '23:00:00',
#     'REGULAR',
#     '0000308032',
#     '0001028000                                       '],
#    ['C',
#     'IND',
#     '12/28/2014',
#     '03:00:00',
#     'REGULAR',
#     '0000308049',
#     '0001028100                                       '],
#    ['C',
#     'IND',
#     '12/28/2014',
#     '07:00:00',
#     'REGULAR',
#     '0000308055',
#     '0001028126                                       '],
#    ['C',
#     'IND',
#     '12/28/2014',
#     '11:00:00',
#     'REGULAR',
#     '0000308074',
#     '0001028154                                       '],
#    ['C',
#     'IND',
#     '12/28/2014',
#     '15:00:00',
#     'REGULAR',
#     '0000308105',
#     '0001028211                                       '],
#    ['C',
#     'IND',
#     '12/28/2014',
#     '19:00:00',
#     'REGULAR',
#     '0000308163',
#     '0001028354                                       '],
#    ['C',
#     'IND',
#     '12/28/2014',
#     '23:00:00',
#     'REGULAR',
#     '0000308195',
#     '0001028453                                       '],
#    ['C',
#     'IND',
#     '12/29/2014',
#     '03:00:00',
#     'REGULAR',
#     '0000308205',
#     '0001028506                                       '],
#    ['C',
#     'IND',
#     '12/29/2014',
#     '07:00:00',
#     'REGULAR',
#     '0000308215',
#     '0001028521                                       '],
#    ['C',
#     'IND',
#     '12/29/2014',
#     '11:00:00',
#     'REGULAR',
#     '0000308256',
#     '0001028584                                       '],
#    ['C',
#     'IND',
#     '12/29/2014',
#     '15:00:00',
#     'REGULAR',
#     '0000308299',
#     '0001028677                                       '],
#    ['C',
#     'IND',
#     '12/29/2014',
#     '19:00:00',
#     'REGULAR',
#     '0000308386',
#     '0001028941                                       '],
#    ['C',
#     'IND',
#     '12/29/2014',
#     '23:00:00',
#     'REGULAR',
#     '0000308427',
#     '0001029175                                       '],
#    ['C',
#     'IND',
#     '12/30/2014',
#     '03:00:00',
#     'REGULAR',
#     '0000308446',
#     '0001029240                                       '],
#    ['C',
#     'IND',
#     '12/30/2014',
#     '07:00:00',
#     'REGULAR',
#     '0000308454',
#     '0001029248                                       '],
#    ['C',
#     'IND',
#     '12/30/2014',
#     '11:00:00',
#     'REGULAR',
#     '0000308486',
#     '0001029315                                       '],
#    ['C',
#     'IND',
#     '12/30/2014',
#     '15:00:00',
#     'REGULAR',
#     '0000308537',
#     '0001029408                                       '],
#    ['C',
#     'IND',
#     '12/30/2014',
#     '19:00:00',
#     'REGULAR',
#     '0000308629',
#     '0001029732                                       '],
#    ['C',
#     'IND',
#     '12/30/2014',
#     '23:00:00',
#     'REGULAR',
#     '0000308693',
#     '0001029988                                       '],
#    ['C',
#     'IND',
#     '12/31/2014',
#     '03:00:00',
#     'REGULAR',
#     '0000308707',
#     '0001030080                                       '],
#    ['C',
#     'IND',
#     '12/31/2014',
#     '07:00:00',
#     'REGULAR',
#     '0000308718',
#     '0001030096                                       '],
#    ['C',
#     'IND',
#     '12/31/2014',
#     '11:00:00',
#     'REGULAR',
#     '0000308745',
#     '0001030170                                       '],
#    ['C',
#     'IND',
#     '12/31/2014',
#     '15:00:00',
#     'REGULAR',
#     '0000308792',
#     '0001030311                                       '],
#    ['C',
#     'IND',
#     '12/31/2014',
#     '19:00:00',
#     'REGULAR',
#     '0000308863',
#     '0001030644                                       '],
#    ['C',
#     'IND',
#     '12/31/2014',
#     '23:00:00',
#     'REGULAR',
#     '0000308934',
#     '0001030856                                       '],
#    ['C',
#     'IND',
#     '01/01/2015',
#     '03:00:00',
#     'REGULAR',
#     '0000308982',
#     '0001031024                                       '],
#    ['C',
#     'IND',
#     '01/01/2015',
#     '07:00:00',
#     'REGULAR',
#     '0000309003',
#     '0001031073                                       '],
#    ['C',
#     'IND',
#     '01/01/2015',
#     '11:00:00',
#     'REGULAR',
#     '0000309013',
#     '0001031089                                       '],
#    ['C',
#     'IND',
#     '01/01/2015',
#     '15:00:00',
#     'REGULAR',
#     '0000309052',
#     '0001031140                                       '],
#    ['C',
#     'IND',
#     '01/01/2015',
#     '19:00:00',
#     'REGULAR',
#     '0000309101',
#     '0001031264                                       '],
#    ['C',
#     'IND',
#     '01/01/2015',
#     '23:00:00',
#     'REGULAR',
#     '0000309134',
#     '0001031401                                       '],
#    ['C',
#     'IND',
#     '01/02/2015',
#     '03:00:00',
#     'REGULAR',
#     '0000309148',
#     '0001031468                                       '],
#    ['C',
#     'IND',
#     '01/02/2015',
#     '07:00:00',
#     'REGULAR',
#     '0000309157',
#     '0001031477                                       '],
#    ['C',
#     'IND',
#     '01/02/2015',
#     '11:00:00',
#     'REGULAR',
#     '0000309198',
#     '0001031524                                       '],
#    ['C',
#     'IND',
#     '01/02/2015',
#     '15:00:00',
#     'REGULAR',
#     '0000309244',
#     '0001031641                                       '],
#    ['C',
#     'IND',
#     '01/02/2015',
#     '19:00:00',
#     'REGULAR',
#     '0000309340',
#     '0001031904                                       '],
#    ['C',
#     'IND',
#     '01/02/2015',
#     '23:00:00',
#     'REGULAR',
#     '0000309386',
#     '0001032107                                       ']])]

# %% [markdown]
# ### Task 2
# - Let's turn this into a time series.
#
#  For each key (basically the control area, unit, device address and station of a specific turnstile), have a list again, but let the list be comprised of just the point in time and the cumulative count of entries.
#
# This basically means keeping only the date, time, and entries fields in each list. You can convert the date and time into datetime objects -- That is a python class that represents a point in time. You can combine the date and time fields into a string and use the [dateutil](https://dateutil.readthedocs.io/en/stable/) module to convert it into a datetime object.
#
# Your new dict should look something like
#
#     {    ('A002','R051','02-00-00','LEXINGTON AVE'):
#              [
#                 [datetime.datetime(2013, 3, 2, 3, 0), 3788],
#                 [datetime.datetime(2013, 3, 2, 7, 0), 2585],
#                 [datetime.datetime(2013, 3, 2, 12, 0), 10653],
#                 [datetime.datetime(2013, 3, 2, 17, 0), 11016],
#                 [datetime.datetime(2013, 3, 2, 23, 0), 10666],
#                 [datetime.datetime(2013, 3, 3, 3, 0), 10814],
#                 [datetime.datetime(2013, 3, 3, 7, 0), 10229],
#                 ...
#               ],
#      ....
#      }

# %%
from itertools import groupby
from operator import itemgetter

def count_within_normal_bounds(count):
    if count is None:
        return True
    else:
        return 10000 > count >= 0

def convert_time_series_to_daily(high_res_time_series):
    daily_time_series = []
    # I can define a function WITHIN another function. It will only
    # be defined within the scope of the mother function
    def day_of_timestamp(time_series_entry):
        timestamp, tot_entries = time_series_entry
        # the .date() method of a datetime object returns the day
        #(as another datetime object)
        return timestamp.date()
    # groupby() requires data to be sorted. It is sorted already here,
    # but if it wasn't, we would have to sort it first
    count_on_previous_day = None
    for day, entries_on_this_day in groupby(high_res_time_series,
                                                      key=day_of_timestamp):
        # get the maximum cumulative count among the entries on this day
        cum_entry_count_on_day = max([count for time, count in entries_on_this_day])
        # skip the first entry if we don't know the previous day
        if count_on_previous_day is None:
            daily_entries = None
        else:
            daily_entries = cum_entry_count_on_day - count_on_previous_day
        # Save today's count for tomorrow's calculation
        count_on_previous_day = cum_entry_count_on_day
        # Only append if the cumulative increased. Otherwise there is something wrong in the data
        # skip with a warning
        if count_within_normal_bounds(daily_entries):
            daily_time_series.append( (day, daily_entries) )
        else:
            print ('WARNING. Abnormal entry count found '
                   'on day %s: %s' % (day, daily_entries))
            daily_time_series.append( (day, None) )

    return daily_time_series


def combine_multiple_weeks_into_single_high_res_timeseries(weekly_time_series):
    combined_time_series = defaultdict(list)
    for turnstile_to_weeklong_time_series in weekly_time_series:
        for turnstile, weeklong_time_series in turnstile_to_weeklong_time_series.items():
            combined_time_series[turnstile] += weeklong_time_series
    # It's already sorted due to the nature of the files but if not you would want to sort
    # the dates first before retiurning it
    return combined_time_series


def convert_turnstile_to_high_res_time_series_to_daily(turnstile_to_time_series):
    turnstile_to_daily_time_series = {}
    for i, (turnstile, time_series) in enumerate(turnstile_to_time_series.items()):
        print('Processing turnstile', turnstile)
        turnstile_to_daily_time_series[turnstile] = convert_time_series_to_daily(time_series)
    return turnstile_to_daily_time_series


turnstile_to_full_time_series = combine_multiple_weeks_into_single_high_res_timeseries(weekly_time_series)
turnstile_to_daily_time_series = convert_turnstile_to_high_res_time_series_to_daily(turnstile_to_full_time_series)
# Out:
# Processing turnstile ('R208', 'R014', '03-00-00', 'FULTON ST')
# Processing turnstile ('N112A', 'R284', '01-00-01', 'CLINTON-WASH AV')
# Processing turnstile ('R301', 'R323', '00-00-00', '110 ST-CPN')
# Processing turnstile ('R521', 'R327', '00-00-00', '52 ST-LINCOLN')
# Processing turnstile ('N063A', 'R011', '00-00-00', '42 ST-PA BUS TE')
# Processing turnstile ('N329', 'R201', '00-00-01', 'WOODHAVEN BLVD')
# Processing turnstile ('N067', 'R012', '00-00-04', '34 ST-PENN STA')
# Processing turnstile ('R232', 'R176', '02-00-06', '33 ST')
# Processing turnstile ('R417', 'R222', '00-05-01', 'E 177 ST-PARKCH')
# Processing turnstile ('N016A', 'R296', '00-03-01', '163 ST-AMSTERDM')
# Processing turnstile ('N120', 'R153', '00-00-01', 'UTICA AVE')
# Processing turnstile ('R610', 'R057', '00-03-00', 'BARCLAYS CENTER')
# Processing turnstile ('C020', 'R233', '00-00-01', '53 ST')
# Processing turnstile ('N077', 'R111', '02-06-00', '23 ST')
# Processing turnstile ('R639', 'R109', '00-05-02', 'CHURCH AVE')
# Processing turnstile ('N196', 'R285', '00-05-00', 'FAR ROCKAWAY')
# Processing turnstile ('A030', 'R083', '01-00-01', '23 ST-5 AVE')
# Processing turnstile ('R301', 'R323', '00-00-01', '110 ST-CPN')
# Processing turnstile ('N062', 'R011', '01-05-00', '42 ST-PA BUS TE')
# Processing turnstile ('R133', 'R272', '00-00-01', '28 ST')
# Processing turnstile ('N332', 'R219', '01-05-01', '67 AVE')
# Processing turnstile ('N303', 'R015', '00-00-07', '5 AVE-53 ST')
# Processing turnstile ('R128', 'R105', '01-00-00', '14 ST')
# Processing turnstile ('N329', 'R201', '00-03-01', 'WOODHAVEN BLVD')
# Processing turnstile ('R127', 'R105', '00-03-03', '14 ST')
# Processing turnstile ('N340', 'R115', '00-00-05', '169 ST')
# Processing turnstile ('N507', 'R023', '00-00-02', '34 ST-HERALD SQ')
# Processing turnstile ('R515', 'R095', '00-00-03', 'DITMARS BL-31 S')
# Processing turnstile ('PTH05', 'R543', '00-00-00', 'EXCHANGE PLACE')
# Processing turnstile ('R418', 'R106', '00-00-00', 'CASTLE HILL AVE')
# Processing turnstile ('A084', 'R125', '01-00-01', 'BROAD ST')
# Processing turnstile ('N501A', 'R020', '02-03-03', '47-50 ST-ROCK')
# Processing turnstile ('N343', 'R019', '00-00-09', 'JAMAICA-179 ST')
# Processing turnstile ('H027', 'R137', '01-00-01', 'MYRTLE AVE')
# Processing turnstile ('N120A', 'R153', '01-05-00', 'UTICA AVE')
# Processing turnstile ('N549', 'R242', '00-00-00', '18 AVE')
# Processing turnstile ('H026', 'R137', '00-03-00', 'MYRTLE AVE')
# Processing turnstile ('R226A', 'R131', '03-05-01', '23 ST')
# Processing turnstile ('R142', 'R293', '01-06-00', '34 ST-PENN STA')
# Processing turnstile ('N505', 'R022', '02-00-02', '34 ST-HERALD SQ')
# Processing turnstile ('N124', 'R103', '00-00-00', 'BROADWAY-ENY')
# Processing turnstile ('N073', 'R013', '02-00-00', '34 ST-PENN STA')
# Processing turnstile ('R160', 'R164', '02-05-01', '66 ST-LINCOLN')
# Processing turnstile ('J028', 'R004', '00-00-04', 'ELDERTS LANE')
# Processing turnstile ('H041', 'R152', '00-00-01', 'ROCKAWAY PKY')
# Processing turnstile ('J032', 'R006', '01-06-01', 'WOODHAVEN BLVD')
# Processing turnstile ('N203', 'R195', '00-05-01', '161 ST-YANKEE')
# Processing turnstile ('S101A', 'R070', '01-03-03', 'ST. GEORGE')
# Processing turnstile ('R318', 'R408', '00-00-02', 'SIMPSON ST')
# Processing turnstile ('R172', 'R192', '00-00-00', '110 ST-CATHEDRL')
# Processing turnstile ('PTH04', 'R551', '00-01-00', 'GROVE STREET')
# Processing turnstile ('R250', 'R179', '00-00-09', '86 ST')
# Processing turnstile ('B022', 'R229', '00-00-01', 'AVE M')
# Processing turnstile ('N311', 'R339', '01-06-01', '36 ST')
# Processing turnstile ('R326', 'R389', '00-00-01', 'BRONX PARK EAST')
# Processing turnstile ('R331', 'R364', '00-05-01', 'GUN HILL ROAD')
# Processing turnstile ('H032', 'R295', '00-00-02', 'WILSON AVE')
# Processing turnstile ('A007', 'R079', '01-06-03', '5 AVE-59 ST')
# Processing turnstile ('H014', 'R249', '00-00-00', 'GRAHAM AVE')
# Processing turnstile ('N034', 'R334', '01-06-00', 'CATHEDRL-110 ST')
# WARNING. Abnormal entry count found on day 2015-01-20: 50146029
# Processing turnstile ('N544', 'R289', '01-06-00', 'FT HAMILTON PKY')
# Processing turnstile ('N062A', 'R010', '00-00-01', '42 ST-PA BUS TE')
# Processing turnstile ('PTH05', 'R543', '00-04-03', 'EXCHANGE PLACE')
# Processing turnstile ('R523', 'R147', '00-06-01', '61 ST/WOODSIDE')
# Processing turnstile ('A071', 'R044', '02-06-02', 'CHAMBERS ST')
# Processing turnstile ('R113', 'R028', '01-06-01', 'FULTON ST')
# Processing turnstile ('PTH06', 'R546', '00-00-03', 'PAVONIA/NEWPORT')
# Processing turnstile ('N025', 'R102', '01-00-04', '125 ST')
# Processing turnstile ('N507', 'R023', '00-03-06', '34 ST-HERALD SQ')
# Processing turnstile ('R320', 'R409', '00-00-00', 'FREEMAN ST')
# Processing turnstile ('R501', 'R054', '00-06-01', '5 AVE-BRYANT PK')
# Processing turnstile ('B004', 'R171', '00-00-02', '7 AVE')
# Processing turnstile ('N405', 'R239', '00-03-01', 'GREENPOINT AVE')
# Processing turnstile ('N531', 'R129', '01-06-00', 'BERGEN ST')
# Processing turnstile ('N102', 'R127', '01-00-05', 'JAY ST-METROTEC')
# Processing turnstile ('N305', 'R017', '01-00-02', 'LEXINGTON-53 ST')
# Processing turnstile ('N203', 'R195', '00-00-04', '161 ST-YANKEE')
# Processing turnstile ('A006', 'R079', '00-00-00', '5 AVE-59 ST')
# Processing turnstile ('R161B', 'R452', '00-00-02', '72 ST')
# Processing turnstile ('H038', 'R350', '00-00-01', 'LIVONIA AVE')
# Processing turnstile ('N183', 'R415', '00-00-01', 'BROAD CHANNEL')
# Processing turnstile ('R513', 'R093', '00-03-01', 'GRAND-30 AVE')
# Processing turnstile ('R249', 'R179', '01-00-05', '86 ST')
# Processing turnstile ('H041', 'R152', '00-00-00', 'ROCKAWAY PKY')
# Processing turnstile ('N133', 'R384', '00-00-01', 'BOYD-88 ST')
# Processing turnstile ('R310', 'R053', '01-00-00', '149 ST-3 AVE')
# Processing turnstile ('R645', 'R110', '00-00-01', 'FLATBUSH AVE')
# Processing turnstile ('N123B', 'R439', '01-06-01', 'ROCKAWAY AVE')
# Processing turnstile ('N049', 'R084', '01-03-00', '59 ST-COLUMBUS')
# Processing turnstile ('N092', 'R029', '03-00-02', 'CHAMBERS ST')
# Processing turnstile ('C028', 'R216', '01-05-01', 'BAY RIDGE-95 ST')
# Processing turnstile ('PTH07', 'R550', '00-01-05', 'CITY / BUS')
# Processing turnstile ('R154', 'R116', '00-00-01', '50 ST')
# Processing turnstile ('N312', 'R339', '00-00-01', '36 ST')
# Processing turnstile ('A011', 'R080', '01-00-03', '57 ST-7 AVE')
# Processing turnstile ('R317', 'R408', '01-05-01', 'SIMPSON ST')
# Processing turnstile ('R127', 'R105', '00-00-00', '14 ST')
# WARNING. Abnormal entry count found on day 2014-12-28: -1820
# WARNING. Abnormal entry count found on day 2014-12-29: -1613
# WARNING. Abnormal entry count found on day 2014-12-30: -2254
# WARNING. Abnormal entry count found on day 2014-12-31: -2246
# WARNING. Abnormal entry count found on day 2015-01-01: -2158
# WARNING. Abnormal entry count found on day 2015-01-02: -1369
# WARNING. Abnormal entry count found on day 2015-01-03: -2134
# WARNING. Abnormal entry count found on day 2015-01-04: -1634
# WARNING. Abnormal entry count found on day 2015-01-05: -1612
# WARNING. Abnormal entry count found on day 2015-01-06: -2508
# WARNING. Abnormal entry count found on day 2015-01-07: -2531
# WARNING. Abnormal entry count found on day 2015-01-08: -2401
# WARNING. Abnormal entry count found on day 2015-01-09: -2380
# WARNING. Abnormal entry count found on day 2015-01-10: -2531
# WARNING. Abnormal entry count found on day 2015-01-11: -1920
# WARNING. Abnormal entry count found on day 2015-01-12: -1719
# WARNING. Abnormal entry count found on day 2015-01-13: -2508
# WARNING. Abnormal entry count found on day 2015-01-14: -2597
# WARNING. Abnormal entry count found on day 2015-01-15: -2658
# WARNING. Abnormal entry count found on day 2015-01-16: -2722
# WARNING. Abnormal entry count found on day 2015-01-17: -2653
# WARNING. Abnormal entry count found on day 2015-01-18: -2213
# WARNING. Abnormal entry count found on day 2015-01-19: -1463
# WARNING. Abnormal entry count found on day 2015-01-20: -1996
# WARNING. Abnormal entry count found on day 2015-01-21: -2711
# WARNING. Abnormal entry count found on day 2015-01-22: -2739
# WARNING. Abnormal entry count found on day 2015-01-23: -2799
# Processing turnstile ('N035', 'R334', '00-00-00', 'CATHEDRL-110 ST')
# Processing turnstile ('N118', 'R199', '01-00-01', 'KINGSTON-THROOP')
# Processing turnstile ('N418', 'R269', '01-05-01', 'BEDFORD/NOSTRAN')
# Processing turnstile ('R210', 'R044', '00-03-03', 'BROOKLYN BRIDGE')
# Processing turnstile ('R154', 'R116', '00-03-02', '50 ST')
# Processing turnstile ('R148', 'R033', '01-00-00', '42 ST-TIMES SQ')
# Processing turnstile ('J030', 'R005', '00-00-01', 'FOREST PARKWAY')
# Processing turnstile ('R290', 'R161', '00-00-03', 'KINGSBRIDGE RD')
# Processing turnstile ('N091', 'R029', '02-06-00', 'CHAMBERS ST')
# Processing turnstile ('JFK03', 'R536', '00-03-04', 'JFK JAMAICA CT1')
# Processing turnstile ('J032', 'R006', '01-05-01', 'WOODHAVEN BLVD')
# Processing turnstile ('N605', 'R024', '00-06-03', 'SUTPHIN BLVD')
# Processing turnstile ('R246', 'R177', '00-03-05', '68ST-HUNTER COL')
# Processing turnstile ('N095A', 'R014', '01-03-04', 'FULTON ST')
# Processing turnstile ('R516', 'R291', '00-00-02', '33 ST/RAWSON ST')
# Processing turnstile ('R521', 'R327', '00-00-01', '52 ST-LINCOLN')
# Processing turnstile ('R645', 'R110', '00-05-00', 'FLATBUSH AVE')
# Processing turnstile ('PTH07', 'R550', '00-01-08', 'CITY / BUS')
# Processing turnstile ('N056', 'R188', '01-00-00', '50 ST')
# Processing turnstile ('R418', 'R106', '00-00-01', 'CASTLE HILL AVE')
# Processing turnstile ('N100', 'R252', '00-00-00', 'HIGH ST')
# Processing turnstile ('B028', 'R136', '01-00-02', 'SHEEPSHEAD BAY')
# Processing turnstile ('R301', 'R323', '00-06-00', '110 ST-CPN')
# Processing turnstile ('R521', 'R327', '00-06-00', '52 ST-LINCOLN')
# Processing turnstile ('A054', 'R227', '01-06-00', 'RECTOR ST')
# Processing turnstile ('PTH08', 'R540', '00-00-03', 'PATH WTC')
# Processing turnstile ('B023', 'R211', '01-06-02', 'KINGS HIGHWAY')
# Processing turnstile ('R161B', 'R452', '00-03-03', '72 ST')
# Processing turnstile ('N103', 'R127', '00-06-01', 'JAY ST-METROTEC')
# Processing turnstile ('PTH07', 'R550', '00-01-07', 'CITY / BUS')
# Processing turnstile ('R245', 'R051', '00-03-02', '59 ST')
# Processing turnstile ('PTH03', 'R552', '00-01-03', 'JOURNAL SQUARE')
# Processing turnstile ('N090', 'R139', '01-00-01', 'CANAL ST')
# Processing turnstile ('PTH05', 'R543', '00-04-09', 'EXCHANGE PLACE')
# Processing turnstile ('B024A', 'R211', '02-00-03', 'KINGS HIGHWAY')
# Processing turnstile ('PTH17', 'R541', '01-00-01', 'THIRTY THIRD ST')
# Processing turnstile ('B004', 'R171', '00-00-00', '7 AVE')
# Processing turnstile ('R206', 'R014', '02-03-03', 'FULTON ST')
# Processing turnstile ('A081', 'R028', '04-00-03', 'FULTON ST')
# Processing turnstile ('N215', 'R237', '00-00-00', '182-183 ST')
# Processing turnstile ('N335', 'R158', '01-06-03', 'UNION TPK-KEW G')
# Processing turnstile ('N207', 'R104', '00-00-02', '167 ST')
# Processing turnstile ('N418', 'R269', '01-06-00', 'BEDFORD/NOSTRAN')
# Processing turnstile ('H037', 'R349', '00-00-01', 'SUTTER AVE')
# Processing turnstile ('R317', 'R408', '01-00-01', 'SIMPSON ST')
# Processing turnstile ('R215', 'R322', '00-00-01', 'SPRING ST')
# Processing turnstile ('R132', 'R190', '01-00-00', '23 ST')
# Processing turnstile ('N221', 'R155', '00-00-03', 'KINGSBRIDGE RD')
# Processing turnstile ('R160', 'R164', '02-00-02', '66 ST-LINCOLN')
# Processing turnstile ('D006', 'R398', '01-05-00', 'NEW UTRECHT AVE')
# Processing turnstile ('N049', 'R084', '01-02-00', '59 ST-COLUMBUS')
# Processing turnstile ('N311', 'R339', '01-00-01', '36 ST')
# Processing turnstile ('A007', 'R079', '01-05-01', '5 AVE-59 ST')
# Processing turnstile ('R245', 'R051', '00-03-00', '59 ST')
# Processing turnstile ('S101', 'R070', '00-00-00', 'ST. GEORGE')
# Processing turnstile ('R639', 'R109', '00-00-03', 'CHURCH AVE')
# Processing turnstile ('R533', 'R055', '00-00-05', 'MAIN ST')
# Processing turnstile ('R228', 'R143', '00-00-01', '28 ST')
# Processing turnstile ('TRAM2', 'R469', '00-00-01', 'RIT-ROOSEVELT')
# Processing turnstile ('N316', 'R267', '00-00-00', '46 ST')
# Processing turnstile ('N303', 'R015', '00-00-03', '5 AVE-53 ST')
# Processing turnstile ('R111', 'R027', '00-00-03', 'WALL ST')
# Processing turnstile ('A027', 'R082', '01-03-02', '28 ST-BROADWAY')
# Processing turnstile ('R639', 'R109', '00-00-00', 'CHURCH AVE')
# Processing turnstile ('B021', 'R228', '00-00-02', 'AVE J')
# Processing turnstile ('R160', 'R164', '02-03-01', '66 ST-LINCOLN')
# Processing turnstile ('R215', 'R322', '00-00-02', 'SPRING ST')
# Processing turnstile ('H008', 'R248', '01-00-01', '1 AVE')
# Processing turnstile ('R401', 'R445', '00-00-01', '138 ST-3 AVE')
# Processing turnstile ('R322', 'R386', '00-00-01', '174 ST')
# Processing turnstile ('H012', 'R268', '01-00-00', 'LORIMER ST')
# Processing turnstile ('PTH17', 'R541', '01-00-08', 'THIRTY THIRD ST')
# Processing turnstile ('PTH16', 'R550', '01-00-04', 'LACKAWANNA')
# Processing turnstile ('PTH10', 'R547', '00-00-04', '9TH STREET')
# Processing turnstile ('N063A', 'R011', '00-00-09', '42 ST-PA BUS TE')
# Processing turnstile ('R529', 'R208', '00-05-01', '103 ST-CORONA')
# Processing turnstile ('N009', 'R174', '01-00-02', '181 ST')
# Processing turnstile ('R160', 'R164', '02-05-00', '66 ST-LINCOLN')
# Processing turnstile ('N051', 'R084', '02-03-02', '59 ST-COLUMBUS')
# Processing turnstile ('J021', 'R434', '00-00-00', 'VAN SICLEN AVE')
# Processing turnstile ('N339', 'R114', '01-06-00', 'PARSONS BLVD')
# Processing turnstile ('B019', 'R149', '00-00-04', 'NEWKIRK PLAZA')
# Processing turnstile ('R237B', 'R047', '01-00-03', '42 ST-GRD CNTRL')
# Processing turnstile ('JFK03', 'R536', '00-00-01', 'JFK JAMAICA CT1')
# WARNING. Abnormal entry count found on day 2015-01-08: -178536
# Processing turnstile ('PTH18', 'R549', '01-02-00', 'NEWARK BM BW')
# Processing turnstile ('N561', 'R271', '00-00-00', 'AVE X')
# Processing turnstile ('A083', 'R125', '00-00-03', 'BROAD ST')
# Processing turnstile ('R306', 'R207', '00-00-01', '135 ST')
# Processing turnstile ('R238', 'R046', '00-00-01', '42 ST-GRD CNTRL')
# Processing turnstile ('N304', 'R015', '01-01-00', '5 AVE-53 ST')
# Processing turnstile ('R241A', 'R048', '00-00-02', '42 ST-GRD CNTRL')
# Processing turnstile ('R504', 'R276', '00-00-00', 'VERNON/JACKSON')
# Processing turnstile ('J005', 'R353', '00-00-02', 'LORIMER ST')
# Processing turnstile ('R230', 'R143', '02-05-00', '28 ST')
# Processing turnstile ('R417', 'R222', '00-00-00', 'E 177 ST-PARKCH')
# Processing turnstile ('N110', 'R283', '00-03-01', 'LAFAYETTE AVE')
# Processing turnstile ('N330', 'R202', '00-00-00', '63 DR-REGO PARK')
# Processing turnstile ('N606', 'R025', '00-00-03', 'JAMAICA CENTER')
# Processing turnstile ('R643', 'R135', '00-00-00', 'NEWKIRK AVE')
# Processing turnstile ('N325A', 'R218', '00-06-02', 'ELMHURST AVE')
# Processing turnstile ('N095A', 'R014', '01-00-04', 'FULTON ST')
# Processing turnstile ('R532H', 'R328', '02-05-01', 'METS-WILLETS PT')
# Processing turnstile ('N217', 'R112', '00-00-01', 'FORDHAM ROAD')
# Processing turnstile ('R307', 'R207', '01-05-00', '135 ST')
# Processing turnstile ('N336', 'R158', '00-05-01', 'UNION TPK-KEW G')
# Processing turnstile ('N306', 'R017', '00-03-01', 'LEXINGTON-53 ST')
# Processing turnstile ('R158', 'R084', '00-06-03', '59 ST-COLUMBUS')
# Processing turnstile ('JFK03', 'R536', '00-00-04', 'JFK JAMAICA CT1')
# Processing turnstile ('N223', 'R156', '01-06-00', 'BEDFORD PARK BL')
# Processing turnstile ('R726', 'R329', '00-00-01', 'MORRIS PARK')
# Processing turnstile ('R240', 'R047', '00-03-06', '42 ST-GRD CNTRL')
# Processing turnstile ('R190', 'R038', '00-00-01', '215 ST')
# Processing turnstile ('R605', 'R456', '00-00-02', 'HOYT ST')
# Processing turnstile ('R533', 'R055', '00-00-03', 'MAIN ST')
# Processing turnstile ('R244A', 'R050', '01-06-00', '59 ST')
# Processing turnstile ('R130', 'R321', '01-06-01', '18 ST')
# Processing turnstile ('N138', 'R355', '01-06-00', 'GREENWOOD-111')
# Processing turnstile ('B023', 'R211', '01-06-01', 'KINGS HIGHWAY')
# Processing turnstile ('PTH19', 'R549', '02-02-01', 'NEWARK C')
# Processing turnstile ('R154', 'R116', '00-00-04', '50 ST')
# Processing turnstile ('N333A', 'R141', '00-03-00', 'FOREST HILLS-71')
# Processing turnstile ('R158', 'R084', '00-06-01', '59 ST-COLUMBUS')
# Processing turnstile ('H003', 'R163', '01-06-01', '6 AVE')
# Processing turnstile ('A013', 'R081', '01-05-00', '49 ST-7 AVE')
# Processing turnstile ('D002', 'R390', '00-03-02', '8 AVE')
# Processing turnstile ('R318', 'R408', '00-00-01', 'SIMPSON ST')
# Processing turnstile ('R119', 'R320', '00-00-02', 'CANAL ST')
# Processing turnstile ('R289', 'R119', '00-03-01', 'FORDHAM ROAD')
# Processing turnstile ('N095A', 'R014', '01-00-02', 'FULTON ST')
# Processing turnstile ('R507', 'R134', '00-00-02', 'HUNTERS PT AVE')
# Processing turnstile ('N541', 'R241', '01-05-01', '15 ST-PROSPECT')
# Processing turnstile ('PTH13', 'R541', '00-04-00', 'THIRTY ST')
# Processing turnstile ('R421', 'R427', '00-03-01', 'MIDDLETOWN ROAD')
# Processing turnstile ('PTH08', 'R540', '00-00-06', 'PATH WTC')
# Processing turnstile ('D012', 'R395', '00-00-00', 'KINGS HIGHWAY')
# Processing turnstile ('R506', 'R276', '02-05-00', 'VERNON/JACKSON')
# Processing turnstile ('N221', 'R155', '00-00-00', 'KINGSBRIDGE RD')
# Processing turnstile ('R612', 'R057', '01-05-01', 'BARCLAYS CENTER')
# Processing turnstile ('R154', 'R116', '00-03-01', '50 ST')
# Processing turnstile ('PTH07', 'R550', '00-00-07', 'CITY / BUS')
# WARNING. Abnormal entry count found on day 2015-01-01: -762872
# Processing turnstile ('A082', 'R028', '05-05-01', 'FULTON ST')
# Processing turnstile ('PTH01', 'R549', '00-00-07', 'NEWARK HW BMEBE')
# Processing turnstile ('N317', 'R267', '02-00-01', '46 ST')
# Processing turnstile ('N098', 'R028', '00-05-00', 'FULTON ST')
# Processing turnstile ('N546', 'R204', '00-00-00', 'CHURCH AVE')
# Processing turnstile ('R626', 'R062', '00-00-02', 'CROWN HTS-UTICA')
# Processing turnstile ('R208', 'R014', '03-03-01', 'FULTON ST')
# Processing turnstile ('H003', 'R163', '01-00-00', '6 AVE')
# Processing turnstile ('PTH08', 'R540', '00-04-08', 'PATH WTC')
# WARNING. Abnormal entry count found on day 2015-01-14: -46409
# WARNING. Abnormal entry count found on day 2015-01-15: -145
# Processing turnstile ('C023', 'R213', '00-00-00', 'BAY RIDGE AVE')
# Processing turnstile ('A042', 'R086', '01-00-04', "PRINCE ST-B'WAY")
# Processing turnstile ('C010', 'R231', '00-00-01', 'UNION ST')
# Processing turnstile ('N324', 'R018', '00-02-00', 'ROOSEVELT AVE')
# Processing turnstile ('R113', 'R028', '01-06-03', 'FULTON ST')
# Processing turnstile ('N129', 'R382', '00-03-00', 'GRANT AVE')
# Processing turnstile ('R116', 'R030', '00-03-00', 'CHAMBERS ST')
# Processing turnstile ('N185', 'R417', '00-00-00', 'BEACH 98 ST')
# Processing turnstile ('H039', 'R375', '00-00-01', 'NEW LOTS AVE')
# Processing turnstile ('N325A', 'R218', '00-03-00', 'ELMHURST AVE')
# Processing turnstile ('R509', 'R121', '00-00-00', 'QUEENSBORO PLZ')
# Processing turnstile ('PTH01', 'R549', '00-00-04', 'NEWARK HW BMEBE')
# Processing turnstile ('A046', 'R463', '00-06-05', 'CANAL ST')
# Processing turnstile ('R632', 'R067', '00-00-02', 'PENNSYLVANIA AV')
# Processing turnstile ('R516', 'R291', '00-00-00', '33 ST/RAWSON ST')
# Processing turnstile ('R606', 'R225', '00-06-00', 'HOYT ST')
# Processing turnstile ('R610', 'R057', '00-04-04', 'BARCLAYS CENTER')
# Processing turnstile ('N067', 'R012', '00-05-01', '34 ST-PENN STA')
# Processing turnstile ('S101A', 'R070', '01-00-03', 'ST. GEORGE')
# Processing turnstile ('A077', 'R028', '03-03-00', 'FULTON ST')
# Processing turnstile ('R625', 'R062', '01-00-02', 'CROWN HTS-UTICA')
# Processing turnstile ('N010', 'R126', '00-00-03', '175 ST')
# Processing turnstile ('PTH05', 'R543', '00-00-04', 'EXCHANGE PLACE')
# Processing turnstile ('N135', 'R385', '01-06-00', 'ROCKAWAY BLVD')
# Processing turnstile ('N070', 'R012', '04-00-03', '34 ST-PENN STA')
# Processing turnstile ('N039', 'R251', '01-00-02', '96 ST')
# Processing turnstile ('N603', 'R303', '00-05-00', '21 ST')
# Processing turnstile ('R217A', 'R194', '00-00-01', 'BLEECKER ST')
# Processing turnstile ('R139', 'R031', '04-00-00', '34 ST-PENN STA')
# Processing turnstile ('R284', 'R243', '00-00-01', '170 ST')
# Processing turnstile ('R143', 'R032', '02-03-01', '42 ST-TIMES SQ')
# Processing turnstile ('R423', 'R429', '00-00-04', 'PELHAM BAY PARK')
# Processing turnstile ('R127', 'R105', '00-03-02', '14 ST')
# Processing turnstile ('N103', 'R127', '00-00-05', 'JAY ST-METROTEC')
# Processing turnstile ('R130', 'R321', '01-00-00', '18 ST')
# Processing turnstile ('N203', 'R195', '00-03-00', '161 ST-YANKEE')
# Processing turnstile ('N414A', 'R316', '01-00-01', 'FLUSHING AVE')
# Processing turnstile ('J024', 'R437', '00-00-01', 'CRESCENT ST')
# Processing turnstile ('B022', 'R229', '00-00-04', 'AVE M')
# Processing turnstile ('K017', 'R401', '00-00-01', 'CENTRAL AVE')
# Processing turnstile ('N224', 'R157', '00-00-04', 'NORWOOD-205 ST')
# Processing turnstile ('R609', 'R056', '01-00-02', 'NEVINS ST')
# Processing turnstile ('N187', 'R419', '00-00-01', 'ROCKAWAY PK 116')
# Processing turnstile ('N056', 'R188', '01-00-02', '50 ST')
# Processing turnstile ('K025', 'R404', '00-03-02', 'FRESH POND ROAD')
# Processing turnstile ('PTH03', 'R552', '00-01-07', 'JOURNAL SQUARE')
# Processing turnstile ('N029', 'R333', '01-00-02', '116 ST')
# Processing turnstile ('B017', 'R262', '00-00-01', 'BEVERLEY ROAD')
# Processing turnstile ('R201', 'R041', '00-06-01', 'BOWLING GREEN')
# Processing turnstile ('N091', 'R029', '02-00-03', 'CHAMBERS ST')
# Processing turnstile ('A050', 'R088', '00-06-01', 'CORTLANDT ST')
# Processing turnstile ('N090', 'R139', '01-05-00', 'CANAL ST')
# Processing turnstile ('N528', 'R257', '01-06-01', 'EAST BROADWAY')
# Processing turnstile ('N539A', 'R288', '00-00-01', '7 AV-PARK SLOPE')
# Processing turnstile ('A027', 'R082', '01-03-01', '28 ST-BROADWAY')
# WARNING. Abnormal entry count found on day 2015-01-06: -195616
# Processing turnstile ('N535', 'R220', '00-03-00', 'CARROLL ST')
# Processing turnstile ('R645', 'R110', '00-03-01', 'FLATBUSH AVE')
# Processing turnstile ('N221', 'R155', '00-00-01', 'KINGSBRIDGE RD')
# Processing turnstile ('N116', 'R198', '00-03-01', 'NOSTRAND AVE')
# Processing turnstile ('N526', 'R142', '02-00-04', 'DELANCEY ST')
# Processing turnstile ('N309A', 'R140', '00-03-00', 'QUEENS PLAZA')
# Processing turnstile ('D011', 'R394', '01-06-01', 'BAY PKY-22 AVE')
# Processing turnstile ('R210', 'R044', '00-05-00', 'BROOKLYN BRIDGE')
# Processing turnstile ('A061', 'R142', '00-00-01', 'ESSEX ST')
# Processing turnstile ('N139', 'R355', '00-00-00', 'GREENWOOD-111')
# Processing turnstile ('N511', 'R163', '03-00-01', '14 ST-6 AVE')
# Processing turnstile ('H009', 'R235', '00-03-04', 'BEDFORD AVE')
# Processing turnstile ('N083', 'R138', '01-06-00', 'W 4 ST-WASH SQ')
# Processing turnstile ('N304', 'R015', '01-00-00', '5 AVE-53 ST')
# Processing turnstile ('N128', 'R200', '00-00-04', 'EUCLID AVE')
# Processing turnstile ('N307', 'R359', '00-00-02', 'COURT SQ-23 ST')
# Processing turnstile ('R155', 'R116', '01-00-03', '50 ST')
# Processing turnstile ('R180', 'R193', '00-00-03', '157 ST')
# Processing turnstile ('N500', 'R020', '00-05-00', '47-50 ST-ROCK')
# Processing turnstile ('R285', 'R308', '00-00-02', 'MT EDEN AVE')
# Processing turnstile ('R174', 'R034', '00-00-03', '125 ST')
# Processing turnstile ('N129', 'R382', '00-03-01', 'GRANT AVE')
# Processing turnstile ('N504', 'R021', '02-00-02', '42 ST-BRYANT PK')
# Processing turnstile ('B020', 'R263', '00-00-00', 'AVE H')
# Processing turnstile ('C023', 'R213', '00-00-03', 'BAY RIDGE AVE')
# Processing turnstile ('N076', 'R111', '00-00-02', '23 ST')
# Processing turnstile ('J016', 'R381', '00-00-02', 'HALSEY ST')
# Processing turnstile ('R304', 'R206', '00-00-00', '125 ST')
# WARNING. Abnormal entry count found on day 2015-01-07: 1684308912
# WARNING. Abnormal entry count found on day 2015-01-08: -1198
# WARNING. Abnormal entry count found on day 2015-01-09: -2014
# WARNING. Abnormal entry count found on day 2015-01-10: -2247
# WARNING. Abnormal entry count found on day 2015-01-11: -1473
# WARNING. Abnormal entry count found on day 2015-01-12: -1196
# WARNING. Abnormal entry count found on day 2015-01-13: -2028
# WARNING. Abnormal entry count found on day 2015-01-14: -2148
# WARNING. Abnormal entry count found on day 2015-01-15: -2212
# WARNING. Abnormal entry count found on day 2015-01-16: -2156
# WARNING. Abnormal entry count found on day 2015-01-17: -2370
# WARNING. Abnormal entry count found on day 2015-01-18: -1571
# WARNING. Abnormal entry count found on day 2015-01-19: -1069
# WARNING. Abnormal entry count found on day 2015-01-20: -1403
# WARNING. Abnormal entry count found on day 2015-01-21: -2189
# WARNING. Abnormal entry count found on day 2015-01-22: -2234
# WARNING. Abnormal entry count found on day 2015-01-23: -2218
# Processing turnstile ('B020', 'R263', '00-06-02', 'AVE H')
# Processing turnstile ('R420', 'R107', '00-00-01', 'WESTCHESTER SQ')
# Processing turnstile ('R515', 'R095', '00-00-01', 'DITMARS BL-31 S')
# Processing turnstile ('R247', 'R178', '01-03-01', '77 ST')
# Processing turnstile ('A038', 'R085', '00-00-02', "8 ST-B'WAY NYU")
# Processing turnstile ('N333A', 'R141', '00-00-00', 'FOREST HILLS-71')
# Processing turnstile ('R507', 'R134', '00-03-02', 'HUNTERS PT AVE')
# Processing turnstile ('N213', 'R154', '00-00-00', 'TREMONT AVE')
# Processing turnstile ('A084', 'R125', '01-06-01', 'BROAD ST')
# Processing turnstile ('R237', 'R046', '01-00-02', '42 ST-GRD CNTRL')
# Processing turnstile ('R625', 'R062', '01-00-01', 'CROWN HTS-UTICA')
# Processing turnstile ('R124', 'R290', '03-00-02', 'HOUSTON ST')
# Processing turnstile ('PTH06', 'R546', '00-00-0A', 'PAVONIA/NEWPORT')
# Processing turnstile ('R169', 'R168', '01-03-00', '96 ST')
# Processing turnstile ('PTH16', 'R550', '01-02-03', 'LACKAWANNA')
# Processing turnstile ('D002', 'R390', '00-00-01', '8 AVE')
# Processing turnstile ('PTH04', 'R551', '00-04-05', 'GROVE STREET')
# Processing turnstile ('PTH08', 'R540', '00-00-05', 'PATH WTC')
# Processing turnstile ('N067', 'R012', '00-03-00', '34 ST-PENN STA')
# Processing turnstile ('PTH06', 'R546', '00-00-06', 'PAVONIA/NEWPORT')
# Processing turnstile ('R188', 'R037', '00-06-00', '207 ST')
# Processing turnstile ('N340A', 'R115', '01-00-01', '169 ST')
# Processing turnstile ('N125', 'R440', '00-00-00', 'LIBERTY AVE')
# Processing turnstile ('N120', 'R153', '00-05-00', 'UTICA AVE')
# Processing turnstile ('R204', 'R043', '02-05-01', 'WALL ST')
# Processing turnstile ('N072', 'R012', '05-03-00', '34 ST-PENN STA')
# Processing turnstile ('B021', 'R228', '00-00-01', 'AVE J')
# Processing turnstile ('A050', 'R088', '00-06-02', 'CORTLANDT ST')
# Processing turnstile ('G015', 'R312', '01-05-00', 'W 8 ST-AQUARIUM')
# Processing turnstile ('R310', 'R053', '01-03-00', '149 ST-3 AVE')
# Processing turnstile ('N113', 'R297', '00-00-00', 'FRANKLIN AVE')
# Processing turnstile ('A021', 'R032', '01-00-04', '42 ST-TIMES SQ')
# Processing turnstile ('R196', 'R306', '00-00-02', '238 ST')
# Processing turnstile ('R630', 'R066', '00-00-00', 'JUNIUS ST')
# Processing turnstile ('R194', 'R040', '00-03-01', '231 ST')
# Processing turnstile ('R244A', 'R050', '01-00-02', '59 ST')
# Processing turnstile ('N324', 'R018', '00-06-00', 'ROOSEVELT AVE')
# Processing turnstile ('A047', 'R087', '00-06-02', 'CITY HALL')
# Processing turnstile ('A002', 'R051', '02-05-01', 'LEXINGTON AVE')
# Processing turnstile ('N092', 'R029', '03-00-01', 'CHAMBERS ST')
# Processing turnstile ('N556', 'R424', '00-00-01', 'AVE P')
# Processing turnstile ('H039', 'R375', '00-00-02', 'NEW LOTS AVE')
# Processing turnstile ('N600', 'R302', '00-00-00', '57 ST')
# Processing turnstile ('PTH18', 'R549', '01-02-03', 'NEWARK BM BW')
# Processing turnstile ('N303', 'R015', '00-00-0B', '5 AVE-53 ST')
# Processing turnstile ('R610', 'R057', '00-04-05', 'BARCLAYS CENTER')
# Processing turnstile ('N034', 'R334', '01-06-01', 'CATHEDRL-110 ST')
# Processing turnstile ('R243', 'R049', '00-03-00', '51 ST')
# Processing turnstile ('N070', 'R012', '04-05-01', '34 ST-PENN STA')
# Processing turnstile ('J012', 'R379', '00-00-00', 'KOSCIUSZKO ST')
# Processing turnstile ('N090', 'R139', '01-03-00', 'CANAL ST')
# Processing turnstile ('N311', 'R339', '01-06-00', '36 ST')
# Processing turnstile ('R116', 'R030', '00-03-01', 'CHAMBERS ST')
# Processing turnstile ('A046', 'R463', '00-06-01', 'CANAL ST')
# Processing turnstile ('N029', 'R333', '01-00-00', '116 ST')
# Processing turnstile ('A034', 'R170', '03-06-00', '14 ST-UNION SQ')
# Processing turnstile ('N013', 'R035', '02-00-02', '168 ST-BROADWAY')
# Processing turnstile ('N501A', 'R020', '02-00-02', '47-50 ST-ROCK')
# Processing turnstile ('R602', 'R108', '00-00-01', 'BOROUGH HALL/CT')
# Processing turnstile ('R205A', 'R014', '04-03-00', 'FULTON ST')
# Processing turnstile ('N070', 'R012', '04-00-01', '34 ST-PENN STA')
# Processing turnstile ('N010', 'R126', '00-00-00', '175 ST')
# Processing turnstile ('B019', 'R149', '00-00-02', 'NEWKIRK PLAZA')
# Processing turnstile ('N401', 'R360', '00-00-00', 'VAN ALSTON-21ST')
# Processing turnstile ('B031', 'R172', '01-06-01', 'BRIGHTON BEACH')
# Processing turnstile ('N333B', 'R141', '02-01-01', 'FOREST HILLS-71')
# Processing turnstile ('N022', 'R332', '02-06-01', '135 ST')
# Processing turnstile ('N057', 'R188', '00-05-00', '50 ST')
# Processing turnstile ('A031', 'R083', '00-03-02', '23 ST-5 AVE')
# Processing turnstile ('R131', 'R190', '00-00-00', '23 ST')
# Processing turnstile ('N501A', 'R020', '02-00-00', '47-50 ST-ROCK')
# Processing turnstile ('PTH11', 'R545', '00-04-01', '14TH STREET')
# Processing turnstile ('R636', 'R209', '00-00-01', 'STERLING ST')
# Processing turnstile ('R525', 'R018', '02-00-00', '74 ST-BROADWAY')
# Processing turnstile ('N400A', 'R359', '02-06-01', 'COURT SQ')
# Processing turnstile ('R635', 'R277', '00-00-00', 'PRESIDENT ST')
# Processing turnstile ('H017', 'R265', '00-00-00', 'MONTROSE AVE')
# Processing turnstile ('R171', 'R192', '01-00-01', '110 ST-CATHEDRL')
# Processing turnstile ('B022', 'R229', '00-05-01', 'AVE M')
# Processing turnstile ('N530', 'R301', '00-00-01', 'YORK ST')
# Processing turnstile ('R412', 'R146', '00-03-00', 'HUNTS POINT AVE')
# Processing turnstile ('PTH04', 'R551', '00-04-00', 'GROVE STREET')
# Processing turnstile ('N071', 'R013', '00-06-00', '34 ST-PENN STA')
# Processing turnstile ('N098', 'R028', '00-02-00', 'FULTON ST')
# Processing turnstile ('N602', 'R259', '00-05-00', 'ROOSEVELT IS')
# Processing turnstile ('N330C', 'R202', '01-04-01', '63 DR-REGO PARK')
# Processing turnstile ('R610', 'R057', '00-03-04', 'BARCLAYS CENTER')
# Processing turnstile ('R288', 'R275', '00-00-03', '183 ST')
# Processing turnstile ('R245', 'R051', '00-05-02', '59 ST')
# Processing turnstile ('N023', 'R332', '01-00-01', '135 ST')
# Processing turnstile ('N039', 'R251', '01-06-01', '96 ST')
# Processing turnstile ('J003', 'R352', '00-00-00', 'HEWES ST')
# Processing turnstile ('PTH04', 'R551', '00-00-01', 'GROVE STREET')
# WARNING. Abnormal entry count found on day 2015-01-08: -41712
# Processing turnstile ('R523', 'R147', '00-00-05', '61 ST/WOODSIDE')
# Processing turnstile ('R508', 'R346', '00-05-00', 'COURT SQ')
# Processing turnstile ('A043', 'R462', '00-03-04', 'CANAL ST')
# Processing turnstile ('R637', 'R451', '00-00-01', 'WINTHROP ST')
# WARNING. Abnormal entry count found on day 2015-01-17: 12378
# Processing turnstile ('N519A', 'R461', '01-01-02', 'BROADWAY/LAFAY')
# Processing turnstile ('R421', 'R427', '00-06-01', 'MIDDLETOWN ROAD')
# Processing turnstile ('R203', 'R043', '00-03-02', 'WALL ST')
# Processing turnstile ('PTH16', 'R550', '01-00-00', 'LACKAWANNA')
# Processing turnstile ('R229', 'R143', '01-00-03', '28 ST')
# Processing turnstile ('E005', 'R247', '00-00-01', '55 ST')
# Processing turnstile ('N333A', 'R141', '00-00-02', 'FOREST HILLS-71')
# Processing turnstile ('R227A', 'R131', '01-00-00', '23 ST')
# Processing turnstile ('N092', 'R029', '03-03-02', 'CHAMBERS ST')
# Processing turnstile ('H038', 'R350', '00-06-01', 'LIVONIA AVE')
# Processing turnstile ('R201', 'R041', '00-06-00', 'BOWLING GREEN')
# Processing turnstile ('R293', 'R133', '00-06-02', 'MOSHOLU PARKWAY')
# WARNING. Abnormal entry count found on day 2015-01-14: -9328
# Processing turnstile ('C015', 'R454', '00-00-00', 'PROSPECT AVE')
# Processing turnstile ('A021', 'R032', '01-00-05', '42 ST-TIMES SQ')
# Processing turnstile ('PTH05', 'R543', '00-04-01', 'EXCHANGE PLACE')
# WARNING. Abnormal entry count found on day 2015-01-10: -401361
# Processing turnstile ('R283', 'R221', '00-00-01', '167 ST')
# Processing turnstile ('N412', 'R299', '00-00-01', 'BROADWAY')
# Processing turnstile ('G011', 'R312', '00-00-03', 'W 8 ST-AQUARIUM')
# Processing turnstile ('N422', 'R318', '00-00-01', 'FULTON ST')
# Processing turnstile ('N500', 'R020', '00-06-01', '47-50 ST-ROCK')
# Processing turnstile ('N091', 'R029', '02-00-05', 'CHAMBERS ST')
# Processing turnstile ('PTH07', 'R550', '00-01-02', 'CITY / BUS')
# Processing turnstile ('R203', 'R043', '00-05-00', 'WALL ST')
# Processing turnstile ('N546', 'R204', '00-00-06', 'CHURCH AVE')
# Processing turnstile ('N124', 'R103', '00-00-03', 'BROADWAY-ENY')
# Processing turnstile ('R508', 'R346', '00-05-01', 'COURT SQ')
# Processing turnstile ('PTH01', 'R549', '00-01-04', 'NEWARK HW BMEBE')
# Processing turnstile ('R236', 'R045', '00-03-01', '42 ST-GRD CNTRL')
# Processing turnstile ('N412', 'R299', '00-00-02', 'BROADWAY')
# Processing turnstile ('R518', 'R261', '00-00-01', '40 ST-LOWERY ST')
# Processing turnstile ('R127', 'R105', '00-00-01', '14 ST')
# Processing turnstile ('B031', 'R172', '01-00-00', 'BRIGHTON BEACH')
# Processing turnstile ('N318', 'R298', '00-00-00', 'NORTHERN BLVD')
# Processing turnstile ('N409', 'R268', '00-00-01', 'METROPOLITAN AV')
# Processing turnstile ('N525', 'R142', '01-00-03', 'DELANCEY ST')
# Processing turnstile ('N098', 'R028', '00-00-00', 'FULTON ST')
# Processing turnstile ('R323', 'R387', '00-06-00', 'E TREMONT AVE')
# Processing turnstile ('R236', 'R045', '00-03-02', '42 ST-GRD CNTRL')
# Processing turnstile ('N120A', 'R153', '01-00-03', 'UTICA AVE')
# Processing turnstile ('R219', 'R160', '00-00-04', 'ASTOR PLACE')
# Processing turnstile ('R306', 'R207', '00-00-00', '135 ST')
# Processing turnstile ('PTH08', 'R540', '00-00-04', 'PATH WTC')
# Processing turnstile ('R122', 'R290', '02-06-00', 'HOUSTON ST')
# Processing turnstile ('A033', 'R170', '02-00-05', '14 ST-UNION SQ')
# Processing turnstile ('N542', 'R241', '00-00-02', '15 ST-PROSPECT')
# Processing turnstile ('R244', 'R050', '00-06-02', '59 ST')
# Processing turnstile ('N331', 'R219', '00-00-01', '67 AVE')
# Processing turnstile ('N063', 'R011', '02-00-00', '42 ST-PA BUS TE')
# Processing turnstile ('C001', 'R108', '01-00-01', 'BOROUGH HALL/CT')
# Processing turnstile ('PTH08', 'R540', '00-01-01', 'PATH WTC')
# Processing turnstile ('R168A', 'R168', '00-00-01', '96 ST')
# Processing turnstile ('N095', 'R014', '00-03-05', 'FULTON ST')
# Processing turnstile ('R254', 'R181', '01-00-02', '110 ST')
# Processing turnstile ('R514', 'R094', '00-03-00', 'HOYT ST-ASTORIA')
# Processing turnstile ('N062A', 'R010', '00-00-00', '42 ST-PA BUS TE')
# Processing turnstile ('N549', 'R242', '00-00-02', '18 AVE')
# Processing turnstile ('N502', 'R021', '01-00-03', '42 ST-BRYANT PK')
# Processing turnstile ('N220', 'R155', '01-00-04', 'KINGSBRIDGE RD')
# Processing turnstile ('H035', 'R348', '00-00-02', 'ATLANTIC AVE')
# Processing turnstile ('R246', 'R177', '00-03-02', '68ST-HUNTER COL')
# Processing turnstile ('R147', 'R033', '04-00-00', '42 ST-TIMES SQ')
# Processing turnstile ('R165', 'R167', '01-00-04', '86 ST')
# Processing turnstile ('R504', 'R276', '00-00-03', 'VERNON/JACKSON')
# Processing turnstile ('N203', 'R195', '00-00-02', '161 ST-YANKEE')
# Processing turnstile ('J030', 'R005', '00-00-00', 'FOREST PARKWAY')
# Processing turnstile ('R526', 'R096', '00-05-03', '82 ST-JACKSON H')
# Processing turnstile ('N062A', 'R010', '00-00-03', '42 ST-PA BUS TE')
# Processing turnstile ('N063A', 'R011', '00-00-04', '42 ST-PA BUS TE')
# Processing turnstile ('PTH19', 'R549', '02-01-02', 'NEWARK C')
# Processing turnstile ('N323', 'R018', '01-06-01', 'ROOSEVELT AVE')
# Processing turnstile ('R509', 'R121', '00-00-01', 'QUEENSBORO PLZ')
# Processing turnstile ('R501', 'R054', '00-00-04', '5 AVE-BRYANT PK')
# Processing turnstile ('R231', 'R176', '00-00-04', '33 ST')
# Processing turnstile ('R533', 'R055', '00-03-07', 'MAIN ST')
# Processing turnstile ('A049', 'R088', '02-03-00', 'CORTLANDT ST')
# Processing turnstile ('N007A', 'R174', '00-00-00', '181 ST')
# Processing turnstile ('H001', 'R175', '00-00-04', '8 AVE')
# Processing turnstile ('R128', 'R105', '01-06-00', '14 ST')
# Processing turnstile ('N543', 'R289', '00-00-01', 'FT HAMILTON PKY')
# Processing turnstile ('J007', 'R377', '00-05-01', 'FLUSHING AVE')
# Processing turnstile ('N304', 'R015', '01-06-02', '5 AVE-53 ST')
# Processing turnstile ('R171', 'R192', '01-00-02', '110 ST-CATHEDRL')
# Processing turnstile ('R110', 'R027', '01-00-02', 'WALL ST')
# Processing turnstile ('PTH01', 'R549', '00-00-09', 'NEWARK HW BMEBE')
# Processing turnstile ('R192', 'R039', '00-06-00', 'MARBLE HILL-225')
# Processing turnstile ('R182', 'R035', '00-05-01', '168 ST-BROADWAY')
# Processing turnstile ('R322', 'R386', '00-00-00', '174 ST')
# Processing turnstile ('N537', 'R258', '00-00-01', '4 AVE')
# Processing turnstile ('N325A', 'R218', '00-06-00', 'ELMHURST AVE')
# Processing turnstile ('R604', 'R108', '03-00-01', 'BOROUGH HALL/CT')
# Processing turnstile ('B021', 'R228', '00-00-03', 'AVE J')
# Processing turnstile ('R154', 'R116', '00-00-03', '50 ST')
# Processing turnstile ('R147', 'R033', '04-05-01', '42 ST-TIMES SQ')
# Processing turnstile ('R236', 'R045', '00-06-00', '42 ST-GRD CNTRL')
# Processing turnstile ('A014', 'R081', '02-00-02', '49 ST-7 AVE')
# Processing turnstile ('A037', 'R170', '05-00-02', '14 ST-UNION SQ')
# Processing turnstile ('N113', 'R297', '00-00-02', 'FRANKLIN AVE')
# Processing turnstile ('R226', 'R131', '02-05-02', '23 ST')
# Processing turnstile ('R408', 'R449', '00-00-00', 'E 149 ST')
# Processing turnstile ('R610', 'R057', '00-04-03', 'BARCLAYS CENTER')
# Processing turnstile ('R632', 'R067', '00-00-00', 'PENNSYLVANIA AV')
# Processing turnstile ('R112', 'R027', '02-00-02', 'WALL ST')
# Processing turnstile ('N192', 'R336', '00-05-00', 'BEACH 60 ST')
# Processing turnstile ('R200A', 'R041', '01-00-05', 'BOWLING GREEN')
# Processing turnstile ('N306', 'R017', '00-03-03', 'LEXINGTON-53 ST')
# Processing turnstile ('R246', 'R177', '00-00-00', '68ST-HUNTER COL')
# Processing turnstile ('H038', 'R350', '00-00-02', 'LIVONIA AVE')
# Processing turnstile ('PTH13', 'R541', '00-04-05', 'THIRTY ST')
# Processing turnstile ('R293', 'R133', '00-06-01', 'MOSHOLU PARKWAY')
# Processing turnstile ('R246', 'R177', '00-03-01', '68ST-HUNTER COL')
# Processing turnstile ('R217A', 'R194', '00-00-00', 'BLEECKER ST')
# Processing turnstile ('N119', 'R199', '00-00-02', 'KINGSTON-THROOP')
# Processing turnstile ('N092', 'R029', '03-00-03', 'CHAMBERS ST')
# Processing turnstile ('N083', 'R138', '01-00-00', 'W 4 ST-WASH SQ')
# Processing turnstile ('B027', 'R136', '00-00-04', 'SHEEPSHEAD BAY')
# Processing turnstile ('R248', 'R178', '00-00-01', '77 ST')
# Processing turnstile ('R423', 'R429', '00-00-02', 'PELHAM BAY PARK')
# Processing turnstile ('PTH08', 'R540', '00-01-08', 'PATH WTC')
# Processing turnstile ('N503', 'R021', '00-00-04', '42 ST-BRYANT PK')
# Processing turnstile ('R204', 'R043', '02-06-01', 'WALL ST')
# Processing turnstile ('N324', 'R018', '00-00-02', 'ROOSEVELT AVE')
# Processing turnstile ('R600', 'R224', '00-00-02', 'CLARK ST')
# Processing turnstile ('N051', 'R084', '02-00-01', '59 ST-COLUMBUS')
# Processing turnstile ('A022', 'R022', '01-00-00', '34 ST-HERALD SQ')
# Processing turnstile ('R248', 'R178', '00-00-04', '77 ST')
# Processing turnstile ('N083', 'R138', '01-02-02', 'W 4 ST-WASH SQ')
# Processing turnstile ('R203A', 'R043', '01-06-01', 'WALL ST')
# Processing turnstile ('R612', 'R057', '01-00-04', 'BARCLAYS CENTER')
# Processing turnstile ('N126', 'R441', '00-00-00', 'VAN SICLEN AVE')
# Processing turnstile ('C012', 'R258', '01-00-01', '9 ST')
# Processing turnstile ('R244', 'R050', '00-00-04', '59 ST')
# Processing turnstile ('R113', 'R028', '01-06-00', 'FULTON ST')
# Processing turnstile ('N049', 'R084', '01-00-02', '59 ST-COLUMBUS')
# Processing turnstile ('R242', 'R049', '01-00-02', '51 ST')
# Processing turnstile ('H007', 'R248', '00-03-00', '1 AVE')
# Processing turnstile ('R169', 'R168', '01-03-04', '96 ST')
# Processing turnstile ('N001', 'R173', '01-06-00', 'INWOOD-207 ST')
# Processing turnstile ('N102', 'R127', '01-06-01', 'JAY ST-METROTEC')
# Processing turnstile ('R625', 'R062', '01-00-00', 'CROWN HTS-UTICA')
# Processing turnstile ('R262B', 'R195', '05-00-01', '161 ST-YANKEE')
# Processing turnstile ('PTH01', 'R549', '00-01-06', 'NEWARK HW BMEBE')
# Processing turnstile ('E001', 'R368', '00-00-02', '9 AVE')
# Processing turnstile ('R606', 'R225', '00-00-04', 'HOYT ST')
# Processing turnstile ('C016', 'R278', '00-00-02', '25 ST')
# Processing turnstile ('R618', 'R058', '01-06-01', 'BERGEN ST')
# Processing turnstile ('N519A', 'R461', '01-01-00', 'BROADWAY/LAFAY')
# Processing turnstile ('N067', 'R012', '00-06-01', '34 ST-PENN STA')
# Processing turnstile ('N133', 'R384', '00-00-02', 'BOYD-88 ST')
# Processing turnstile ('R120', 'R320', '01-00-00', 'CANAL ST')
# Processing turnstile ('N420B', 'R317', '00-06-01', 'CLINTON-WASH AV')
# Processing turnstile ('R238', 'R046', '00-06-01', '42 ST-GRD CNTRL')
# Processing turnstile ('R196', 'R306', '00-00-01', '238 ST')
# Processing turnstile ('R244A', 'R050', '01-00-03', '59 ST')
# Processing turnstile ('N191', 'R335', '00-00-00', 'BEACH 67 ST')
# Processing turnstile ('PTH17', 'R541', '01-00-05', 'THIRTY THIRD ST')
# Processing turnstile ('N209', 'R443', '00-00-02', '170 ST')
# Processing turnstile ('N519A', 'R461', '01-00-01', 'BROADWAY/LAFAY')
# Processing turnstile ('H015', 'R250', '01-00-02', 'GRAND ST')
# Processing turnstile ('R221', 'R170', '01-06-00', '14 ST-UNION SQ')
# Processing turnstile ('R610', 'R057', '00-03-05', 'BARCLAYS CENTER')
# Processing turnstile ('N306', 'R017', '00-00-03', 'LEXINGTON-53 ST')
# Processing turnstile ('R635', 'R277', '00-00-01', 'PRESIDENT ST')
# Processing turnstile ('N192', 'R336', '00-00-01', 'BEACH 60 ST')
# Processing turnstile ('A033', 'R170', '02-06-00', '14 ST-UNION SQ')
# Processing turnstile ('C004', 'R089', '01-05-00', 'JAY ST-METROTEC')
# Processing turnstile ('R244', 'R050', '00-00-03', '59 ST')
# Processing turnstile ('N186', 'R418', '00-00-00', 'BEACH 105 ST')
# Processing turnstile ('R644', 'R135', '01-00-00', 'NEWKIRK AVE')
# Processing turnstile ('B022', 'R229', '00-00-00', 'AVE M')
# Processing turnstile ('N607', 'R025', '01-06-00', 'JAMAICA CENTER')
# Processing turnstile ('S102', 'R165', '00-05-01', 'TOMPKINSVILLE')
# Processing turnstile ('PTH16', 'R550', '01-01-04', 'LACKAWANNA')
# Processing turnstile ('A066', 'R118', '00-00-02', 'CANAL ST')
# Processing turnstile ('R201', 'R041', '00-00-01', 'BOWLING GREEN')
# Processing turnstile ('J023', 'R436', '00-00-00', 'NORWOOD AVE')
# Processing turnstile ('PTH07', 'R550', '00-00-08', 'CITY / BUS')
# Processing turnstile ('N094', 'R029', '01-00-01', 'WORLD TRADE CTR')
# Processing turnstile ('R117', 'R343', '00-00-01', 'FRANKLIN ST')
# Processing turnstile ('N605', 'R024', '00-00-04', 'SUTPHIN BLVD')
# Processing turnstile ('R134', 'R272', '01-06-00', '28 ST')
# Processing turnstile ('N536', 'R270', '00-05-01', 'SMITH-9 ST')
# Processing turnstile ('PTH13', 'R541', '00-04-06', 'THIRTY ST')
# Processing turnstile ('N314', 'R238', '01-00-02', 'STEINWAY ST')
# Processing turnstile ('R242A', 'R049', '02-03-00', '51 ST')
# Processing turnstile ('R122', 'R290', '02-06-01', 'HOUSTON ST')
# Processing turnstile ('R728', 'R226', '00-00-01', 'GUN HILL ROAD')
# Processing turnstile ('N184', 'R416', '00-05-00', 'BEACH 90 ST')
# Processing turnstile ('R240', 'R047', '00-03-00', '42 ST-GRD CNTRL')
# WARNING. Abnormal entry count found on day 2015-01-21: -11696489
# WARNING. Abnormal entry count found on day 2015-01-22: -2954
# Processing turnstile ('D011', 'R394', '01-06-00', 'BAY PKY-22 AVE')
# Processing turnstile ('A022', 'R022', '01-06-00', '34 ST-HERALD SQ')
# Processing turnstile ('N309A', 'R140', '00-03-01', 'QUEENS PLAZA')
# Processing turnstile ('C008', 'R099', '00-03-01', 'DEKALB AVE')
# Processing turnstile ('PTH03', 'R552', '00-00-04', 'JOURNAL SQUARE')
# Processing turnstile ('PTH20', 'R549', '03-01-07', 'NEWARK HM HE')
# Processing turnstile ('N304', 'R015', '01-01-01', '5 AVE-53 ST')
# Processing turnstile ('N535', 'R220', '00-03-01', 'CARROLL ST')
# Processing turnstile ('R330', 'R363', '00-00-01', 'BURKE AVE')
# Processing turnstile ('R532H', 'R328', '02-03-06', 'METS-WILLETS PT')
# Processing turnstile ('TRAM2', 'R469', '00-05-01', 'RIT-ROOSEVELT')
# Processing turnstile ('A054', 'R227', '01-03-01', 'RECTOR ST')
# Processing turnstile ('E011', 'R371', '00-00-00', '79 ST')
# Processing turnstile ('B026', 'R230', '00-05-00', 'NECK ROAD')
# Processing turnstile ('H001', 'R175', '00-00-05', '8 AVE')
# Processing turnstile ('A049', 'R088', '02-05-00', 'CORTLANDT ST')
# WARNING. Abnormal entry count found on day 2014-12-30: -1
# WARNING. Abnormal entry count found on day 2015-01-18: -1
# Processing turnstile ('S101A', 'R070', '01-00-05', 'ST. GEORGE')
# Processing turnstile ('N507', 'R023', '00-00-03', '34 ST-HERALD SQ')
# Processing turnstile ('A050', 'R088', '00-03-00', 'CORTLANDT ST')
# Processing turnstile ('R532', 'R328', '00-06-03', 'METS-WILLETS PT')
# Processing turnstile ('R515', 'R095', '00-00-02', 'DITMARS BL-31 S')
# Processing turnstile ('R527', 'R122', '00-00-00', '90 ST-ELMHURST')
# Processing turnstile ('H013', 'R249', '01-00-02', 'GRAHAM AVE')
# Processing turnstile ('R635', 'R277', '00-00-02', 'PRESIDENT ST')
# Processing turnstile ('R302', 'R324', '01-00-00', '116 ST')
# Processing turnstile ('C018', 'R197', '00-00-03', '36 ST')
# Processing turnstile ('K019', 'R413', '00-03-00', 'KNICKERBOCKER')
# Processing turnstile ('G009', 'R151', '02-00-04', 'STILLWELL AVE')
# Processing turnstile ('R530', 'R310', '00-00-03', '111 ST')
# Processing turnstile ('N135', 'R385', '01-05-01', 'ROCKAWAY BLVD')
# Processing turnstile ('E003', 'R369', '00-00-02', 'FT HAMILTON PKY')
# Processing turnstile ('R623', 'R061', '00-00-02', 'NOSTRAND AVE')
# Processing turnstile ('PTH11', 'R545', '00-04-00', '14TH STREET')
# Processing turnstile ('R534', 'R055', '01-00-02', 'MAIN ST')
# Processing turnstile ('A029', 'R082', '00-00-00', '28 ST-BROADWAY')
# Processing turnstile ('H009', 'R235', '00-03-02', 'BEDFORD AVE')
# Processing turnstile ('R507', 'R134', '00-00-00', 'HUNTERS PT AVE')
# Processing turnstile ('R231', 'R176', '00-00-03', '33 ST')
# Processing turnstile ('R168A', 'R168', '00-00-02', '96 ST')
# Processing turnstile ('R249', 'R179', '01-00-08', '86 ST')
# Processing turnstile ('A031', 'R083', '00-00-00', '23 ST-5 AVE')
# Processing turnstile ('PTH08', 'R540', '00-00-01', 'PATH WTC')
# Processing turnstile ('N408A', 'R256', '00-03-01', 'NASSAU AV')
# Processing turnstile ('R260', 'R205', '01-06-00', '149 ST-GR CONC')
# Processing turnstile ('R532', 'R328', '00-06-00', 'METS-WILLETS PT')
# Processing turnstile ('R310', 'R053', '01-05-00', '149 ST-3 AVE')
# Processing turnstile ('A002', 'R051', '02-03-02', 'LEXINGTON AVE')
# Processing turnstile ('R312', 'R405', '00-05-00', 'JACKSON AVE')
# Processing turnstile ('R172', 'R192', '00-00-02', '110 ST-CATHEDRL')
# Processing turnstile ('R515', 'R095', '00-03-00', 'DITMARS BL-31 S')
# Processing turnstile ('N011', 'R126', '01-06-01', '175 ST')
# Processing turnstile ('N528', 'R257', '01-05-00', 'EAST BROADWAY')
# Processing turnstile ('N130', 'R383', '01-06-00', 'HUDSON-80 ST')
# Processing turnstile ('R161A', 'R452', '01-06-00', '72 ST')
# Processing turnstile ('N546', 'R204', '00-00-01', 'CHURCH AVE')
# Processing turnstile ('R523', 'R147', '00-00-03', '61 ST/WOODSIDE')
# Processing turnstile ('N073', 'R013', '02-00-02', '34 ST-PENN STA')
# Processing turnstile ('PTH19', 'R549', '02-01-06', 'NEWARK C')
# Processing turnstile ('R125', 'R189', '00-00-00', 'CHRISTOPHER ST')
# Processing turnstile ('N114', 'R297', '01-00-01', 'FRANKLIN AVE')
# Processing turnstile ('N111', 'R284', '00-00-01', 'CLINTON-WASH AV')
# Processing turnstile ('J031', 'R006', '00-00-01', 'WOODHAVEN BLVD')
# Processing turnstile ('A055', 'R227', '00-00-01', 'RECTOR ST')
# Processing turnstile ('N400A', 'R359', '02-03-00', 'COURT SQ')
# Processing turnstile ('R135', 'R031', '01-00-05', '34 ST-PENN STA')
# Processing turnstile ('R155', 'R116', '01-00-08', '50 ST')
# Processing turnstile ('R221', 'R170', '01-05-01', '14 ST-UNION SQ')
# Processing turnstile ('R637', 'R451', '00-00-00', 'WINTHROP ST')
# ...
# WARNING. Abnormal entry count found on day 2015-01-17: -271540
# Processing turnstile ('E015', 'R399', '00-00-01', '25 AVE')
# Processing turnstile ('R228', 'R143', '00-00-03', '28 ST')
# Processing turnstile ('R138', 'R293', '00-03-02', '34 ST-PENN STA')
# Processing turnstile ('R310', 'R053', '01-00-04', '149 ST-3 AVE')
# Processing turnstile ('R534', 'R055', '01-03-05', 'MAIN ST')
# Processing turnstile ('R503', 'R276', '01-00-00', 'VERNON/JACKSON')
# Processing turnstile ('R161A', 'R452', '01-00-02', '72 ST')
# Processing turnstile ('N422', 'R318', '00-05-01', 'FULTON ST')
# Processing turnstile ('N315', 'R238', '00-00-00', 'STEINWAY ST')
# Processing turnstile ('N506', 'R022', '00-00-02', '34 ST-HERALD SQ')
# Processing turnstile ('N013', 'R035', '02-05-01', '168 ST-BROADWAY')
# Processing turnstile ('R625', 'R062', '01-06-01', 'CROWN HTS-UTICA')
# Processing turnstile ('C022', 'R212', '01-06-01', '59 ST')
# Processing turnstile ('C003', 'R089', '00-03-00', 'JAY ST-METROTEC')
# Processing turnstile ('N102', 'R127', '01-00-02', 'JAY ST-METROTEC')
# Processing turnstile ('R160A', 'R164', '00-05-01', '66 ST-LINCOLN')
# Processing turnstile ('N315', 'R238', '00-00-02', 'STEINWAY ST')
# Processing turnstile ('N020', 'R101', '00-00-00', '145 ST')
# Processing turnstile ('R169', 'R168', '01-07-00', '96 ST')
# Processing turnstile ('C008', 'R099', '00-00-03', 'DEKALB AVE')
# Processing turnstile ('A047', 'R087', '00-06-00', 'CITY HALL')
# WARNING. Abnormal entry count found on day 2015-01-17: 50103608
# Processing turnstile ('N506', 'R022', '00-03-01', '34 ST-HERALD SQ')
# Processing turnstile ('R257', 'R182', '01-03-00', '116 ST')
# Processing turnstile ('R145', 'R032', '00-00-02', '42 ST-TIMES SQ')
# Processing turnstile ('R621', 'R060', '00-03-01', 'EASTERN PKWY')
# Processing turnstile ('PTH11', 'R545', '00-04-03', '14TH STREET')
# Processing turnstile ('R509', 'R121', '00-00-04', 'QUEENSBORO PLZ')
# Processing turnstile ('H035', 'R348', '00-00-01', 'ATLANTIC AVE')
# Processing turnstile ('R413', 'R325', '00-00-01', 'WHITLOCK AVE')
# Processing turnstile ('N307', 'R359', '00-06-00', 'COURT SQ-23 ST')
# Processing turnstile ('N026', 'R102', '00-00-04', '125 ST')
# Processing turnstile ('N309A', 'R140', '00-06-02', 'QUEENS PLAZA')
# Processing turnstile ('N078', 'R175', '01-00-00', '14 ST')
# Processing turnstile ('R245A', 'R051', '01-06-01', '59 ST')
# Processing turnstile ('H009', 'R235', '00-03-00', 'BEDFORD AVE')
# Processing turnstile ('A049', 'R088', '02-03-01', 'CORTLANDT ST')
# Processing turnstile ('R323', 'R387', '00-06-01', 'E TREMONT AVE')
# Processing turnstile ('N187', 'R419', '00-05-01', 'ROCKAWAY PK 116')
# Processing turnstile ('N605', 'R024', '00-00-06', 'SUTPHIN BLVD')
# Processing turnstile ('R103', 'R304', '00-06-00', 'RECTOR ST')
# Processing turnstile ('R244', 'R050', '00-06-00', '59 ST')
# Processing turnstile ('R210', 'R044', '00-00-01', 'BROOKLYN BRIDGE')
# Processing turnstile ('E015', 'R399', '00-00-02', '25 AVE')
# Processing turnstile ('R111', 'R027', '00-00-00', 'WALL ST')
# Processing turnstile ('R210', 'R044', '00-05-01', 'BROOKLYN BRIDGE')
# Processing turnstile ('N123B', 'R439', '01-05-01', 'ROCKAWAY AVE')
# Processing turnstile ('E009', 'R370', '00-06-00', '71 ST')
# Processing turnstile ('PTH07', 'R550', '00-02-03', 'CITY / BUS')
# Processing turnstile ('R252', 'R180', '00-00-00', '103 ST')
# Processing turnstile ('N521', 'R300', '01-00-02', '2 AVE')
# Processing turnstile ('A046', 'R463', '00-03-00', 'CANAL ST')
# Processing turnstile ('S101A', 'R070', '01-03-02', 'ST. GEORGE')
# WARNING. Abnormal entry count found on day 2015-01-07: -537776
# Processing turnstile ('N340', 'R115', '00-06-01', '169 ST')
# Processing turnstile ('J024', 'R437', '00-00-02', 'CRESCENT ST')
# Processing turnstile ('R244A', 'R050', '01-06-01', '59 ST')
# Processing turnstile ('N128', 'R200', '00-05-00', 'EUCLID AVE')
# Processing turnstile ('N342', 'R019', '01-06-01', 'JAMAICA-179 ST')
# Processing turnstile ('R248', 'R178', '00-00-06', '77 ST')
# Processing turnstile ('N078', 'R175', '01-03-02', '14 ST')
# Processing turnstile ('C023', 'R213', '00-00-05', 'BAY RIDGE AVE')
# Processing turnstile ('N192', 'R336', '00-00-00', 'BEACH 60 ST')
# Processing turnstile ('A060', 'R001', '00-00-07', 'WHITEHALL ST')
# Processing turnstile ('S101A', 'R070', '01-00-06', 'ST. GEORGE')
# Processing turnstile ('R533', 'R055', '00-03-01', 'MAIN ST')
# Processing turnstile ('PTH11', 'R545', '00-00-04', '14TH STREET')
# Processing turnstile ('N026', 'R102', '00-00-03', '125 ST')
# Processing turnstile ('R336', 'R145', '00-00-00', 'WAKEFIELD-241')
# Processing turnstile ('N003', 'R185', '00-00-01', 'DYCKMAN-200 ST')
# Processing turnstile ('N060', 'R010', '01-00-00', '42 ST-PA BUS TE')
# Processing turnstile ('N531', 'R129', '01-00-01', 'BERGEN ST')
# Processing turnstile ('N203', 'R195', '00-00-01', '161 ST-YANKEE')
# Processing turnstile ('B004', 'R171', '00-00-01', '7 AVE')
# Processing turnstile ('R327', 'R361', '01-05-01', 'PELHAM PARKWAY')
# Processing turnstile ('N076', 'R111', '00-00-01', '23 ST')
# Processing turnstile ('R605', 'R456', '00-00-00', 'HOYT ST')
# Processing turnstile ('A021', 'R032', '01-00-03', '42 ST-TIMES SQ')
# Processing turnstile ('PTH19', 'R549', '02-01-01', 'NEWARK C')
# Processing turnstile ('B012', 'R196', '00-00-01', 'PROSPECT PARK')
# Processing turnstile ('R141', 'R031', '00-03-02', '34 ST-PENN STA')
# Processing turnstile ('J037', 'R009', '00-00-02', '121 ST')
# Processing turnstile ('N545', 'R204', '01-05-00', 'CHURCH AVE')
# Processing turnstile ('R169', 'R168', '01-00-05', '96 ST')
# Processing turnstile ('N010', 'R126', '00-03-02', '175 ST')
# Processing turnstile ('N098', 'R028', '00-02-01', 'FULTON ST')
# Processing turnstile ('C003', 'R089', '00-00-00', 'JAY ST-METROTEC')
# Processing turnstile ('C016', 'R278', '00-00-00', '25 ST')
# Processing turnstile ('R154', 'R116', '00-00-00', '50 ST')
# Processing turnstile ('R314', 'R406', '00-00-01', 'PROSPECT AVE')
# Processing turnstile ('N120', 'R153', '00-00-02', 'UTICA AVE')
# Processing turnstile ('N010', 'R126', '00-00-02', '175 ST')
# Processing turnstile ('N340', 'R115', '00-00-04', '169 ST')
# Processing turnstile ('PTH20', 'R549', '03-01-05', 'NEWARK HM HE')
# Processing turnstile ('N049', 'R084', '01-06-00', '59 ST-COLUMBUS')
# Processing turnstile ('N309A', 'R140', '00-06-01', 'QUEENS PLAZA')
# Processing turnstile ('PTH16', 'R550', '01-01-00', 'LACKAWANNA')
# Processing turnstile ('N184', 'R416', '00-00-00', 'BEACH 90 ST')
# Processing turnstile ('N043', 'R186', '00-00-02', '86 ST')
# Processing turnstile ('N040', 'R251', '00-00-01', '96 ST')
# Processing turnstile ('N001', 'R173', '01-06-01', 'INWOOD-207 ST')
# Processing turnstile ('N181', 'R357', '00-00-00', 'AQUEDUCT-N CNDT')
# Processing turnstile ('R506', 'R276', '02-06-01', 'VERNON/JACKSON')
# Processing turnstile ('PTH02', 'R544', '00-00-05', 'HARRISON')
# Processing turnstile ('R249', 'R179', '01-00-00', '86 ST')
# Processing turnstile ('H016', 'R250', '00-00-00', 'GRAND ST')
# Processing turnstile ('PTH13', 'R541', '00-00-00', 'THIRTY ST')
# Processing turnstile ('R415', 'R120', '00-00-00', 'MORRISON AVE')
# Processing turnstile ('R200A', 'R041', '01-00-06', 'BOWLING GREEN')
# Processing turnstile ('PTH01', 'R549', '00-00-01', 'NEWARK HW BMEBE')
# Processing turnstile ('N103', 'R127', '00-06-03', 'JAY ST-METROTEC')
# Processing turnstile ('PTH02', 'R544', '00-04-04', 'HARRISON')
# Processing turnstile ('A050', 'R088', '00-02-00', 'CORTLANDT ST')
# Processing turnstile ('R609', 'R056', '01-00-00', 'NEVINS ST')
# Processing turnstile ('R413', 'R325', '00-05-01', 'WHITLOCK AVE')
# Processing turnstile ('PTH02', 'R544', '00-00-03', 'HARRISON')
# Processing turnstile ('R644', 'R135', '01-06-00', 'NEWKIRK AVE')
# Processing turnstile ('R601A', 'R108', '02-00-05', 'BOROUGH HALL/CT')
# Processing turnstile ('R412', 'R146', '00-00-01', 'HUNTS POINT AVE')
# Processing turnstile ('H003', 'R163', '01-06-00', '6 AVE')
# Processing turnstile ('N306', 'R017', '00-03-02', 'LEXINGTON-53 ST')
# Processing turnstile ('C009', 'R057', '03-00-01', 'BARCLAYS CENTER')
# Processing turnstile ('B016', 'R098', '00-03-01', 'CHURCH AVE')
# Processing turnstile ('B015', 'R098', '01-00-02', 'CHURCH AVE')
# Processing turnstile ('N400A', 'R359', '02-00-00', 'COURT SQ')
# Processing turnstile ('N314', 'R238', '01-06-00', 'STEINWAY ST')
# Processing turnstile ('B026', 'R230', '00-06-00', 'NECK ROAD')
# Processing turnstile ('N123B', 'R439', '01-05-00', 'ROCKAWAY AVE')
# Processing turnstile ('N417', 'R269', '00-00-01', 'BEDFORD/NOSTRAN')
# Processing turnstile ('R322', 'R386', '00-00-02', '174 ST')
# WARNING. Abnormal entry count found on day 2014-12-28: -1
# WARNING. Abnormal entry count found on day 2014-12-29: -1
# WARNING. Abnormal entry count found on day 2014-12-31: -1
# WARNING. Abnormal entry count found on day 2015-01-02: -1
# WARNING. Abnormal entry count found on day 2015-01-12: -1
# WARNING. Abnormal entry count found on day 2015-01-14: -3
# WARNING. Abnormal entry count found on day 2015-01-15: -2
# WARNING. Abnormal entry count found on day 2015-01-16: -4
# WARNING. Abnormal entry count found on day 2015-01-17: -1
# WARNING. Abnormal entry count found on day 2015-01-18: -1
# WARNING. Abnormal entry count found on day 2015-01-20: -1
# WARNING. Abnormal entry count found on day 2015-01-21: -2
# WARNING. Abnormal entry count found on day 2015-01-22: -7
# WARNING. Abnormal entry count found on day 2015-01-23: -6
# Processing turnstile ('B019', 'R149', '00-00-01', 'NEWKIRK PLAZA')
# Processing turnstile ('R242', 'R049', '01-03-04', '51 ST')
# Processing turnstile ('N067', 'R012', '00-00-05', '34 ST-PENN STA')
# Processing turnstile ('R332', 'R365', '00-00-00', '219 ST')
# Processing turnstile ('S101', 'R070', '00-00-03', 'ST. GEORGE')
# Processing turnstile ('N418', 'R269', '01-06-01', 'BEDFORD/NOSTRAN')
# Processing turnstile ('R123', 'R290', '00-00-02', 'HOUSTON ST')
# Processing turnstile ('R133', 'R272', '00-00-03', '28 ST')
# Processing turnstile ('R217A', 'R194', '00-00-02', 'BLEECKER ST')
# Processing turnstile ('A077', 'R028', '03-03-02', 'FULTON ST')
# Processing turnstile ('N319', 'R298', '01-06-01', 'NORTHERN BLVD')
# Processing turnstile ('R304', 'R206', '00-00-01', '125 ST')
# Processing turnstile ('R258', 'R132', '00-00-00', '125 ST')
# Processing turnstile ('N051', 'R084', '02-03-03', '59 ST-COLUMBUS')
# Processing turnstile ('R532', 'R328', '00-05-04', 'METS-WILLETS PT')
# Processing turnstile ('TRAM1', 'R468', '00-00-00', 'RIT-MANHATTAN')
# Processing turnstile ('R205A', 'R014', '04-02-03', 'FULTON ST')
# WARNING. Abnormal entry count found on day 2015-01-22: 668490662
# Processing turnstile ('N501', 'R020', '01-00-03', '47-50 ST-ROCK')
# Processing turnstile ('N110', 'R283', '00-00-00', 'LAFAYETTE AVE')
# Processing turnstile ('N601', 'R319', '00-05-00', 'LEXINGTON AVE')
# Processing turnstile ('N531', 'R129', '01-00-00', 'BERGEN ST')
# Processing turnstile ('R318', 'R408', '00-05-00', 'SIMPSON ST')
# Processing turnstile ('A033', 'R170', '02-00-01', '14 ST-UNION SQ')
# Processing turnstile ('R330', 'R363', '00-00-00', 'BURKE AVE')
# Processing turnstile ('R316', 'R407', '00-00-02', 'INTERVALE-163')
# Processing turnstile ('K025', 'R404', '00-00-01', 'FRESH POND ROAD')
# Processing turnstile ('R228', 'R143', '00-00-00', '28 ST')
# Processing turnstile ('N335', 'R158', '01-00-02', 'UNION TPK-KEW G')
# Processing turnstile ('R630', 'R066', '00-00-01', 'JUNIUS ST')
# Processing turnstile ('R101', 'R001', '02-00-05', 'SOUTH FERRY')
# Processing turnstile ('PTH13', 'R541', '00-00-04', 'THIRTY ST')
# Processing turnstile ('R609', 'R056', '01-03-00', 'NEVINS ST')
# Processing turnstile ('R133', 'R272', '00-00-00', '28 ST')
# Processing turnstile ('N314', 'R238', '01-03-00', 'STEINWAY ST')
# Processing turnstile ('J037', 'R009', '00-06-00', '121 ST')
# Processing turnstile ('N220', 'R155', '01-00-00', 'KINGSBRIDGE RD')
# Processing turnstile ('N519', 'R461', '00-03-03', 'BROADWAY/LAFAY')
# Processing turnstile ('N062', 'R011', '01-03-04', '42 ST-PA BUS TE')
# Processing turnstile ('N117', 'R198', '01-00-02', 'NOSTRAND AVE')
# Processing turnstile ('N331', 'R219', '00-00-00', '67 AVE')
# Processing turnstile ('R242A', 'R049', '02-00-00', '51 ST')
# Processing turnstile ('N208', 'R443', '01-05-01', '170 ST')
# Processing turnstile ('R240', 'R047', '00-03-04', '42 ST-GRD CNTRL')
# Processing turnstile ('N045', 'R187', '01-00-02', '81 ST-MUSEUM')
# Processing turnstile ('A049', 'R088', '02-03-02', 'CORTLANDT ST')
# Processing turnstile ('R501', 'R054', '00-00-05', '5 AVE-BRYANT PK')
# Processing turnstile ('R201', 'R041', '00-06-02', 'BOWLING GREEN')
# Processing turnstile ('S101', 'R070', '00-00-08', 'ST. GEORGE')
# Processing turnstile ('C001', 'R108', '01-06-00', 'BOROUGH HALL/CT')
# Processing turnstile ('R220', 'R160', '01-03-00', 'ASTOR PLACE')
# Processing turnstile ('R310', 'R053', '01-00-01', '149 ST-3 AVE')
# Processing turnstile ('PTH11', 'R545', '00-00-00', '14TH STREET')
# Processing turnstile ('A015', 'R081', '00-03-00', '49 ST-7 AVE')
# Processing turnstile ('R612', 'R057', '01-00-03', 'BARCLAYS CENTER')
# Processing turnstile ('R258', 'R132', '00-03-01', '125 ST')
# Processing turnstile ('K022', 'R402', '00-00-00', 'SENECA AVE')
# Processing turnstile ('R325', 'R388', '00-05-01', 'E 180 ST')
# Processing turnstile ('R286', 'R309', '00-00-00', '176 ST')
# Processing turnstile ('R621', 'R060', '00-00-00', 'EASTERN PKWY')
# Processing turnstile ('JFK01', 'R535', '00-00-03', 'JFK HOWARD BCH')
# Processing turnstile ('R523', 'R147', '00-00-06', '61 ST/WOODSIDE')
# Processing turnstile ('PTH03', 'R552', '00-01-06', 'JOURNAL SQUARE')
# Processing turnstile ('N103', 'R127', '00-03-01', 'JAY ST-METROTEC')
# Processing turnstile ('R221', 'R170', '01-06-03', '14 ST-UNION SQ')
# Processing turnstile ('S101A', 'R070', '01-00-01', 'ST. GEORGE')
# Processing turnstile ('A061', 'R142', '00-03-02', 'ESSEX ST')
# Processing turnstile ('E012', 'R372', '00-00-01', '18 AVE')
# Processing turnstile ('R509', 'R121', '00-00-02', 'QUEENSBORO PLZ')
# Processing turnstile ('H026', 'R137', '00-03-02', 'MYRTLE AVE')
# Processing turnstile ('JFK02', 'R535', '01-00-06', 'JFK HOWARD BCH')
# Processing turnstile ('R507', 'R134', '00-03-03', 'HUNTERS PT AVE')
# Processing turnstile ('PTH05', 'R543', '00-01-05', 'EXCHANGE PLACE')
# Processing turnstile ('E012', 'R372', '00-00-00', '18 AVE')
# Processing turnstile ('R192', 'R039', '00-00-02', 'MARBLE HILL-225')
# Processing turnstile ('C027', 'R216', '00-00-00', 'BAY RIDGE-95 ST')
# Processing turnstile ('A060', 'R001', '00-00-04', 'WHITEHALL ST')
# Processing turnstile ('N091', 'R029', '02-05-02', 'CHAMBERS ST')
# Processing turnstile ('N511', 'R163', '03-00-02', '14 ST-6 AVE')
# Processing turnstile ('A046', 'R463', '00-06-07', 'CANAL ST')
# Processing turnstile ('N501', 'R020', '01-06-01', '47-50 ST-ROCK')
# Processing turnstile ('R245', 'R051', '00-03-03', '59 ST')
# Processing turnstile ('N139', 'R355', '00-00-02', 'GREENWOOD-111')
# Processing turnstile ('R216', 'R322', '01-00-00', 'SPRING ST')
# Processing turnstile ('N135', 'R385', '01-03-01', 'ROCKAWAY BLVD')
# Processing turnstile ('N546', 'R204', '00-00-04', 'CHURCH AVE')
# Processing turnstile ('N311', 'R339', '01-00-02', '36 ST')
# Processing turnstile ('N141', 'R356', '00-03-02', 'LEFFERTS BLVD')
# Processing turnstile ('N130', 'R383', '01-06-01', 'HUDSON-80 ST')
# Processing turnstile ('N124', 'R103', '00-03-00', 'BROADWAY-ENY')
# Processing turnstile ('R190', 'R038', '00-00-02', '215 ST')
# Processing turnstile ('J001', 'R460', '01-06-00', 'MARCY AVE')
# Processing turnstile ('N057', 'R188', '00-05-01', '50 ST')
# Processing turnstile ('R532', 'R328', '00-00-01', 'METS-WILLETS PT')
# Processing turnstile ('R412', 'R146', '00-03-01', 'HUNTS POINT AVE')
# Processing turnstile ('N195', 'R358', '00-00-01', 'BEACH 25 ST')
# Processing turnstile ('A002', 'R051', '02-05-00', 'LEXINGTON AVE')
# Processing turnstile ('N419', 'R287', '00-00-00', 'CLASSON AVE')
# Processing turnstile ('J030', 'R005', '00-00-03', 'FOREST PARKWAY')
# Processing turnstile ('E001', 'R368', '00-05-01', '9 AVE')
# Processing turnstile ('N415', 'R286', '00-00-00', 'MYRTLE-WILLOUGH')
# Processing turnstile ('PTH05', 'R543', '00-04-06', 'EXCHANGE PLACE')
# Processing turnstile ('R501', 'R054', '00-00-07', '5 AVE-BRYANT PK')

# %%
from datetime import datetime
from dateutil.parser import parse
from collections import defaultdict


def convert_week_data_to_time_series(week_data_dict):
    turnstile_to_time_series = defaultdict(list)
    for i, (turnstile, row_data) in enumerate(week_data_dict.items()):
        # report every 100 turnstiles
        if i%100 == 0:
            print('Processing turnstile', turnstile)
        for lines, division, datestr, timestr, event, cum_entries, cum_exits in row_data:
            timestamp = parse('%sT%s' % (datestr,timestr))
            turnstile_to_time_series[turnstile].append([timestamp, int(cum_entries)])
    return turnstile_to_time_series


# this takes a while
weekly_time_series = list(map(convert_week_data_to_time_series, weekly_data_dicts))
# Out:
# Processing turnstile ('R208', 'R014', '03-00-00', 'FULTON ST')
# Processing turnstile ('A011', 'R080', '01-00-03', '57 ST-7 AVE')
# Processing turnstile ('R230', 'R143', '02-05-00', '28 ST')
# Processing turnstile ('K025', 'R404', '00-03-02', 'FRESH POND ROAD')
# Processing turnstile ('N333B', 'R141', '02-01-01', 'FOREST HILLS-71')
# Processing turnstile ('N062A', 'R010', '00-00-00', '42 ST-PA BUS TE')
# Processing turnstile ('H015', 'R250', '01-00-02', 'GRAND ST')
# Processing turnstile ('R622', 'R123', '00-00-07', 'FRANKLIN AVE')
# Processing turnstile ('N049', 'R084', '01-03-03', '59 ST-COLUMBUS')
# Processing turnstile ('N500', 'R020', '00-00-02', '47-50 ST-ROCK')
# Processing turnstile ('N533', 'R129', '02-05-00', 'BERGEN ST')
# Processing turnstile ('S101A', 'R070', '01-05-01', 'ST. GEORGE')
# Processing turnstile ('R602', 'R108', '00-00-00', 'BOROUGH HALL/CT')
# Processing turnstile ('PTH12', 'R542', '00-00-04', 'TWENTY THIRD ST')
# Processing turnstile ('B016', 'R098', '00-00-01', 'CHURCH AVE')
# Processing turnstile ('R237', 'R046', '01-00-05', '42 ST-GRD CNTRL')
# Processing turnstile ('N546', 'R204', '00-00-03', 'CHURCH AVE')
# Processing turnstile ('R182', 'R035', '00-05-00', '168 ST-BROADWAY')
# Processing turnstile ('B031', 'R172', '01-06-03', 'BRIGHTON BEACH')
# Processing turnstile ('N060', 'R010', '01-05-01', '42 ST-PA BUS TE')
# Processing turnstile ('R601A', 'R108', '02-00-00', 'BOROUGH HALL/CT')
# Processing turnstile ('N504', 'R021', '02-00-00', '42 ST-BRYANT PK')
# Processing turnstile ('R332', 'R365', '00-00-02', '219 ST')
# Processing turnstile ('J001', 'R460', '01-05-00', 'MARCY AVE')
# Processing turnstile ('B026', 'R230', '00-00-00', 'NECK ROAD')
# Processing turnstile ('G001', 'R151', '00-06-00', 'STILLWELL AVE')
# Processing turnstile ('B031', 'R172', '01-00-02', 'BRIGHTON BEACH')
# Processing turnstile ('N002A', 'R173', '00-00-02', 'INWOOD-207 ST')
# Processing turnstile ('R166', 'R167', '02-00-02', '86 ST')
# Processing turnstile ('H009', 'R235', '00-00-00', 'BEDFORD AVE')
# Processing turnstile ('N010', 'R126', '00-00-04', '175 ST')
# Processing turnstile ('N400A', 'R359', '02-00-02', 'COURT SQ')
# Processing turnstile ('R145', 'R032', '00-00-04', '42 ST-TIMES SQ')
# Processing turnstile ('R162', 'R166', '00-00-03', '79 ST')
# Processing turnstile ('R114', 'R028', '02-00-01', 'FULTON ST')
# Processing turnstile ('B022', 'R229', '00-03-00', 'AVE M')
# Processing turnstile ('H026', 'R137', '00-05-01', 'MYRTLE AVE')
# Processing turnstile ('B013', 'R196', '01-05-00', 'PROSPECT PARK')
# Processing turnstile ('A060', 'R001', '00-00-03', 'WHITEHALL ST')
# Processing turnstile ('A050', 'R088', '00-03-02', 'CORTLANDT ST')
# Processing turnstile ('R626', 'R062', '00-00-01', 'CROWN HTS-UTICA')
# Processing turnstile ('R316', 'R407', '00-00-02', 'INTERVALE-163')
# Processing turnstile ('H014', 'R249', '00-00-01', 'GRAHAM AVE')
# Processing turnstile ('N049', 'R084', '01-03-02', '59 ST-COLUMBUS')
# Processing turnstile ('S101A', 'R070', '01-00-06', 'ST. GEORGE')
# Processing turnstile ('N208', 'R443', '01-05-01', '170 ST')
# Processing turnstile ('R208', 'R014', '03-00-00', 'FULTON ST')
# Processing turnstile ('A011', 'R080', '01-00-03', '57 ST-7 AVE')
# Processing turnstile ('R230', 'R143', '02-05-00', '28 ST')
# Processing turnstile ('K025', 'R404', '00-03-02', 'FRESH POND ROAD')
# Processing turnstile ('N333B', 'R141', '02-01-01', 'FOREST HILLS-71')
# Processing turnstile ('N062A', 'R010', '00-00-00', '42 ST-PA BUS TE')
# Processing turnstile ('H015', 'R250', '01-00-02', 'GRAND ST')
# Processing turnstile ('R622', 'R123', '00-00-07', 'FRANKLIN AVE')
# Processing turnstile ('N049', 'R084', '01-03-03', '59 ST-COLUMBUS')
# Processing turnstile ('N500', 'R020', '00-00-02', '47-50 ST-ROCK')
# Processing turnstile ('N533', 'R129', '02-05-00', 'BERGEN ST')
# Processing turnstile ('S101A', 'R070', '01-05-01', 'ST. GEORGE')
# Processing turnstile ('R602', 'R108', '00-00-00', 'BOROUGH HALL/CT')
# Processing turnstile ('PTH12', 'R542', '00-00-04', 'TWENTY THIRD ST')
# Processing turnstile ('B016', 'R098', '00-00-01', 'CHURCH AVE')
# Processing turnstile ('R237', 'R046', '01-00-05', '42 ST-GRD CNTRL')
# Processing turnstile ('N546', 'R204', '00-00-03', 'CHURCH AVE')
# Processing turnstile ('R182', 'R035', '00-05-00', '168 ST-BROADWAY')
# Processing turnstile ('B031', 'R172', '01-06-03', 'BRIGHTON BEACH')
# Processing turnstile ('N060', 'R010', '01-05-01', '42 ST-PA BUS TE')
# Processing turnstile ('R601A', 'R108', '02-00-00', 'BOROUGH HALL/CT')
# Processing turnstile ('N504', 'R021', '02-00-00', '42 ST-BRYANT PK')
# Processing turnstile ('R332', 'R365', '00-00-02', '219 ST')
# Processing turnstile ('J001', 'R460', '01-05-00', 'MARCY AVE')
# Processing turnstile ('B026', 'R230', '00-00-00', 'NECK ROAD')
# Processing turnstile ('G001', 'R151', '00-06-00', 'STILLWELL AVE')
# Processing turnstile ('B031', 'R172', '01-00-02', 'BRIGHTON BEACH')
# Processing turnstile ('N002A', 'R173', '00-00-02', 'INWOOD-207 ST')
# Processing turnstile ('R166', 'R167', '02-00-02', '86 ST')
# Processing turnstile ('H009', 'R235', '00-00-00', 'BEDFORD AVE')
# Processing turnstile ('N010', 'R126', '00-00-04', '175 ST')
# Processing turnstile ('N400A', 'R359', '02-00-02', 'COURT SQ')
# Processing turnstile ('R145', 'R032', '00-00-04', '42 ST-TIMES SQ')
# Processing turnstile ('R162', 'R166', '00-00-03', '79 ST')
# Processing turnstile ('R114', 'R028', '02-00-01', 'FULTON ST')
# Processing turnstile ('B022', 'R229', '00-03-00', 'AVE M')
# Processing turnstile ('H026', 'R137', '00-05-01', 'MYRTLE AVE')
# Processing turnstile ('B013', 'R196', '01-05-00', 'PROSPECT PARK')
# Processing turnstile ('A060', 'R001', '00-00-03', 'WHITEHALL ST')
# Processing turnstile ('N529', 'R257', '00-00-02', 'EAST BROADWAY')
# Processing turnstile ('N420B', 'R317', '00-06-00', 'CLINTON-WASH AV')
# Processing turnstile ('PTH10', 'R547', '00-00-02', '9TH STREET')
# Processing turnstile ('N304', 'R015', '01-06-00', '5 AVE-53 ST')
# Processing turnstile ('N057', 'R188', '00-00-00', '50 ST')
# Processing turnstile ('PTH17', 'R541', '01-01-01', 'THIRTY THIRD ST')
# Processing turnstile ('N600', 'R302', '00-03-00', '57 ST')
# Processing turnstile ('R208', 'R014', '03-00-00', 'FULTON ST')
# Processing turnstile ('A011', 'R080', '01-00-03', '57 ST-7 AVE')
# Processing turnstile ('R230', 'R143', '02-05-00', '28 ST')
# Processing turnstile ('K025', 'R404', '00-03-02', 'FRESH POND ROAD')
# Processing turnstile ('N333B', 'R141', '02-01-01', 'FOREST HILLS-71')
# Processing turnstile ('N062A', 'R010', '00-00-00', '42 ST-PA BUS TE')
# Processing turnstile ('H015', 'R250', '01-00-02', 'GRAND ST')
# Processing turnstile ('R622', 'R123', '00-00-07', 'FRANKLIN AVE')
# Processing turnstile ('N049', 'R084', '01-03-03', '59 ST-COLUMBUS')
# Processing turnstile ('N500', 'R020', '00-00-02', '47-50 ST-ROCK')
# Processing turnstile ('N533', 'R129', '02-05-00', 'BERGEN ST')
# Processing turnstile ('S101A', 'R070', '01-05-01', 'ST. GEORGE')
# Processing turnstile ('R602', 'R108', '00-00-00', 'BOROUGH HALL/CT')
# Processing turnstile ('PTH12', 'R542', '00-00-04', 'TWENTY THIRD ST')
# Processing turnstile ('B016', 'R098', '00-00-01', 'CHURCH AVE')
# Processing turnstile ('R237', 'R046', '01-00-05', '42 ST-GRD CNTRL')
# Processing turnstile ('N546', 'R204', '00-00-03', 'CHURCH AVE')
# Processing turnstile ('R182', 'R035', '00-05-00', '168 ST-BROADWAY')
# Processing turnstile ('B031', 'R172', '01-06-03', 'BRIGHTON BEACH')
# Processing turnstile ('N060', 'R010', '01-05-01', '42 ST-PA BUS TE')
# Processing turnstile ('R601A', 'R108', '02-00-00', 'BOROUGH HALL/CT')
# Processing turnstile ('N504', 'R021', '02-00-00', '42 ST-BRYANT PK')
# Processing turnstile ('R332', 'R365', '00-00-02', '219 ST')
# Processing turnstile ('J001', 'R460', '01-05-00', 'MARCY AVE')
# Processing turnstile ('B026', 'R230', '00-00-00', 'NECK ROAD')
# Processing turnstile ('G001', 'R151', '00-06-00', 'STILLWELL AVE')
# Processing turnstile ('B031', 'R172', '01-00-02', 'BRIGHTON BEACH')
# Processing turnstile ('N002A', 'R173', '00-00-02', 'INWOOD-207 ST')
# Processing turnstile ('R166', 'R167', '02-00-02', '86 ST')
# Processing turnstile ('H009', 'R235', '00-00-00', 'BEDFORD AVE')
# Processing turnstile ('N010', 'R126', '00-00-04', '175 ST')
# Processing turnstile ('N400A', 'R359', '02-00-02', 'COURT SQ')
# Processing turnstile ('R145', 'R032', '00-00-04', '42 ST-TIMES SQ')
# Processing turnstile ('N103', 'R127', '00-00-02', 'JAY ST-METROTEC')
# Processing turnstile ('R135', 'R031', '01-00-03', '34 ST-PENN STA')
# Processing turnstile ('N114', 'R297', '01-05-00', 'FRANKLIN AVE')
# Processing turnstile ('J001', 'R460', '01-05-01', 'MARCY AVE')
# Processing turnstile ('A010', 'R080', '00-00-02', '57 ST-7 AVE')
# Processing turnstile ('B020', 'R263', '00-06-01', 'AVE H')
# Processing turnstile ('N532', 'R129', '00-00-02', 'BERGEN ST')
# Processing turnstile ('N400A', 'R359', '02-03-01', 'COURT SQ')
# Processing turnstile ('N141', 'R356', '00-00-04', 'LEFFERTS BLVD')
# Processing turnstile ('R116', 'R030', '00-05-00', 'CHAMBERS ST')
# Processing turnstile ('N327', 'R254', '00-03-01', 'GRAND AV-NEWTON')
# Processing turnstile ('N420B', 'R317', '00-06-01', 'CLINTON-WASH AV')
# Processing turnstile ('A049', 'R088', '02-03-02', 'CORTLANDT ST')
# Processing turnstile ('R208', 'R014', '03-00-00', 'FULTON ST')
# Processing turnstile ('A011', 'R080', '01-00-03', '57 ST-7 AVE')
# Processing turnstile ('N110', 'R283', '00-03-01', 'LAFAYETTE AVE')
# Processing turnstile ('N029', 'R333', '01-00-02', '116 ST')
# Processing turnstile ('N057', 'R188', '00-05-00', '50 ST')
# Processing turnstile ('N502', 'R021', '01-00-03', '42 ST-BRYANT PK')
# Processing turnstile ('R610', 'R057', '00-03-05', 'BARCLAYS CENTER')
# Processing turnstile ('R288', 'R275', '00-00-00', '183 ST')
# Processing turnstile ('R304', 'R206', '00-00-00', '125 ST')
# Processing turnstile ('A025', 'R023', '01-00-01', '34 ST-HERALD SQ')
# Processing turnstile ('R208', 'R014', '03-00-02', 'FULTON ST')
# Processing turnstile ('N510', 'R163', '02-00-01', '14 ST-6 AVE')
# Processing turnstile ('G001', 'R151', '00-00-02', 'STILLWELL AVE')
# Processing turnstile ('R601A', 'R108', '02-00-01', 'BOROUGH HALL/CT')
# Processing turnstile ('R284', 'R243', '00-00-03', '170 ST')
# Processing turnstile ('PTH07', 'R550', '00-01-08', 'CITY / BUS')
# Processing turnstile ('B020', 'R263', '00-03-01', 'AVE H')
# Processing turnstile ('N542', 'R241', '00-06-00', '15 ST-PROSPECT')
# Processing turnstile ('N335', 'R158', '01-00-01', 'UNION TPK-KEW G')
# Processing turnstile ('C024', 'R214', '00-00-03', '77 ST')
# Processing turnstile ('R617', 'R058', '00-00-02', 'BERGEN ST')
# Processing turnstile ('N323', 'R018', '01-00-02', 'ROOSEVELT AVE')
# Processing turnstile ('N533', 'R129', '02-05-01', 'BERGEN ST')
# Processing turnstile ('G015', 'R312', '01-06-00', 'W 8 ST-AQUARIUM')
# Processing turnstile ('R245A', 'R051', '01-06-00', '59 ST')
# Processing turnstile ('A021', 'R032', '01-00-06', '42 ST-TIMES SQ')
# Processing turnstile ('J022', 'R435', '00-00-00', 'CLEVELAND ST')
# Processing turnstile ('N605', 'R024', '00-00-02', 'SUTPHIN BLVD')
# Processing turnstile ('PTH16', 'R550', '01-00-08', 'LACKAWANNA')
# Processing turnstile ('A049', 'R088', '02-05-00', 'CORTLANDT ST')
# Processing turnstile ('R114', 'R028', '02-00-02', 'FULTON ST')
# Processing turnstile ('N205', 'R195', '02-00-02', '161 ST-YANKEE')
# Processing turnstile ('N605', 'R024', '00-00-05', 'SUTPHIN BLVD')
# Processing turnstile ('C003', 'R089', '00-03-00', 'JAY ST-METROTEC')
# Processing turnstile ('S101A', 'R070', '01-00-02', 'ST. GEORGE')
# Processing turnstile ('H009', 'R235', '00-06-01', 'BEDFORD AVE')
# Processing turnstile ('H040', 'R376', '00-00-00', 'EAST 105 ST')
# Processing turnstile ('N039', 'R251', '01-06-00', '96 ST')
# Processing turnstile ('R159', 'R164', '01-00-00', '66 ST-LINCOLN')
# Processing turnstile ('N501A', 'R020', '02-03-02', '47-50 ST-ROCK')
# Processing turnstile ('H003', 'R163', '01-00-01', '6 AVE')
# Processing turnstile ('N336', 'R158', '00-00-01', 'UNION TPK-KEW G')
# Processing turnstile ('R608', 'R056', '00-00-00', 'NEVINS ST')
# Processing turnstile ('R251', 'R144', '00-03-02', '96 ST')
# Processing turnstile ('R115', 'R029', '00-06-00', 'PARK PLACE')
# Processing turnstile ('C001', 'R108', '01-06-00', 'BOROUGH HALL/CT')

# %%
# Checking the result
# just get 2 keys from the first dict to now overwhelm the output
sample_turnstile_to_time_series = list(weekly_time_series[0].items())[:2]
pprint(sample_turnstile_to_time_series)
# Out:
# [(('R208', 'R014', '03-00-00', 'FULTON ST'),
#   [[datetime.datetime(2014, 12, 27, 0, 0), 10282065],
#    [datetime.datetime(2014, 12, 27, 4, 0), 10282066],
#    [datetime.datetime(2014, 12, 27, 8, 0), 10282066],
#    [datetime.datetime(2014, 12, 27, 12, 0), 10282073],
#    [datetime.datetime(2014, 12, 27, 16, 0), 10282086],
#    [datetime.datetime(2014, 12, 27, 20, 0), 10282086],
#    [datetime.datetime(2014, 12, 28, 0, 0), 10282086],
#    [datetime.datetime(2014, 12, 28, 4, 0), 10282086],
#    [datetime.datetime(2014, 12, 28, 8, 0), 10282086],
#    [datetime.datetime(2014, 12, 28, 12, 0), 10282087],
#    [datetime.datetime(2014, 12, 28, 16, 0), 10282096],
#    [datetime.datetime(2014, 12, 28, 20, 0), 10282103],
#    [datetime.datetime(2014, 12, 29, 0, 0), 10282105],
#    [datetime.datetime(2014, 12, 29, 4, 0), 10282105],
#    [datetime.datetime(2014, 12, 29, 8, 0), 10282111],
#    [datetime.datetime(2014, 12, 29, 12, 0), 10282126],
#    [datetime.datetime(2014, 12, 29, 16, 0), 10282152],
#    [datetime.datetime(2014, 12, 29, 20, 0), 10282190],
#    [datetime.datetime(2014, 12, 30, 0, 0), 10282192],
#    [datetime.datetime(2014, 12, 30, 4, 0), 10282192],
#    [datetime.datetime(2014, 12, 30, 8, 0), 10282204],
#    [datetime.datetime(2014, 12, 30, 12, 0), 10282219],
#    [datetime.datetime(2014, 12, 30, 16, 0), 10282240],
#    [datetime.datetime(2014, 12, 30, 20, 0), 10282265],
#    [datetime.datetime(2014, 12, 31, 0, 0), 10282273],
#    [datetime.datetime(2014, 12, 31, 4, 0), 10282275],
#    [datetime.datetime(2014, 12, 31, 8, 0), 10282278],
#    [datetime.datetime(2014, 12, 31, 12, 0), 10282290],
#    [datetime.datetime(2014, 12, 31, 16, 0), 10282318],
#    [datetime.datetime(2014, 12, 31, 20, 0), 10282340],
#    [datetime.datetime(2015, 1, 1, 0, 0), 10282344],
#    [datetime.datetime(2015, 1, 1, 4, 0), 10282344],
#    [datetime.datetime(2015, 1, 1, 8, 0), 10282344],
#    [datetime.datetime(2015, 1, 1, 12, 0), 10282347],
#    [datetime.datetime(2015, 1, 1, 16, 0), 10282356],
#    [datetime.datetime(2015, 1, 1, 20, 0), 10282361],
#    [datetime.datetime(2015, 1, 2, 0, 0), 10282366],
#    [datetime.datetime(2015, 1, 2, 4, 0), 10282367],
#    [datetime.datetime(2015, 1, 2, 8, 0), 10282368],
#    [datetime.datetime(2015, 1, 2, 12, 0), 10282393],
#    [datetime.datetime(2015, 1, 2, 16, 0), 10282411],
#    [datetime.datetime(2015, 1, 2, 20, 0), 10282425]]),
#  (('N112A', 'R284', '01-00-01', 'CLINTON-WASH AV'),
#   [[datetime.datetime(2014, 12, 27, 3, 0), 307917],
#    [datetime.datetime(2014, 12, 27, 7, 0), 307924],
#    [datetime.datetime(2014, 12, 27, 11, 0), 307939],
#    [datetime.datetime(2014, 12, 27, 15, 0), 307964],
#    [datetime.datetime(2014, 12, 27, 19, 0), 308006],
#    [datetime.datetime(2014, 12, 27, 23, 0), 308032],
#    [datetime.datetime(2014, 12, 28, 3, 0), 308049],
#    [datetime.datetime(2014, 12, 28, 7, 0), 308055],
#    [datetime.datetime(2014, 12, 28, 11, 0), 308074],
#    [datetime.datetime(2014, 12, 28, 15, 0), 308105],
#    [datetime.datetime(2014, 12, 28, 19, 0), 308163],
#    [datetime.datetime(2014, 12, 28, 23, 0), 308195],
#    [datetime.datetime(2014, 12, 29, 3, 0), 308205],
#    [datetime.datetime(2014, 12, 29, 7, 0), 308215],
#    [datetime.datetime(2014, 12, 29, 11, 0), 308256],
#    [datetime.datetime(2014, 12, 29, 15, 0), 308299],
#    [datetime.datetime(2014, 12, 29, 19, 0), 308386],
#    [datetime.datetime(2014, 12, 29, 23, 0), 308427],
#    [datetime.datetime(2014, 12, 30, 3, 0), 308446],
#    [datetime.datetime(2014, 12, 30, 7, 0), 308454],
#    [datetime.datetime(2014, 12, 30, 11, 0), 308486],
#    [datetime.datetime(2014, 12, 30, 15, 0), 308537],
#    [datetime.datetime(2014, 12, 30, 19, 0), 308629],
#    [datetime.datetime(2014, 12, 30, 23, 0), 308693],
#    [datetime.datetime(2014, 12, 31, 3, 0), 308707],
#    [datetime.datetime(2014, 12, 31, 7, 0), 308718],
#    [datetime.datetime(2014, 12, 31, 11, 0), 308745],
#    [datetime.datetime(2014, 12, 31, 15, 0), 308792],
#    [datetime.datetime(2014, 12, 31, 19, 0), 308863],
#    [datetime.datetime(2014, 12, 31, 23, 0), 308934],
#    [datetime.datetime(2015, 1, 1, 3, 0), 308982],
#    [datetime.datetime(2015, 1, 1, 7, 0), 309003],
#    [datetime.datetime(2015, 1, 1, 11, 0), 309013],
#    [datetime.datetime(2015, 1, 1, 15, 0), 309052],
#    [datetime.datetime(2015, 1, 1, 19, 0), 309101],
#    [datetime.datetime(2015, 1, 1, 23, 0), 309134],
#    [datetime.datetime(2015, 1, 2, 3, 0), 309148],
#    [datetime.datetime(2015, 1, 2, 7, 0), 309157],
#    [datetime.datetime(2015, 1, 2, 11, 0), 309198],
#    [datetime.datetime(2015, 1, 2, 15, 0), 309244],
#    [datetime.datetime(2015, 1, 2, 19, 0), 309340],
#    [datetime.datetime(2015, 1, 2, 23, 0), 309386]])]

# %% [markdown]
# ## Challenge 3
# - These counts are cumulative every n hours. We want total daily entries.
#
# Now make it that we again have the same keys, but now we have a single value for a single day, which is not cumulative counts but the total number of passengers that entered through this turnstile on this day.

# %%
# Let's check
pprint( turnstile_to_daily_time_series[('N507', 'R023', '00-00-03', '34 ST-HERALD SQ')] )
# Out:
# [(datetime.date(2014, 12, 27), None),
#  (datetime.date(2014, 12, 28), 146),
#  (datetime.date(2014, 12, 29), 534),
#  (datetime.date(2014, 12, 30), 508),
#  (datetime.date(2014, 12, 31), 384),
#  (datetime.date(2015, 1, 1), 96),
#  (datetime.date(2015, 1, 2), 453),
#  (datetime.date(2015, 1, 3), 159),
#  (datetime.date(2015, 1, 4), 100),
#  (datetime.date(2015, 1, 5), 600),
#  (datetime.date(2015, 1, 6), 636),
#  (datetime.date(2015, 1, 7), 516),
#  (datetime.date(2015, 1, 8), 554),
#  (datetime.date(2015, 1, 9), 539),
#  (datetime.date(2015, 1, 10), 133),
#  (datetime.date(2015, 1, 11), 82),
#  (datetime.date(2015, 1, 12), 651),
#  (datetime.date(2015, 1, 13), 584),
#  (datetime.date(2015, 1, 14), 627),
#  (datetime.date(2015, 1, 15), 635),
#  (datetime.date(2015, 1, 16), 626),
#  (datetime.date(2015, 1, 17), 153),
#  (datetime.date(2015, 1, 18), 96),
#  (datetime.date(2015, 1, 19), 268),
#  (datetime.date(2015, 1, 20), 622),
#  (datetime.date(2015, 1, 21), 615),
#  (datetime.date(2015, 1, 22), 550),
#  (datetime.date(2015, 1, 23), 599)]

# %% [markdown]
# ## Challenge 4
# - We will plot the daily time series for a turnstile.
#
# In ipython notebook, add this to the beginning of your next cell:
#
#     %matplotlib inline
#
# This will make your matplotlib graphs integrate nicely with the notebook.
# To plot the time series, import matplotlib with
#
#     import matplotlib.pyplot as plt
#
# Take the list of [(date1, count1), (date2, count2), ...], for the turnstile and turn it into two lists:
# dates and counts. This should plot it:
#
#     plt.figure(figsize=(10,3))
#     plt.plot(dates,counts)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

time_series = turnstile_to_daily_time_series[('A030', 'R083', '01-06-00', '23 ST-5 AVE')]
days, counts = zip(*time_series)
plt.figure(figsize=(15,5))
plt.plot(days,counts)

# %% [markdown]
# ## Challenge 5
# - So far we've been operating on a single turnstile level, let's combine turnstiles in the same ControlArea/Unit/Station combo. There are some ControlArea/Unit/Station groups that have a single turnstile, but most have multiple turnstilea-- same value for the C/A, UNIT and STATION columns, different values for the SCP column.
#
# We want to combine the numbers together -- for each ControlArea/UNIT/STATION combo, for each day, add the counts from each turnstile belonging to that combo.

# %%
from collections import Counter

def booth_of_a_turnstile(turnstile):
    control_area, unit, device_id, station = turnstile
    return (control_area, unit, station)

def booth_of_a_time_series_item(item):
    turnstile, time_series = item
    return booth_of_a_turnstile(turnstile)

def reduce_turnstile_time_series_to_booths(turnstile_to_daily_time_series):
    turnstile_time_series_items = sorted(turnstile_to_daily_time_series.items())
    booth_to_time_series = {}
    for booth, item_list_of_booth in groupby(turnstile_time_series_items,
                                             key=booth_of_a_time_series_item):
        daily_counter = Counter()
        for turnstile, time_series in item_list_of_booth:
            for day, count in time_series:
                if count is not None:
                    daily_counter[day] += count
                
        booth_to_time_series[booth] = sorted(daily_counter.items())

    return booth_to_time_series


booth_to_daily_time_series = reduce_turnstile_time_series_to_booths(turnstile_to_daily_time_series)

# %%
#Check
pprint(booth_to_daily_time_series[('A030', 'R083', '23 ST-5 AVE')])
# Out:
# [(datetime.date(2014, 12, 28), 5699),
#  (datetime.date(2014, 12, 29), 11454),
#  (datetime.date(2014, 12, 30), 12366),
#  (datetime.date(2014, 12, 31), 9163),
#  (datetime.date(2015, 1, 1), 5328),
#  (datetime.date(2015, 1, 2), 9948),
#  (datetime.date(2015, 1, 3), 6352),
#  (datetime.date(2015, 1, 4), 4684),
#  (datetime.date(2015, 1, 5), 13969),
#  (datetime.date(2015, 1, 6), 14595),
#  (datetime.date(2015, 1, 7), 14890),
#  (datetime.date(2015, 1, 8), 14755),
#  (datetime.date(2015, 1, 9), 12964),
#  (datetime.date(2015, 1, 10), 7457),
#  (datetime.date(2015, 1, 11), 5837),
#  (datetime.date(2015, 1, 12), 13860),
#  (datetime.date(2015, 1, 13), 15652),
#  (datetime.date(2015, 1, 14), 15148),
#  (datetime.date(2015, 1, 15), 15046),
#  (datetime.date(2015, 1, 16), 14636),
#  (datetime.date(2015, 1, 17), 7466),
#  (datetime.date(2015, 1, 18), 4857),
#  (datetime.date(2015, 1, 19), 8360),
#  (datetime.date(2015, 1, 20), 14696),
#  (datetime.date(2015, 1, 21), 14990),
#  (datetime.date(2015, 1, 22), 14953),
#  (datetime.date(2015, 1, 23), 14462)]

# %% [markdown]
# ## Challenge 6
# - Similarly, combine everything in each station, and come up with a time series of `[(date1, count1),(date2,count2),...]` type of time series for each STATION, by adding up all the turnstiles in a station.

# %%
def station_of_a_booth(booth):
    control_area, unit, station = booth
    return station

def station_of_a_time_series_item(item):
    booth, time_series = item
    return station_of_a_booth(booth)

def reduce_booth_time_series_to_stations(booth_to_daily_time_series):
    booth_time_series_items = sorted(booth_to_daily_time_series.items())
    station_to_time_series = {}
    for station, item_list_of_station in groupby(booth_time_series_items,
                                             key=station_of_a_time_series_item):
        daily_counter = Counter()
        for turnstile, time_series in item_list_of_station:
            for day, count in time_series:
                daily_counter[day] += count
        station_to_time_series[station] = sorted(daily_counter.items())
    return station_to_time_series


station_to_daily_time_series = reduce_booth_time_series_to_stations(booth_to_daily_time_series)

# %%
pprint(station_to_daily_time_series['14 ST-UNION SQ'])
# Out:
# [(datetime.date(2014, 12, 28), 19688),
#  (datetime.date(2014, 12, 29), 29393),
#  (datetime.date(2014, 12, 30), 31698),
#  (datetime.date(2014, 12, 31), 31667),
#  (datetime.date(2015, 1, 1), 19605),
#  (datetime.date(2015, 1, 2), 28517),
#  (datetime.date(2015, 1, 3), 24845),
#  (datetime.date(2015, 1, 4), 19788),
#  (datetime.date(2015, 1, 5), 32550),
#  (datetime.date(2015, 1, 6), 32634),
#  (datetime.date(2015, 1, 7), 33368),
#  (datetime.date(2015, 1, 8), 31329),
#  (datetime.date(2015, 1, 9), 33572),
#  (datetime.date(2015, 1, 10), 26064),
#  (datetime.date(2015, 1, 11), 23052),
#  (datetime.date(2015, 1, 12), 31240),
#  (datetime.date(2015, 1, 13), 33766),
#  (datetime.date(2015, 1, 14), 34383),
#  (datetime.date(2015, 1, 15), 34816),
#  (datetime.date(2015, 1, 16), 36092),
#  (datetime.date(2015, 1, 17), 26819),
#  (datetime.date(2015, 1, 18), 19765),
#  (datetime.date(2015, 1, 19), 23975),
#  (datetime.date(2015, 1, 20), 33618),
#  (datetime.date(2015, 1, 21), 35152),
#  (datetime.date(2015, 1, 22), 35067),
#  (datetime.date(2015, 1, 23), 36959)]

# %% [markdown]
# ## Challenge 7
# - Plot the time series for a station

# %%
def plot_station_time_series(station_name, station_to_daily_time_series):
    time_series = station_to_daily_time_series[station_name]
    days, counts = zip(*time_series)
    plt.figure(figsize=(15,5))
    plt.plot(days,counts)
    plt.xlabel('Date')
    plt.ylabel('Number of turnstile entries')
    plt.title('Daily entries for station %s' % station_name)
    
plot_station_time_series('14 ST-UNION SQ', station_to_daily_time_series)

# %% [markdown]
# ## Challenge 8
# - Make one list of counts for **one** week for one station. Monday's count, Tuesday's count, etc. so it's a list of 7 counts.
# Make the same list for another week, and another week, and another week.
# `plt.plot(week_count_list)` for every `week_count_list` you created this way. You should get a rainbow plot of weekly commute numbers on top of each other.

# %%
import numpy as np

def separate_weeks(time_series):
    time_series_for_each_week = []
    week = []
    for i, (day, count) in enumerate(time_series):
        week.append( (day,count) )
        # every 7 days, start a new week
        # (do this on the last day of the current week)
        if i%7 == 6:
            time_series_for_each_week.append(week)
            week = []
    # at the end of the for loop, if there are some left
    # over, put this partial week as the last (partial) week
    time_series_for_each_week.append(week)
    return time_series_for_each_week


def rainbow_plot_for_station(station_name, station_to_daily_time_series):
    time_series = station_to_daily_time_series[station_name]
    time_series_for_each_week = separate_weeks(time_series)
    plt.figure(figsize=(15,5))
    for week in time_series_for_each_week:
        days, counts = zip(*week)
        days = range(len(counts))
        plt.plot(days,counts)
    plt.xlabel('Day of the week')
    plt.ylabel('Number of turnstile entries')
    plt.xticks(np.arange(7),['St','Sn','Mo','Tu','We','Th','Fr'])
    plt.title('Ridership per day for station %s'%station_name)
    
    
rainbow_plot_for_station('14 ST-UNION SQ', station_to_daily_time_series)

# %% [markdown]
# ## Challenge 9
# - Over multiple weeks, sum total ridership for each station and sort them, so you can find out the stations with the highest traffic during the time you investigate

# %%
def total_traffic(time_series):
    return sum([count for day,count in time_series])

def station_time_series_item_to_station_total_traffic(item):
    station, time_series = item
    return total_traffic(time_series), station

traffic_report = list(map(station_time_series_item_to_station_total_traffic,
                 station_to_daily_time_series.items()))

for tot_traffic, station in sorted(traffic_report, reverse=True)[:30]:
    print('%-18s %s' % (station, tot_traffic))
# Out:
# 42 ST-GRD CNTRL    3191992
# 42 ST-PA BUS TE    2396771
# 34 ST-PENN STA     2016352
# 42 ST-TIMES SQ     1906670
# 34 ST-HERALD SQ    1670192
# 86 ST              1453363
# 47-50 ST-ROCK      1347132
# MAIN ST            1197571
# ROOSEVELT AVE      1105137
# 59 ST              1098360
# LEXINGTON-53 ST    954511
# 72 ST              940759
# W 4 ST-WASH SQ     907010
# JAMAICA CENTER     866463
# PATH WTC           862301
# 42 ST-BRYANT PK    825354
# 14 ST-UNION SQ     799422
# 77 ST              794806
# BOROUGH HALL/CT    721704
# BARCLAYS CENTER    712839
# JAY ST-METROTEC    708005
# 33 ST              674216
# 68ST-HUNTER COL    639785
# BEDFORD AVE        635539
# 57 ST-7 AVE        629000
# BOWLING GREEN      625178
# CROWN HTS-UTICA    611196
# FOREST HILLS-71    606484
# UNION TPK-KEW G    596326
# 49 ST-7 AVE        581121

# %%
stations = []
entries = []

for tot_traffic, station in sorted(traffic_report, reverse=True)[:30]:
    stations.append(station)
    entries.append(tot_traffic)

plt.bar(stations, entries)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-b53deb3c24a0> in <module>()
#       6     entries.append(tot_traffic)
#       7
# ----> 8 plt.bar(stations, entries)
#
# /Users/osx10/anaconda/lib/python3.5/site-packages/matplotlib/pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2648     try:
#    2649         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2650                      **kwargs)
#    2651     finally:
#    2652         ax.hold(washold)
#
# /Users/osx10/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /Users/osx10/anaconda/lib/python3.5/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2085                 edgecolor=e,
#    2086                 linewidth=lw,
# -> 2087                 label='_nolegend_'
#    2088                 )
#    2089             r.update(kwargs)
#
# /Users/osx10/anaconda/lib/python3.5/site-packages/matplotlib/patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     638         Patch.__init__(self, **kwargs)
#     639
# --> 640         self._x = float(xy[0])
#     641         self._y = float(xy[1])
#     642         self._width = float(width)
#
# ValueError: could not convert string to float: '42 ST-GRD CNTRL'

# %% [markdown]
# ## Challenge 10
# - Make a single list of these total ridership values and plot it with `plt.hist(total_ridership_counts)` to get an idea about the distribution of total ridership among different stations.
# This should show you that most stations have a small traffic, and the histogram bins for large traffic volumes have small bars.
#
# *Additional Hint*:
# If you want to see which stations take the meat of the traffic, you can sort the total ridership counts and make a `plt.bar` graph. For this, you want to have two lists: the indices of each bar, and the values. The indices can just be `0,1,2,3,...`, so you can do
#
#     indices = range(len(total_ridership_values))
#     plt.bar(indices, total_ridership_values)

# %%
total_ridership_counts = [ridership for ridership, station in traffic_report]
plt.figure(figsize=(15,5))
hist = plt.hist(total_ridership_counts, bins=20)

# %% [markdown]
# Well, ok, the majority of the stations fall into the first bins with lower counts.
# We can't see a lot of detail.
# To get a better understanding, let's look at the histogram of log counts.

# %%
import math
log_counts = [math.log10(count) for count in total_ridership_counts]
plt.figure(figsize=(15,5))
n,bins,patches = hist = plt.hist(log_counts, bins=15)

# Labels for the logarithmic x axis
def log_count_to_label(log_count):
    if log_count <= 6:
        return '%.0f Thousand' % 10**(log_count-3)
    else:
        return '%.1f Million' % 10**(log_count-6)
    
tick_labels = map(log_count_to_label, bins)
ticks = plt.xticks(bins, tick_labels, rotation=70)
plt.xlabel("Total ridership count")
plt.ylabel("Number of stations with this total count")
plt.title("Distribution of ridership among\n"
          "NYC subway stations between\n"
          "Jan 3 to Jan 24, 2015")

# %% [markdown]
# If you switch the y axis to logarithmic as well, you can see even more detail, but you lose some readability.
# You can do this by setting
#
#     log=True
#
# in the `plt.hist()` call. Below I copy paste the same code with only this difference

# %%
log_counts = [math.log10(count) for count in total_ridership_counts]
plt.figure(figsize=(15,5))
n,bins,patches = hist = plt.hist(log_counts, log=True, bins = 12)
tick_labels = map(log_count_to_label, bins)
ticks = plt.xticks(bins, tick_labels, rotation=70)
plt.xlabel("Total ridership count")
plt.ylabel("Number of stations with this total count")
plt.title("Distribution of ridership among\n"
          "NYC subway stations between\n"
          "Jan 3 to Jan 24, 2015")

# %% [markdown]
# This really does not add much. But if one of the peaks dominated and you couldn't see the other peaks, using a log scale for the y axis would have helped.
#
# And finally, the bar graph mentioned in the _Additional Hint_ for the top 30 stations

# %%
top_stations = sorted(traffic_report, reverse=True)[:30]
counts, stations = zip(*top_stations)
indices = range(len(counts))
plt.figure(figsize=(15,5))
plt.bar(indices, counts)
ticks = plt.xticks(indices, stations, rotation=70)

# %%
top_stations = sorted(traffic_report, reverse=True)[:15]
counts, stations = zip(*top_stations)
indices = range(len(counts))
plt.figure(figsize=(15,5))
plt.bar(indices, counts)
ticks = plt.xticks(indices, stations, rotation=70)

# %%
import seaborn as sns

sns.factorplot('stat_line', 'traffic', data = df2, kind = 'bar', aspect = 2)
