# %% [markdown]
# ### Exploratory Data Analysis with Python
#
# We will explore the NYC MTA turnstile data set. These data files are from the New York Subway. It tracks the hourly entries and exits to turnstiles (UNIT) by day in the subway system.
#
# Here is an [example of what you could do with the data](https://jameskao.me/analyzing-the-nyc-subway-dataset/). James Kao investigates how subway ridership is affected by incidence of rain.

# %% [markdown]
# ## Exercise 1
#
# - Download a few [MTA turnstile data files](http://web.mta.info/developers/turnstile.html)
# - Open up a file, use csv reader to read it, make a python dict where there is a key for each (C/A, UNIT, SCP, STATION). These are the first four columns. The value for this key should be a list of lists. Each list in the list is the rest of the columns in a row. For example, one key-value pair should look like
#
#
#         {    ('A002','R051','02-00-00','LEXINGTON AVE'):
#              [
#                ['NQR456', 'BMT', '01/03/2015', '03:00:00', 'REGULAR', '0004945474', '0001675324'],
#                  ['NQR456', 'BMT', '01/03/2015', '07:00:00', 'REGULAR', '0004945478', '0001675333'],
#                 ['NQR456', 'BMT', '01/03/2015', '11:00:00', 'REGULAR', '0004945515', '0001675364'],
#               ...
#          ]
#         }

# %%
import wget

url_template = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_%s.txt'
for date in ['161231', '161224', '161217', '161210']:
    url = url_template % date
    wget.download(url)
    print(date, 'file downloaded')
# Out:
# 161231 file downloaded
# 161224 file downloaded
# 161217 file downloaded
# 161210 file downloaded

# %%
import csv, glob
from collections import defaultdict

def read_csv(csv_file_name):
    turnstile_to_count_reading = defaultdict(list)
    with open(csv_file_name, 'r') as csv_file:
        mta_reader = csv.reader(csv_file)
        for i, row in enumerate(mta_reader):
            if i == 0:
                continue
            
            turnstile_info = tuple(row[:4])
            count_reading = row[4:]
            turnstile_to_count_reading[turnstile_info].append(count_reading)
    
    return turnstile_to_count_reading

# %%
weekly_data_dicts = [read_csv(csvfile) for csvfile in glob.glob('turnstile_*.txt')]

# %%
sample_dict = list(weekly_data_dicts[0].items())[:2]

# %%
print(sample_dict)
# Out:
# [(('A049', 'R088', '02-00-00', 'CORTLANDT ST'), [['RNW', 'BMT', '12/03/2016', '00:00:00', 'REGULAR', '0000237904', '0000154264                                         '], ['RNW', 'BMT', '12/03/2016', '04:00:00', 'REGULAR', '0000237904', '0000154264                                         '], ['RNW', 'BMT', '12/03/2016', '08:00:00', 'REGULAR', '0000237904', '0000154264                                         '], ['RNW', 'BMT', '12/03/2016', '12:00:00', 'REGULAR', '0000237904', '0000154264                                         '], ['RNW', 'BMT', '12/03/2016', '16:00:00', 'REGULAR', '0000237904', '0000154264                                         '], ['RNW', 'BMT', '12/03/2016', '20:00:00', 'REGULAR', '0000237904', '0000154265                                         '], ['RNW', 'BMT', '12/04/2016', '00:00:00', 'REGULAR', '0000237904', '0000154265                                         '], ['RNW', 'BMT', '12/04/2016', '04:00:00', 'REGULAR', '0000237904', '0000154265                                         '], ['RNW', 'BMT', '12/04/2016', '08:00:00', 'REGULAR', '0000237904', '0000154265                                         '], ['RNW', 'BMT', '12/04/2016', '12:00:00', 'REGULAR', '0000237904', '0000154265                                         '], ['RNW', 'BMT', '12/04/2016', '16:00:00', 'REGULAR', '0000237904', '0000154265                                         '], ['RNW', 'BMT', '12/04/2016', '20:00:00', 'REGULAR', '0000237904', '0000154265                                         '], ['RNW', 'BMT', '12/05/2016', '00:00:00', 'REGULAR', '0000237904', '0000154265                                         '], ['RNW', 'BMT', '12/05/2016', '04:00:00', 'REGULAR', '0000237904', '0000154265                                         '], ['RNW', 'BMT', '12/05/2016', '08:00:00', 'REGULAR', '0000237919', '0000154346                                         '], ['RNW', 'BMT', '12/05/2016', '12:00:00', 'REGULAR', '0000238011', '0000154699                                         '], ['RNW', 'BMT', '12/05/2016', '16:00:00', 'REGULAR', '0000238205', '0000154782                                         '], ['RNW', 'BMT', '12/05/2016', '20:00:00', 'REGULAR', '0000238419', '0000155099                                         '], ['RNW', 'BMT', '12/06/2016', '00:00:00', 'REGULAR', '0000238472', '0000155161                                         '], ['RNW', 'BMT', '12/06/2016', '04:00:00', 'REGULAR', '0000238473', '0000155165                                         '], ['RNW', 'BMT', '12/06/2016', '08:00:00', 'REGULAR', '0000238487', '0000155312                                         '], ['RNW', 'BMT', '12/06/2016', '12:00:00', 'REGULAR', '0000238577', '0000155680                                         '], ['RNW', 'BMT', '12/06/2016', '16:00:00', 'REGULAR', '0000238720', '0000155740                                         '], ['RNW', 'BMT', '12/06/2016', '20:00:00', 'REGULAR', '0000238962', '0000156092                                         '], ['RNW', 'BMT', '12/07/2016', '00:00:00', 'REGULAR', '0000238988', '0000156155                                         '], ['RNW', 'BMT', '12/07/2016', '04:00:00', 'REGULAR', '0000238988', '0000156155                                         '], ['RNW', 'BMT', '12/07/2016', '08:00:00', 'REGULAR', '0000239001', '0000156298                                         '], ['RNW', 'BMT', '12/07/2016', '12:00:00', 'REGULAR', '0000239103', '0000156615                                         '], ['RNW', 'BMT', '12/07/2016', '16:00:00', 'REGULAR', '0000239252', '0000156691                                         '], ['RNW', 'BMT', '12/07/2016', '20:00:00', 'REGULAR', '0000239474', '0000157000                                         '], ['RNW', 'BMT', '12/08/2016', '00:00:00', 'REGULAR', '0000239523', '0000157059                                         '], ['RNW', 'BMT', '12/08/2016', '04:00:00', 'REGULAR', '0000239523', '0000157060                                         '], ['RNW', 'BMT', '12/08/2016', '08:00:00', 'REGUL ...

# %%
from pprint import pprint
pprint(sample_dict)
# Out:
# [(('A049', 'R088', '02-00-00', 'CORTLANDT ST'),
#   [['RNW',
#     'BMT',
#     '12/03/2016',
#     '00:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154264                                         '],
#    ['RNW',
#     'BMT',
#     '12/03/2016',
#     '04:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154264                                         '],
#    ['RNW',
#     'BMT',
#     '12/03/2016',
#     '08:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154264                                         '],
#    ['RNW',
#     'BMT',
#     '12/03/2016',
#     '12:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154264                                         '],
#    ['RNW',
#     'BMT',
#     '12/03/2016',
#     '16:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154264                                         '],
#    ['RNW',
#     'BMT',
#     '12/03/2016',
#     '20:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154265                                         '],
#    ['RNW',
#     'BMT',
#     '12/04/2016',
#     '00:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154265                                         '],
#    ['RNW',
#     'BMT',
#     '12/04/2016',
#     '04:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154265                                         '],
#    ['RNW',
#     'BMT',
#     '12/04/2016',
#     '08:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154265                                         '],
#    ['RNW',
#     'BMT',
#     '12/04/2016',
#     '12:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154265                                         '],
#    ['RNW',
#     'BMT',
#     '12/04/2016',
#     '16:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154265                                         '],
#    ['RNW',
#     'BMT',
#     '12/04/2016',
#     '20:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154265                                         '],
#    ['RNW',
#     'BMT',
#     '12/05/2016',
#     '00:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154265                                         '],
#    ['RNW',
#     'BMT',
#     '12/05/2016',
#     '04:00:00',
#     'REGULAR',
#     '0000237904',
#     '0000154265                                         '],
#    ['RNW',
#     'BMT',
#     '12/05/2016',
#     '08:00:00',
#     'REGULAR',
#     '0000237919',
#     '0000154346                                         '],
#    ['RNW',
#     'BMT',
#     '12/05/2016',
#     '12:00:00',
#     'REGULAR',
#     '0000238011',
#     '0000154699                                         '],
#    ['RNW',
#     'BMT',
#     '12/05/2016',
#     '16:00:00',
#     'REGULAR',
#     '0000238205',
#     '0000154782                                         '],
#    ['RNW',
#     'BMT',
#     '12/05/2016',
#     '20:00:00',
#     'REGULAR',
#     '0000238419',
#     '0000155099                                         '],
#    ['RNW',
#     'BMT',
#     '12/06/2016',
#     '00:00:00',
#     'REGULAR',
#     '0000238472',
#     '0000155161                                         '],
#    ['RNW',
#     'BMT',
#     '12/06/2016',
#     '04:00:00',
#     'REGULAR',
#     '0000238473',
#     '0000155165                                         '],
#    ['RNW',
#     'BMT',
#     '12/06/2016',
#     '08:00:00',
#     'REGULAR',
#     '0000238487',
#     '0000155312                                         '],
#    ['RNW',
#     'BMT',
#     '12/06/2016',
#     '12:00:00',
#     'REGULAR',
#     '0000238577',
#     '0000155680                                         '],
#    ['RNW',
#     'BMT',
#     '12/06/2016',
#     '16:00:00',
#     'REGULAR',
#     '0000238720',
#     '0000155740                                         '],
#    ['RNW',
#     'BMT',
#     '12/06/2016',
#     '20:00:00',
#     'REGULAR',
#     '0000238962',
#     '0000156092                                         '],
#    ['RNW',
#     'BMT',
#     '12/07/2016',
#     '00:00:00',
#     'REGULAR',
#     '0000238988',
#     '0000156155                                         '],
#    ['RNW',
#     'BMT',
#     '12/07/2016',
#     '04:00:00',
#     'REGULAR',
#     '0000238988',
#     '0000156155                                         '],
#    ['RNW',
#     'BMT',
#     '12/07/2016',
#     '08:00:00',
#     'REGULAR',
#     '0000239001',
#     '0000156298                                         '],
#    ['RNW',
#     'BMT',
#     '12/07/2016',
#     '12:00:00',
#     'REGULAR',
#     '0000239103',
#     '0000156615                                         '],
#    ['RNW',
#     'BMT',
#     '12/07/2016',
#     '16:00:00',
#     'REGULAR',
#     '0000239252',
#     '0000156691                                         '],
#    ['RNW',
#     'BMT',
#     '12/07/2016',
#     '20:00:00',
#     'REGULAR',
#     '0000239474',
#     '0000157000                                         '],
#    ['RNW',
#     'BMT',
#     '12/08/2016',
#     '00:00:00',
#     'REGULAR',
#     '0000239523',
#     '0000157059                                         '],
#    ['RNW',
#     'BMT',
#     '12/08/2016',
#     '04:00:00',
#     'REGULAR',
#     '0000239523',
#     '0000157060                                         '],
#    ['RNW',
#     'BMT',
#     '12/08/2016',
#     '08:00:00',
#     'REGULAR',
#     '0000239538',
#     '0000157168                                         '],
#    ['RNW',
#     'BMT',
#     '12/08/2016',
#     '12:00:00',
#     'REGULAR',
#     '0000239635',
#     '0000157546                                         '],
#    ['RNW',
#     'BMT',
#     '12/08/2016',
#     '16:00:00',
#     'REGULAR',
#     '0000239806',
#     '0000157640                                         '],
#    ['RNW',
#     'BMT',
#     '12/08/2016',
#     '20:00:00',
#     'REGULAR',
#     '0000240041',
#     '0000157955                                         '],
#    ['RNW',
#     'BMT',
#     '12/09/2016',
#     '00:00:00',
#     'REGULAR',
#     '0000240091',
#     '0000158016                                         '],
#    ['RNW',
#     'BMT',
#     '12/09/2016',
#     '04:00:00',
#     'REGULAR',
#     '0000240091',
#     '0000158019                                         '],
#    ['RNW',
#     'BMT',
#     '12/09/2016',
#     '08:00:00',
#     'REGULAR',
#     '0000240102',
#     '0000158142                                         '],
#    ['RNW',
#     'BMT',
#     '12/09/2016',
#     '12:00:00',
#     'REGULAR',
#     '0000240198',
#     '0000158498                                         '],
#    ['RNW',
#     'BMT',
#     '12/09/2016',
#     '16:00:00',
#     'REGULAR',
#     '0000240484',
#     '0000158626                                         '],
#    ['RNW',
#     'BMT',
#     '12/09/2016',
#     '20:00:00',
#     'REGULAR',
#     '0000240838',
#     '0000158966                                         ']]),
#  (('N309A', 'R140', '00-00-02', 'QUEENS PLAZA'),
#   [['EMR',
#     'IND',
#     '12/03/2016',
#     '00:00:00',
#     'REGULAR',
#     '0002457263',
#     '0001485816                                        '],
#    ['EMR',
#     'IND',
#     '12/03/2016',
#     '04:00:00',
#     'REGULAR',
#     '0002457276',
#     '0001485841                                        '],
#    ['EMR',
#     'IND',
#     '12/03/2016',
#     '08:00:00',
#     'REGULAR',
#     '0002457297',
#     '0001485865                                        '],
#    ['EMR',
#     'IND',
#     '12/03/2016',
#     '12:00:00',
#     'REGULAR',
#     '0002457358',
#     '0001485919                                        '],
#    ['EMR',
#     'IND',
#     '12/03/2016',
#     '16:00:00',
#     'REGULAR',
#     '0002457438',
#     '0001485981                                        '],
#    ['EMR',
#     'IND',
#     '12/03/2016',
#     '20:00:00',
#     'REGULAR',
#     '0002457531',
#     '0001486152                                        '],
#    ['EMR',
#     'IND',
#     '12/04/2016',
#     '00:00:00',
#     'REGULAR',
#     '0002457548',
#     '0001486229                                        '],
#    ['EMR',
#     'IND',
#     '12/04/2016',
#     '04:00:00',
#     'REGULAR',
#     '0002457554',
#     '0001486246                                        '],
#    ['EMR',
#     'IND',
#     '12/04/2016',
#     '08:00:00',
#     'REGULAR',
#     '0002457577',
#     '0001486262                                        '],
#    ['EMR',
#     'IND',
#     '12/04/2016',
#     '12:00:00',
#     'REGULAR',
#     '0002457650',
#     '0001486297                                        '],
#    ['EMR',
#     'IND',
#     '12/04/2016',
#     '16:00:00',
#     'REGULAR',
#     '0002457716',
#     '0001486378                                        '],
#    ['EMR',
#     'IND',
#     '12/04/2016',
#     '20:00:00',
#     'REGULAR',
#     '0002457760',
#     '0001486469                                        '],
#    ['EMR',
#     'IND',
#     '12/05/2016',
#     '00:00:00',
#     'REGULAR',
#     '0002457778',
#     '0001486534                                        '],
#    ['EMR',
#     'IND',
#     '12/05/2016',
#     '04:00:00',
#     'REGULAR',
#     '0002457781',
#     '0001486544                                        '],
#    ['EMR',
#     'IND',
#     '12/05/2016',
#     '08:00:00',
#     'REGULAR',
#     '0002457802',
#     '0001486608                                        '],
#    ['EMR',
#     'IND',
#     '12/05/2016',
#     '12:00:00',
#     'REGULAR',
#     '0002457869',
#     '0001486743                                        '],
#    ['EMR',
#     'IND',
#     '12/05/2016',
#     '16:00:00',
#     'REGULAR',
#     '0002458023',
#     '0001486820                                        '],
#    ['EMR',
#     'IND',
#     '12/05/2016',
#     '20:00:00',
#     'REGULAR',
#     '0002458317',
#     '0001486904                                        '],
#    ['EMR',
#     'IND',
#     '12/06/2016',
#     '00:00:00',
#     'REGULAR',
#     '0002458354',
#     '0001486951                                        '],
#    ['EMR',
#     'IND',
#     '12/06/2016',
#     '04:00:00',
#     'REGULAR',
#     '0002458363',
#     '0001486961                                        '],
#    ['EMR',
#     'IND',
#     '12/06/2016',
#     '08:00:00',
#     'REGULAR',
#     '0002458388',
#     '0001487036                                        '],
#    ['EMR',
#     'IND',
#     '12/06/2016',
#     '12:00:00',
#     'REGULAR',
#     '0002458459',
#     '0001487167                                        '],
#    ['EMR',
#     'IND',
#     '12/06/2016',
#     '16:00:00',
#     'REGULAR',
#     '0002458654',
#     '0001487237                                        '],
#    ['EMR',
#     'IND',
#     '12/06/2016',
#     '20:00:00',
#     'REGULAR',
#     '0002458908',
#     '0001487337                                        '],
#    ['EMR',
#     'IND',
#     '12/07/2016',
#     '00:00:00',
#     'REGULAR',
#     '0002458948',
#     '0001487369                                        '],
#    ['EMR',
#     'IND',
#     '12/07/2016',
#     '04:00:00',
#     'REGULAR',
#     '0002458957',
#     '0001487384                                        '],
#    ['EMR',
#     'IND',
#     '12/07/2016',
#     '08:00:00',
#     'REGULAR',
#     '0002458979',
#     '0001487467                                        '],
#    ['EMR',
#     'IND',
#     '12/07/2016',
#     '12:00:00',
#     'REGULAR',
#     '0002459072',
#     '0001487617                                        '],
#    ['EMR',
#     'IND',
#     '12/07/2016',
#     '16:00:00',
#     'REGULAR',
#     '0002459281',
#     '0001487694                                        '],
#    ['EMR',
#     'IND',
#     '12/07/2016',
#     '20:00:00',
#     'REGULAR',
#     '0002459561',
#     '0001487784                                        '],
#    ['EMR',
#     'IND',
#     '12/08/2016',
#     '00:00:00',
#     'REGULAR',
#     '0002459600',
#     '0001487825                                        '],
#    ['EMR',
#     'IND',
#     '12/08/2016',
#     '04:00:00',
#     'REGULAR',
#     '0002459606',
#     '0001487838                                        '],
#    ['EMR',
#     'IND',
#     '12/08/2016',
#     '08:00:00',
#     'REGULAR',
#     '0002459622',
#     '0001487901                                        '],
#    ['EMR',
#     'IND',
#     '12/08/2016',
#     '12:00:00',
#     'REGULAR',
#     '0002459679',
#     '0001488048                                        '],
#    ['EMR',
#     'IND',
#     '12/08/2016',
#     '16:00:00',
#     'REGULAR',
#     '0002459876',
#     '0001488122                                        '],
#    ['EMR',
#     'IND',
#     '12/08/2016',
#     '20:00:00',
#     'REGULAR',
#     '0002460190',
#     '0001488219                                        '],
#    ['EMR',
#     'IND',
#     '12/09/2016',
#     '00:00:00',
#     'REGULAR',
#     '0002460229',
#     '0001488275                                        '],
#    ['EMR',
#     'IND',
#     '12/09/2016',
#     '04:00:00',
#     'REGULAR',
#     '0002460232',
#     '0001488290                                        '],
#    ['EMR',
#     'IND',
#     '12/09/2016',
#     '08:00:00',
#     'REGULAR',
#     '0002460252',
#     '0001488349                                        '],
#    ['EMR',
#     'IND',
#     '12/09/2016',
#     '12:00:00',
#     'REGULAR',
#     '0002460303',
#     '0001488496                                        '],
#    ['EMR',
#     'IND',
#     '12/09/2016',
#     '16:00:00',
#     'REGULAR',
#     '0002460474',
#     '0001488565                                        '],
#    ['EMR',
#     'IND',
#     '12/09/2016',
#     '20:00:00',
#     'REGULAR',
#     '0002460717',
#     '0001488637                                        ']])]

# %% [markdown]
# ## Exercise 2
# - Let's turn this into a time series.
#
#  For each key (basically the control area, unit, device address and station of a specific turnstile), have a list again, but let the list be comprised of just the point in time and the cumulative count of entries.
#
# This basically means keeping only the date, time, and entries fields in each list. You can convert the date and time into datetime objects -- That is a python class that represents a point in time. You can combine the date and time fields into a string and use the [dateutil](https://dateutil.readthedocs.io/en/stable/) module to convert it into a datetime object.
#
# Your new dict should look something like
#
#     {    ('A002','R051','02-00-00','LEXINGTON AVE'):
#              [
#                 [datetime.datetime(2013, 3, 2, 3, 0), 3788],
#                 [datetime.datetime(2013, 3, 2, 7, 0), 2585],
#                 [datetime.datetime(2013, 3, 2, 12, 0), 10653],
#                 [datetime.datetime(2013, 3, 2, 17, 0), 11016],
#                 [datetime.datetime(2013, 3, 2, 23, 0), 10666],
#                 [datetime.datetime(2013, 3, 3, 3, 0), 10814],
#                 [datetime.datetime(2013, 3, 3, 7, 0), 10229],
#                 ...
#               ],
#      ....
#      }

# %%
from datetime import datetime
from dateutil.parser import parse

def convert_week_data_to_time_series(week_data_dict):
    turnstile_to_time_series = defaultdict(list)
    for i, (turnstile, row_data) in enumerate(week_data_dict.items()):
        if i % 100 == 0:
            print('Processing turnstile', turnstile)
        for lines, division, datestr, timestr, event, cum_entries, cum_exits in row_data:
            timestamp = parse('%sT%s' % (datestr, timestr))
            turnstile_to_time_series[turnstile].append([timestamp, int(cum_entries)])
            
    return turnstile_to_time_series

# %%
weekly_time_series = list(map(convert_week_data_to_time_series, weekly_data_dicts))
# Out:
# Processing turnstile ('A049', 'R088', '02-00-00', 'CORTLANDT ST')
# Processing turnstile ('H019', 'R294', '00-00-01', 'MORGAN AV')
# Processing turnstile ('N601A', 'R319', '01-05-00', 'LEXINGTON AV/63')
# Processing turnstile ('N045', 'R187', '01-00-02', '81 ST-MUSEUM')
# Processing turnstile ('R416', 'R245', '00-00-00', 'ST LAWRENCE AV')
# Processing turnstile ('R200A', 'R041', '01-05-01', 'BOWLING GREEN')
# Processing turnstile ('H023', 'R236', '00-06-02', 'DEKALB AV')
# Processing turnstile ('N043', 'R186', '00-00-00', '86 ST')
# Processing turnstile ('N119', 'R199', '00-00-01', 'KINGSTON-THROOP')
# Processing turnstile ('J020', 'R433', '00-00-01', 'ALABAMA AV')
# Processing turnstile ('N417', 'R269', '00-00-00', 'BEDFORD-NOSTRAN')
# Processing turnstile ('A015', 'R081', '00-00-03', '49 ST')
# Processing turnstile ('K026', 'R100', '00-05-00', 'METROPOLITAN AV')
# Processing turnstile ('N215', 'R237', '00-00-02', '182-183 STS')
# Processing turnstile ('N339', 'R114', '01-05-01', 'PARSONS BLVD')
# Processing turnstile ('R204', 'R043', '02-06-01', 'WALL ST')
# Processing turnstile ('N562', 'R426', '00-00-01', 'NEPTUNE AV')
# Processing turnstile ('N318', 'R298', '00-00-02', 'NORTHERN BLVD')
# Processing turnstile ('N507', 'R023', '00-03-01', '34 ST-HERALD SQ')
# Processing turnstile ('R524', 'R347', '00-00-02', '69 ST')
# Processing turnstile ('TRAM2', 'R469', '00-03-00', 'RIT-ROOSEVELT')
# Processing turnstile ('N600', 'R302', '00-06-02', '57 ST')
# Processing turnstile ('R511', 'R091', '00-00-00', '36 AV')
# Processing turnstile ('R550', 'R072', '00-03-08', '34 ST-HUDSON YD')
# Processing turnstile ('C017', 'R455', '00-00-02', '25 ST')
# Processing turnstile ('R513', 'R093', '00-03-02', '30 AV')
# Processing turnstile ('J009', 'R378', '00-00-02', 'MYRTLE AV')
# Processing turnstile ('H001', 'R175', '00-06-03', '8 AV')
# Processing turnstile ('R196', 'R306', '00-00-02', '238 ST')
# Processing turnstile ('R169', 'R168', '01-00-00', '96 ST')
# Processing turnstile ('R122', 'R290', '02-06-01', 'HOUSTON ST')
# Processing turnstile ('C003', 'R089', '00-03-01', 'JAY ST-METROTEC')
# Processing turnstile ('H026', 'R137', '00-03-03', 'MYRTLE-WYCKOFF')
# Processing turnstile ('PTH19', 'R549', '02-00-00', 'NEWARK C')
# Processing turnstile ('N549', 'R242', '00-00-01', '18 AV')
# Processing turnstile ('R406', 'R448', '00-00-01', "E 143/ST MARY'S")
# Processing turnstile ('R241A', 'R048', '00-00-00', 'GRD CNTRL-42 ST')
# Processing turnstile ('A054', 'R227', '01-00-01', 'RECTOR ST')
# Processing turnstile ('N092', 'R029', '03-00-00', 'CHAMBERS ST')
# Processing turnstile ('C019', 'R232', '00-00-03', '45 ST')
# Processing turnstile ('JFK03', 'R536', '00-00-03', 'JFK JAMAICA CT1')
# Processing turnstile ('J031', 'R006', '00-00-01', 'WOODHAVEN BLVD')
# Processing turnstile ('N044', 'R187', '00-00-01', '81 ST-MUSEUM')
# Processing turnstile ('R116', 'R030', '00-02-01', 'CHAMBERS ST')
# Processing turnstile ('A022', 'R022', '01-00-02', '34 ST-HERALD SQ')
# Processing turnstile ('R155', 'R116', '01-00-05', '50 ST')
# Processing turnstile ('A049', 'R088', '02-00-00', 'CORTLANDT ST')
# Processing turnstile ('H019', 'R294', '00-00-01', 'MORGAN AV')
# Processing turnstile ('N601A', 'R319', '01-05-00', 'LEXINGTON AV/63')
# Processing turnstile ('N045', 'R187', '01-00-02', '81 ST-MUSEUM')
# Processing turnstile ('R416', 'R245', '00-00-00', 'ST LAWRENCE AV')
# Processing turnstile ('R200A', 'R041', '01-05-01', 'BOWLING GREEN')
# Processing turnstile ('H023', 'R236', '00-06-02', 'DEKALB AV')
# Processing turnstile ('N043', 'R186', '00-00-00', '86 ST')
# Processing turnstile ('N119', 'R199', '00-00-01', 'KINGSTON-THROOP')
# Processing turnstile ('J020', 'R433', '00-00-01', 'ALABAMA AV')
# Processing turnstile ('N417', 'R269', '00-00-00', 'BEDFORD-NOSTRAN')
# Processing turnstile ('A015', 'R081', '00-00-03', '49 ST')
# Processing turnstile ('K026', 'R100', '00-05-00', 'METROPOLITAN AV')
# Processing turnstile ('N215', 'R237', '00-00-02', '182-183 STS')
# Processing turnstile ('N339', 'R114', '01-05-01', 'PARSONS BLVD')
# Processing turnstile ('R204', 'R043', '02-06-01', 'WALL ST')
# Processing turnstile ('N562', 'R426', '00-00-01', 'NEPTUNE AV')
# Processing turnstile ('N318', 'R298', '00-00-02', 'NORTHERN BLVD')
# Processing turnstile ('N507', 'R023', '00-03-01', '34 ST-HERALD SQ')
# Processing turnstile ('R524', 'R347', '00-00-02', '69 ST')
# Processing turnstile ('TRAM2', 'R469', '00-03-00', 'RIT-ROOSEVELT')
# Processing turnstile ('N600', 'R302', '00-06-02', '57 ST')
# Processing turnstile ('R511', 'R091', '00-00-00', '36 AV')
# Processing turnstile ('R550', 'R072', '00-03-08', '34 ST-HUDSON YD')
# Processing turnstile ('C017', 'R455', '00-00-02', '25 ST')
# Processing turnstile ('R513', 'R093', '00-03-02', '30 AV')
# Processing turnstile ('J009', 'R378', '00-00-02', 'MYRTLE AV')
# Processing turnstile ('H001', 'R175', '00-06-03', '8 AV')
# Processing turnstile ('R196', 'R306', '00-00-02', '238 ST')
# Processing turnstile ('R169', 'R168', '01-00-00', '96 ST')
# Processing turnstile ('R122', 'R290', '02-06-01', 'HOUSTON ST')
# Processing turnstile ('C003', 'R089', '00-03-01', 'JAY ST-METROTEC')
# Processing turnstile ('H026', 'R137', '00-03-03', 'MYRTLE-WYCKOFF')
# Processing turnstile ('PTH19', 'R549', '02-00-00', 'NEWARK C')
# Processing turnstile ('N549', 'R242', '00-00-01', '18 AV')
# Processing turnstile ('R406', 'R448', '00-00-01', "E 143/ST MARY'S")
# Processing turnstile ('R241A', 'R048', '00-00-00', 'GRD CNTRL-42 ST')
# Processing turnstile ('A054', 'R227', '01-00-01', 'RECTOR ST')
# Processing turnstile ('N092', 'R029', '03-00-00', 'CHAMBERS ST')
# Processing turnstile ('C019', 'R232', '00-00-03', '45 ST')
# Processing turnstile ('JFK03', 'R536', '00-00-03', 'JFK JAMAICA CT1')
# Processing turnstile ('J031', 'R006', '00-00-01', 'WOODHAVEN BLVD')
# Processing turnstile ('N044', 'R187', '00-00-01', '81 ST-MUSEUM')
# Processing turnstile ('R205A', 'R014', '04-02-03', 'FULTON ST')
# Processing turnstile ('A022', 'R022', '01-00-02', '34 ST-HERALD SQ')
# Processing turnstile ('R155', 'R116', '01-00-05', '50 ST')
# Processing turnstile ('A049', 'R088', '02-00-00', 'CORTLANDT ST')
# Processing turnstile ('H019', 'R294', '00-00-01', 'MORGAN AV')
# Processing turnstile ('N601A', 'R319', '01-05-00', 'LEXINGTON AV/63')
# Processing turnstile ('N045', 'R187', '01-00-02', '81 ST-MUSEUM')
# Processing turnstile ('R416', 'R245', '00-00-00', 'ST LAWRENCE AV')
# Processing turnstile ('R200A', 'R041', '01-05-01', 'BOWLING GREEN')
# Processing turnstile ('H023', 'R236', '00-06-02', 'DEKALB AV')
# Processing turnstile ('N043', 'R186', '00-00-00', '86 ST')
# Processing turnstile ('N119', 'R199', '00-00-01', 'KINGSTON-THROOP')
# Processing turnstile ('J020', 'R433', '00-00-01', 'ALABAMA AV')
# Processing turnstile ('N417', 'R269', '00-00-00', 'BEDFORD-NOSTRAN')
# Processing turnstile ('A015', 'R081', '00-00-03', '49 ST')
# Processing turnstile ('K026', 'R100', '00-05-00', 'METROPOLITAN AV')
# Processing turnstile ('N215', 'R237', '00-00-02', '182-183 STS')
# Processing turnstile ('N339', 'R114', '01-05-01', 'PARSONS BLVD')
# Processing turnstile ('R204', 'R043', '02-06-01', 'WALL ST')
# Processing turnstile ('N562', 'R426', '00-00-01', 'NEPTUNE AV')
# Processing turnstile ('N318', 'R298', '00-00-02', 'NORTHERN BLVD')
# Processing turnstile ('N507', 'R023', '00-03-01', '34 ST-HERALD SQ')
# Processing turnstile ('R524', 'R347', '00-00-02', '69 ST')
# Processing turnstile ('TRAM2', 'R469', '00-03-00', 'RIT-ROOSEVELT')
# Processing turnstile ('N600', 'R302', '00-06-02', '57 ST')
# Processing turnstile ('R511', 'R091', '00-00-00', '36 AV')
# Processing turnstile ('R550', 'R072', '00-03-08', '34 ST-HUDSON YD')
# Processing turnstile ('C017', 'R455', '00-00-02', '25 ST')
# Processing turnstile ('R513', 'R093', '00-03-02', '30 AV')
# Processing turnstile ('J009', 'R378', '00-00-02', 'MYRTLE AV')
# Processing turnstile ('H001', 'R175', '00-06-03', '8 AV')
# Processing turnstile ('R196', 'R306', '00-00-02', '238 ST')
# Processing turnstile ('R169', 'R168', '01-00-00', '96 ST')
# Processing turnstile ('R122', 'R290', '02-06-01', 'HOUSTON ST')
# Processing turnstile ('C003', 'R089', '00-03-01', 'JAY ST-METROTEC')
# Processing turnstile ('H026', 'R137', '00-03-03', 'MYRTLE-WYCKOFF')
# Processing turnstile ('PTH19', 'R549', '02-00-00', 'NEWARK C')
# Processing turnstile ('N549', 'R242', '00-00-01', '18 AV')
# Processing turnstile ('R406', 'R448', '00-00-01', "E 143/ST MARY'S")
# Processing turnstile ('R241A', 'R048', '00-00-00', 'GRD CNTRL-42 ST')
# Processing turnstile ('A054', 'R227', '01-00-01', 'RECTOR ST')
# Processing turnstile ('N092', 'R029', '03-00-00', 'CHAMBERS ST')
# Processing turnstile ('C019', 'R232', '00-00-03', '45 ST')
# Processing turnstile ('JFK03', 'R536', '00-00-03', 'JFK JAMAICA CT1')
# Processing turnstile ('J031', 'R006', '00-00-01', 'WOODHAVEN BLVD')
# Processing turnstile ('N044', 'R187', '00-00-01', '81 ST-MUSEUM')
# Processing turnstile ('R205A', 'R014', '04-02-03', 'FULTON ST')
# Processing turnstile ('A022', 'R022', '01-00-02', '34 ST-HERALD SQ')
# Processing turnstile ('R155', 'R116', '01-00-05', '50 ST')
# Processing turnstile ('A049', 'R088', '02-00-00', 'CORTLANDT ST')
# Processing turnstile ('H019', 'R294', '00-00-01', 'MORGAN AV')
# Processing turnstile ('N505', 'R022', '02-00-04', '34 ST-HERALD SQ')
# Processing turnstile ('A010', 'R080', '00-00-00', '57 ST-7 AV')
# Processing turnstile ('A047', 'R087', '00-00-02', 'CITY HALL')
# Processing turnstile ('R250', 'R179', '00-00-06', '86 ST')
# Processing turnstile ('R532', 'R328', '00-00-01', 'METS-WILLETS PT')
# Processing turnstile ('N070', 'R012', '04-05-00', '34 ST-PENN STA')
# Processing turnstile ('A030', 'R083', '01-03-00', '23 ST')
# Processing turnstile ('R625', 'R062', '01-00-01', 'CROWN HTS-UTICA')
# Processing turnstile ('N012', 'R035', '01-06-03', '168 ST')
# Processing turnstile ('E011', 'R371', '00-00-01', '79 ST')
# Processing turnstile ('N062A', 'R010', '00-00-05', '42 ST-PORT AUTH')
# Processing turnstile ('N337', 'R255', '00-03-00', 'BRIARWOOD')
# Processing turnstile ('N537', 'R258', '00-00-00', '4 AV-9 ST')
# Processing turnstile ('R154', 'R116', '00-00-00', '50 ST')
# Processing turnstile ('N138', 'R355', '01-04-00', '111 ST')
# Processing turnstile ('H006', 'R330', '01-00-01', '3 AV')
# Processing turnstile ('R628', 'R064', '00-00-04', 'SARATOGA AV')
# Processing turnstile ('J002', 'R460', '00-06-01', 'MARCY AV')
# Processing turnstile ('S101A', 'R070', '01-00-02', 'ST. GEORGE')
# Processing turnstile ('A083', 'R125', '00-00-03', 'BROAD ST')
# Processing turnstile ('N414', 'R316', '00-00-00', 'FLUSHING AV')
# Processing turnstile ('R238', 'R046', '00-05-01', 'GRD CNTRL-42 ST')
# Processing turnstile ('N500', 'R020', '00-03-00', '47-50 STS ROCK')
# Processing turnstile ('A029', 'R082', '00-00-01', '28 ST')
# Processing turnstile ('A083', 'R125', '00-00-02', 'BROAD ST')
# Processing turnstile ('R507', 'R134', '00-03-02', 'HUNTERS PT AV')
# Processing turnstile ('R639', 'R109', '00-05-02', 'CHURCH AV')
# Processing turnstile ('N520', 'R240', '00-00-06', 'GRAND ST')
# Processing turnstile ('N113', 'R297', '00-00-00', 'FRANKLIN AV')
# Processing turnstile ('N130', 'R383', '01-06-01', '80 ST')
# Processing turnstile ('A049', 'R088', '02-00-02', 'CORTLANDT ST')
# Processing turnstile ('R513', 'R093', '00-00-01', '30 AV')
# Processing turnstile ('R508', 'R346', '00-00-02', 'COURT SQ')
# Processing turnstile ('R133', 'R272', '00-00-03', '28 ST')
# Processing turnstile ('N303', 'R015', '00-00-02', '5 AV/53 ST')
# Processing turnstile ('R510', 'R090', '00-00-01', '39 AV')
# Processing turnstile ('C015', 'R454', '00-00-00', 'PROSPECT AV')
# Processing turnstile ('R330', 'R363', '00-00-00', 'BURKE AV')
# Processing turnstile ('R325', 'R388', '00-05-00', 'E 180 ST')
# Processing turnstile ('J012', 'R379', '00-00-01', 'KOSCIUSZKO ST')
# Processing turnstile ('N073', 'R013', '02-00-00', '34 ST-PENN STA')
# Processing turnstile ('R205A', 'R014', '04-02-03', 'FULTON ST')
# Processing turnstile ('A022', 'R022', '01-00-02', '34 ST-HERALD SQ')
# Processing turnstile ('R155', 'R116', '01-00-05', '50 ST')

# %%
sample_turnstile_to_time_series = list(weekly_time_series[0].items())[:2]
pprint(sample_turnstile_to_time_series)
# Out:
# [(('A049', 'R088', '02-00-00', 'CORTLANDT ST'),
#   [[datetime.datetime(2016, 12, 3, 0, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 4, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 8, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 12, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 16, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 20, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 0, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 4, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 8, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 12, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 16, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 20, 0), 237904],
#    [datetime.datetime(2016, 12, 5, 0, 0), 237904],
#    [datetime.datetime(2016, 12, 5, 4, 0), 237904],
#    [datetime.datetime(2016, 12, 5, 8, 0), 237919],
#    [datetime.datetime(2016, 12, 5, 12, 0), 238011],
#    [datetime.datetime(2016, 12, 5, 16, 0), 238205],
#    [datetime.datetime(2016, 12, 5, 20, 0), 238419],
#    [datetime.datetime(2016, 12, 6, 0, 0), 238472],
#    [datetime.datetime(2016, 12, 6, 4, 0), 238473],
#    [datetime.datetime(2016, 12, 6, 8, 0), 238487],
#    [datetime.datetime(2016, 12, 6, 12, 0), 238577],
#    [datetime.datetime(2016, 12, 6, 16, 0), 238720],
#    [datetime.datetime(2016, 12, 6, 20, 0), 238962],
#    [datetime.datetime(2016, 12, 7, 0, 0), 238988],
#    [datetime.datetime(2016, 12, 7, 4, 0), 238988],
#    [datetime.datetime(2016, 12, 7, 8, 0), 239001],
#    [datetime.datetime(2016, 12, 7, 12, 0), 239103],
#    [datetime.datetime(2016, 12, 7, 16, 0), 239252],
#    [datetime.datetime(2016, 12, 7, 20, 0), 239474],
#    [datetime.datetime(2016, 12, 8, 0, 0), 239523],
#    [datetime.datetime(2016, 12, 8, 4, 0), 239523],
#    [datetime.datetime(2016, 12, 8, 8, 0), 239538],
#    [datetime.datetime(2016, 12, 8, 12, 0), 239635],
#    [datetime.datetime(2016, 12, 8, 16, 0), 239806],
#    [datetime.datetime(2016, 12, 8, 20, 0), 240041],
#    [datetime.datetime(2016, 12, 9, 0, 0), 240091],
#    [datetime.datetime(2016, 12, 9, 4, 0), 240091],
#    [datetime.datetime(2016, 12, 9, 8, 0), 240102],
#    [datetime.datetime(2016, 12, 9, 12, 0), 240198],
#    [datetime.datetime(2016, 12, 9, 16, 0), 240484],
#    [datetime.datetime(2016, 12, 9, 20, 0), 240838]]),
#  (('N309A', 'R140', '00-00-02', 'QUEENS PLAZA'),
#   [[datetime.datetime(2016, 12, 3, 0, 0), 2457263],
#    [datetime.datetime(2016, 12, 3, 4, 0), 2457276],
#    [datetime.datetime(2016, 12, 3, 8, 0), 2457297],
#    [datetime.datetime(2016, 12, 3, 12, 0), 2457358],
#    [datetime.datetime(2016, 12, 3, 16, 0), 2457438],
#    [datetime.datetime(2016, 12, 3, 20, 0), 2457531],
#    [datetime.datetime(2016, 12, 4, 0, 0), 2457548],
#    [datetime.datetime(2016, 12, 4, 4, 0), 2457554],
#    [datetime.datetime(2016, 12, 4, 8, 0), 2457577],
#    [datetime.datetime(2016, 12, 4, 12, 0), 2457650],
#    [datetime.datetime(2016, 12, 4, 16, 0), 2457716],
#    [datetime.datetime(2016, 12, 4, 20, 0), 2457760],
#    [datetime.datetime(2016, 12, 5, 0, 0), 2457778],
#    [datetime.datetime(2016, 12, 5, 4, 0), 2457781],
#    [datetime.datetime(2016, 12, 5, 8, 0), 2457802],
#    [datetime.datetime(2016, 12, 5, 12, 0), 2457869],
#    [datetime.datetime(2016, 12, 5, 16, 0), 2458023],
#    [datetime.datetime(2016, 12, 5, 20, 0), 2458317],
#    [datetime.datetime(2016, 12, 6, 0, 0), 2458354],
#    [datetime.datetime(2016, 12, 6, 4, 0), 2458363],
#    [datetime.datetime(2016, 12, 6, 8, 0), 2458388],
#    [datetime.datetime(2016, 12, 6, 12, 0), 2458459],
#    [datetime.datetime(2016, 12, 6, 16, 0), 2458654],
#    [datetime.datetime(2016, 12, 6, 20, 0), 2458908],
#    [datetime.datetime(2016, 12, 7, 0, 0), 2458948],
#    [datetime.datetime(2016, 12, 7, 4, 0), 2458957],
#    [datetime.datetime(2016, 12, 7, 8, 0), 2458979],
#    [datetime.datetime(2016, 12, 7, 12, 0), 2459072],
#    [datetime.datetime(2016, 12, 7, 16, 0), 2459281],
#    [datetime.datetime(2016, 12, 7, 20, 0), 2459561],
#    [datetime.datetime(2016, 12, 8, 0, 0), 2459600],
#    [datetime.datetime(2016, 12, 8, 4, 0), 2459606],
#    [datetime.datetime(2016, 12, 8, 8, 0), 2459622],
#    [datetime.datetime(2016, 12, 8, 12, 0), 2459679],
#    [datetime.datetime(2016, 12, 8, 16, 0), 2459876],
#    [datetime.datetime(2016, 12, 8, 20, 0), 2460190],
#    [datetime.datetime(2016, 12, 9, 0, 0), 2460229],
#    [datetime.datetime(2016, 12, 9, 4, 0), 2460232],
#    [datetime.datetime(2016, 12, 9, 8, 0), 2460252],
#    [datetime.datetime(2016, 12, 9, 12, 0), 2460303],
#    [datetime.datetime(2016, 12, 9, 16, 0), 2460474],
#    [datetime.datetime(2016, 12, 9, 20, 0), 2460717]])]

# %%
herald_example = weekly_time_series[0][('N507', 'R023', '00-03-01', '34 ST-HERALD SQ')]
herald_example[:5]
# Out:
# [[datetime.datetime(2016, 12, 3, 3, 0), 2102326],
#  [datetime.datetime(2016, 12, 3, 7, 0), 2102328],
#  [datetime.datetime(2016, 12, 3, 11, 0), 2102354],
#  [datetime.datetime(2016, 12, 3, 15, 0), 2102456],
#  [datetime.datetime(2016, 12, 3, 19, 0), 2102623]]

# %%
station_dict = {}
station_series = []

previous_day = None
for day, entries in herald_example:
    time = day.time()
    
    if previous_day is None:
        period_entries = 0
    else:
        period_entries = entries - previous_day

    previous_day = entries
    
    if time not in station_dict:
        station_dict[time] = 0

    station_dict[time] += period_entries
    
    station_series.append((day, period_entries))

# %%
station_dict
# Out:
# {datetime.time(3, 0): 25,
#  datetime.time(7, 0): 119,
#  datetime.time(11, 0): 2546,
#  datetime.time(15, 0): 926,
#  datetime.time(19, 0): 2414,
#  datetime.time(23, 0): 1025}

# %%
sorted_stations = sorted(station_dict.items(), key=lambda x: x[0], reverse=False)

# %%
times, values = zip(*sorted_stations)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# times = list(station_dict.keys())
# values = list(station_dict.values())
plt.figure(figsize=(15,5))
plt.plot(range(len(times)), values)
plt.title('Time of Day Variability at Penn Station')
plt.xticks(range(len(times)), times)
plt.savefig('images/day_var.jpg')

# %%
# from itertools import groupby

# def count_within_normal_bounds(count):
#     if count is None:
#         return True
#     else:
#         return 10000 > count >= 0

# def convert_time_series_to_daily(high_res_time_series):
#     daily_time_series = []
    
#     def day_of_timestamp(time_series_entry):
#         timestamp, tot_entries = time_series_entry
#         return timestamp.date()
    
#     count_on_previous_day = None
#     for day, entries_on_this_day in groupby(high_res_time_series, key=day_of_timestamp):
#         cum_entry_count_on_day = max([count for time, count in entries_on_this_day])
        
#         if count_on_previous_day is None:
#             daily_entries = None
#         else:
#             daily_entries = cum_entry_count_on_day - count_on_previous_day
            
#         count_on_previous_day = cum_entry_count_on_day
        
#         if count_within_normal_bounds(daily_entries):
#             daily_time_series.append((day, daily_entries))
#         else:
#             print('WARNING. Abnormal entry count found on day %s: %s' % (day, daily_entries))
#             daily_time_series.append((day, None))
            
#     return daily_time_series

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

time_series = turnstile_to_daily_time_series[('H001', 'R175', '00-06-01', '8 AV')]
days, counts = zip(*time_series)
plt.figure(figsize=(15,5))
plt.plot(days, counts)

# %% [markdown]
# ## Exercise 3
# - These counts are cumulative every n hours. We want total daily entries.
#
# Now make it that we again have the same keys, but now we have a single value for a single day, which is not cumulative counts but the total number of passengers that entered through this turnstile on this day.

# %%
def combine_multiple_weeks_into_single_high_res_timeseries(weekly_time_series):
    combined_time_series = defaultdict(list)
    for turnstile_to_weeklong_time_series in weekly_time_series:
        for turnstile, weeklong_time_series in turnstile_to_weeklong_time_series.items():
            combined_time_series[turnstile] += weeklong_time_series
            
    return combined_time_series

# %%
turnstile_to_full_time_series = combine_multiple_weeks_into_single_high_res_timeseries(weekly_time_series)

# %%
type(turnstile_to_full_time_series)
# Out:
# collections.defaultdict

# %%
list(turnstile_to_full_time_series.items())[:2]
# Out:
# [(('A049', 'R088', '02-00-00', 'CORTLANDT ST'),
#   [[datetime.datetime(2016, 12, 3, 0, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 4, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 8, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 12, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 16, 0), 237904],
#    [datetime.datetime(2016, 12, 3, 20, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 0, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 4, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 8, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 12, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 16, 0), 237904],
#    [datetime.datetime(2016, 12, 4, 20, 0), 237904],
#    [datetime.datetime(2016, 12, 5, 0, 0), 237904],
#    [datetime.datetime(2016, 12, 5, 4, 0), 237904],
#    [datetime.datetime(2016, 12, 5, 8, 0), 237919],
#    [datetime.datetime(2016, 12, 5, 12, 0), 238011],
#    [datetime.datetime(2016, 12, 5, 16, 0), 238205],
#    [datetime.datetime(2016, 12, 5, 20, 0), 238419],
#    [datetime.datetime(2016, 12, 6, 0, 0), 238472],
#    [datetime.datetime(2016, 12, 6, 4, 0), 238473],
#    [datetime.datetime(2016, 12, 6, 8, 0), 238487],
#    [datetime.datetime(2016, 12, 6, 12, 0), 238577],
#    [datetime.datetime(2016, 12, 6, 16, 0), 238720],
#    [datetime.datetime(2016, 12, 6, 20, 0), 238962],
#    [datetime.datetime(2016, 12, 7, 0, 0), 238988],
#    [datetime.datetime(2016, 12, 7, 4, 0), 238988],
#    [datetime.datetime(2016, 12, 7, 8, 0), 239001],
#    [datetime.datetime(2016, 12, 7, 12, 0), 239103],
#    [datetime.datetime(2016, 12, 7, 16, 0), 239252],
#    [datetime.datetime(2016, 12, 7, 20, 0), 239474],
#    [datetime.datetime(2016, 12, 8, 0, 0), 239523],
#    [datetime.datetime(2016, 12, 8, 4, 0), 239523],
#    [datetime.datetime(2016, 12, 8, 8, 0), 239538],
#    [datetime.datetime(2016, 12, 8, 12, 0), 239635],
#    [datetime.datetime(2016, 12, 8, 16, 0), 239806],
#    [datetime.datetime(2016, 12, 8, 20, 0), 240041],
#    [datetime.datetime(2016, 12, 9, 0, 0), 240091],
#    [datetime.datetime(2016, 12, 9, 4, 0), 240091],
#    [datetime.datetime(2016, 12, 9, 8, 0), 240102],
#    [datetime.datetime(2016, 12, 9, 12, 0), 240198],
#    [datetime.datetime(2016, 12, 9, 16, 0), 240484],
#    [datetime.datetime(2016, 12, 9, 20, 0), 240838],
#    [datetime.datetime(2016, 12, 10, 0, 0), 240890],
#    [datetime.datetime(2016, 12, 10, 4, 0), 240890],
#    [datetime.datetime(2016, 12, 10, 8, 0), 240891],
#    [datetime.datetime(2016, 12, 10, 12, 0), 240891],
#    [datetime.datetime(2016, 12, 10, 16, 0), 240891],
#    [datetime.datetime(2016, 12, 10, 20, 0), 240891],
#    [datetime.datetime(2016, 12, 11, 0, 0), 240891],
#    [datetime.datetime(2016, 12, 11, 4, 0), 240891],
#    [datetime.datetime(2016, 12, 11, 8, 0), 240891],
#    [datetime.datetime(2016, 12, 11, 12, 0), 240891],
#    [datetime.datetime(2016, 12, 11, 16, 0), 240891],
#    [datetime.datetime(2016, 12, 11, 20, 0), 240891],
#    [datetime.datetime(2016, 12, 12, 0, 0), 240891],
#    [datetime.datetime(2016, 12, 12, 4, 0), 240891],
#    [datetime.datetime(2016, 12, 12, 8, 0), 240904],
#    [datetime.datetime(2016, 12, 12, 12, 0), 240987],
#    [datetime.datetime(2016, 12, 12, 16, 0), 241132],
#    [datetime.datetime(2016, 12, 12, 20, 0), 241355],
#    [datetime.datetime(2016, 12, 13, 0, 0), 241398],
#    [datetime.datetime(2016, 12, 13, 4, 0), 241398],
#    [datetime.datetime(2016, 12, 13, 8, 0), 241409],
#    [datetime.datetime(2016, 12, 13, 12, 0), 241499],
#    [datetime.datetime(2016, 12, 13, 16, 0), 241709],
#    [datetime.datetime(2016, 12, 13, 20, 0), 241931],
#    [datetime.datetime(2016, 12, 14, 0, 0), 241963],
#    [datetime.datetime(2016, 12, 14, 4, 0), 241963],
#    [datetime.datetime(2016, 12, 14, 8, 0), 241972],
#    [datetime.datetime(2016, 12, 14, 12, 0), 242075],
#    [datetime.datetime(2016, 12, 14, 16, 0), 242239],
#    [datetime.datetime(2016, 12, 14, 20, 0), 242482],
#    [datetime.datetime(2016, 12, 15, 0, 0), 242533],
#    [datetime.datetime(2016, 12, 15, 4, 0), 242533],
#    [datetime.datetime(2016, 12, 15, 8, 0), 242543],
#    [datetime.datetime(2016, 12, 15, 12, 0), 242646],
#    [datetime.datetime(2016, 12, 15, 16, 0), 242837],
#    [datetime.datetime(2016, 12, 15, 20, 0), 243048],
#    [datetime.datetime(2016, 12, 16, 0, 0), 243082],
#    [datetime.datetime(2016, 12, 16, 4, 0), 243082],
#    [datetime.datetime(2016, 12, 16, 8, 0), 243092],
#    [datetime.datetime(2016, 12, 16, 12, 0), 243197],
#    [datetime.datetime(2016, 12, 16, 16, 0), 243416],
#    [datetime.datetime(2016, 12, 16, 20, 0), 243697],
#    [datetime.datetime(2016, 12, 17, 0, 0), 243740],
#    [datetime.datetime(2016, 12, 17, 4, 0), 243740],
#    [datetime.datetime(2016, 12, 17, 8, 0), 243740],
#    [datetime.datetime(2016, 12, 17, 12, 0), 243740],
#    [datetime.datetime(2016, 12, 17, 16, 0), 243740],
#    [datetime.datetime(2016, 12, 17, 20, 0), 243740],
#    [datetime.datetime(2016, 12, 18, 0, 0), 243740],
#    [datetime.datetime(2016, 12, 18, 4, 0), 243740],
#    [datetime.datetime(2016, 12, 18, 8, 0), 243740],
#    [datetime.datetime(2016, 12, 18, 12, 0), 243740],
#    [datetime.datetime(2016, 12, 18, 16, 0), 243740],
#    [datetime.datetime(2016, 12, 18, 20, 0), 243740],
#    [datetime.datetime(2016, 12, 19, 0, 0), 243740],
#    [datetime.datetime(2016, 12, 19, 4, 0), 243740],
#    [datetime.datetime(2016, 12, 19, 8, 0), 243740],
#    [datetime.datetime(2016, 12, 19, 12, 0), 243740],
#    [datetime.datetime(2016, 12, 19, 16, 0), 243740],
#    [datetime.datetime(2016, 12, 19, 20, 0), 243779],
#    [datetime.datetime(2016, 12, 20, 0, 0), 243787],
#    [datetime.datetime(2016, 12, 20, 4, 0), 243787],
#    [datetime.datetime(2016, 12, 20, 8, 0), 243791],
#    [datetime.datetime(2016, 12, 20, 12, 0), 243801],
#    [datetime.datetime(2016, 12, 20, 16, 0), 243835],
#    [datetime.datetime(2016, 12, 20, 20, 0), 243916],
#    [datetime.datetime(2016, 12, 21, 0, 0), 243983],
#    [datetime.datetime(2016, 12, 21, 4, 0), 243984],
#    [datetime.datetime(2016, 12, 21, 8, 0), 243996],
#    [datetime.datetime(2016, 12, 21, 12, 0), 244101],
#    [datetime.datetime(2016, 12, 21, 16, 0), 244339],
#    [datetime.datetime(2016, 12, 21, 20, 0), 244578],
#    [datetime.datetime(2016, 12, 22, 0, 0), 244619],
#    [datetime.datetime(2016, 12, 22, 4, 0), 244621],
#    [datetime.datetime(2016, 12, 22, 8, 0), 244627],
#    [datetime.datetime(2016, 12, 22, 12, 0), 244729],
#    [datetime.datetime(2016, 12, 22, 16, 0), 244931],
#    [datetime.datetime(2016, 12, 22, 20, 0), 245229],
#    [datetime.datetime(2016, 12, 23, 0, 0), 245272],
#    [datetime.datetime(2016, 12, 23, 4, 0), 245272],
#    [datetime.datetime(2016, 12, 23, 8, 0), 245278],
#    [datetime.datetime(2016, 12, 23, 12, 0), 245367],
#    [datetime.datetime(2016, 12, 23, 16, 0), 245576],
#    [datetime.datetime(2016, 12, 23, 20, 0), 245832],
#    [datetime.datetime(2016, 12, 24, 0, 0), 245873],
#    [datetime.datetime(2016, 12, 24, 4, 0), 245875],
#    [datetime.datetime(2016, 12, 24, 8, 0), 245880],
#    [datetime.datetime(2016, 12, 24, 12, 0), 245928],
#    [datetime.datetime(2016, 12, 24, 16, 0), 246111],
#    [datetime.datetime(2016, 12, 24, 20, 0), 246324],
#    [datetime.datetime(2016, 12, 25, 0, 0), 246359],
#    [datetime.datetime(2016, 12, 25, 4, 0), 246362],
#    [datetime.datetime(2016, 12, 25, 8, 0), 246366],
#    [datetime.datetime(2016, 12, 25, 12, 0), 246397],
#    [datetime.datetime(2016, 12, 25, 16, 0), 246557],
#    [datetime.datetime(2016, 12, 25, 20, 0), 246746],
#    [datetime.datetime(2016, 12, 26, 0, 0), 246783],
#    [datetime.datetime(2016, 12, 26, 4, 0), 246783],
#    [datetime.datetime(2016, 12, 26, 8, 0), 246788],
#    [datetime.datetime(2016, 12, 26, 12, 0), 246866],
#    [datetime.datetime(2016, 12, 26, 16, 0), 247078],
#    [datetime.datetime(2016, 12, 26, 20, 0), 247281],
#    [datetime.datetime(2016, 12, 27, 0, 0), 247330],
#    [datetime.datetime(2016, 12, 27, 4, 0), 247331],
#    [datetime.datetime(2016, 12, 27, 8, 0), 247334],
#    [datetime.datetime(2016, 12, 27, 12, 0), 247426],
#    [datetime.datetime(2016, 12, 27, 16, 0), 247693],
#    [datetime.datetime(2016, 12, 27, 20, 0), 248062],
#    [datetime.datetime(2016, 12, 28, 0, 0), 248167],
#    [datetime.datetime(2016, 12, 28, 4, 0), 248168],
#    [datetime.datetime(2016, 12, 28, 7, 6, 29), 248172],
#    [datetime.datetime(2016, 12, 28, 8, 0), 248176],
#    [datetime.datetime(2016, 12, 28, 12, 0), 248330],
#    [datetime.datetime(2016, 12, 28, 16, 0), 248622],
#    [datetime.datetime(2016, 12, 28, 20, 0), 248980],
#    [datetime.datetime(2016, 12, 29, 0, 0), 249062],
#    [datetime.datetime(2016, 12, 29, 4, 0), 249065],
#    [datetime.datetime(2016, 12, 29, 8, 0), 249073],
#    [datetime.datetime(2016, 12, 29, 8, 6, 4), 249075],
#    [datetime.datetime(2016, 12, 29, 12, 0), 249161],
#    [datetime.datetime(2016, 12, 29, 16, 0), 249399],
#    [datetime.datetime(2016, 12, 29, 20, 0), 249620],
#    [datetime.datetime(2016, 12, 30, 0, 0), 249697],
#    [datetime.datetime(2016, 12, 30, 4, 0), 249700],
#    [datetime.datetime(2016, 12, 30, 8, 0), 249707],
#    [datetime.datetime(2016, 12, 30, 12, 0), 249800],
#    [datetime.datetime(2016, 12, 30, 16, 0), 250164],
#    [datetime.datetime(2016, 12, 30, 20, 0), 250538]]),
#  (('N002A', 'R173', '00-05-01', 'INWOOD-207 ST'),
#   [[datetime.datetime(2016, 12, 3, 0, 0), 0],
#    [datetime.datetime(2016, 12, 3, 4, 0), 0],
#    [datetime.datetime(2016, 12, 3, 8, 0), 0],
#    [datetime.datetime(2016, 12, 3, 12, 0), 0],
#    [datetime.datetime(2016, 12, 3, 16, 0), 0],
#    [datetime.datetime(2016, 12, 3, 20, 0), 0],
#    [datetime.datetime(2016, 12, 4, 0, 0), 0],
#    [datetime.datetime(2016, 12, 4, 4, 0), 0],
#    [datetime.datetime(2016, 12, 4, 8, 0), 0],
#    [datetime.datetime(2016, 12, 4, 12, 0), 0],
#    [datetime.datetime(2016, 12, 4, 16, 0), 0],
#    [datetime.datetime(2016, 12, 4, 20, 0), 0],
#    [datetime.datetime(2016, 12, 5, 0, 0), 0],
#    [datetime.datetime(2016, 12, 5, 4, 0), 0],
#    [datetime.datetime(2016, 12, 5, 8, 0), 0],
#    [datetime.datetime(2016, 12, 5, 12, 0), 0],
#    [datetime.datetime(2016, 12, 5, 16, 0), 0],
#    [datetime.datetime(2016, 12, 5, 20, 0), 0],
#    [datetime.datetime(2016, 12, 6, 0, 0), 0],
#    [datetime.datetime(2016, 12, 6, 4, 0), 0],
#    [datetime.datetime(2016, 12, 6, 8, 0), 0],
#    [datetime.datetime(2016, 12, 6, 12, 0), 0],
#    [datetime.datetime(2016, 12, 6, 16, 0), 0],
#    [datetime.datetime(2016, 12, 6, 20, 0), 0],
#    [datetime.datetime(2016, 12, 7, 0, 0), 0],
#    [datetime.datetime(2016, 12, 7, 4, 0), 0],
#    [datetime.datetime(2016, 12, 7, 8, 0), 0],
#    [datetime.datetime(2016, 12, 7, 12, 0), 0],
#    [datetime.datetime(2016, 12, 7, 16, 0), 0],
#    [datetime.datetime(2016, 12, 7, 20, 0), 0],
#    [datetime.datetime(2016, 12, 8, 0, 0), 0],
#    [datetime.datetime(2016, 12, 8, 4, 0), 0],
#    [datetime.datetime(2016, 12, 8, 8, 0), 0],
#    [datetime.datetime(2016, 12, 8, 12, 0), 0],
#    [datetime.datetime(2016, 12, 8, 16, 0), 0],
#    [datetime.datetime(2016, 12, 8, 20, 0), 0],
#    [datetime.datetime(2016, 12, 9, 0, 0), 0],
#    [datetime.datetime(2016, 12, 9, 4, 0), 0],
#    [datetime.datetime(2016, 12, 9, 8, 0), 0],
#    [datetime.datetime(2016, 12, 9, 12, 0), 0],
#    [datetime.datetime(2016, 12, 9, 16, 0), 0],
#    [datetime.datetime(2016, 12, 10, 0, 0), 0],
#    [datetime.datetime(2016, 12, 10, 4, 0), 0],
#    [datetime.datetime(2016, 12, 10, 8, 0), 0],
#    [datetime.datetime(2016, 12, 10, 12, 0), 0],
#    [datetime.datetime(2016, 12, 10, 16, 0), 0],
#    [datetime.datetime(2016, 12, 10, 20, 0), 0],
#    [datetime.datetime(2016, 12, 11, 0, 0), 0],
#    [datetime.datetime(2016, 12, 11, 4, 0), 0],
#    [datetime.datetime(2016, 12, 11, 8, 0), 0],
#    [datetime.datetime(2016, 12, 11, 12, 0), 0],
#    [datetime.datetime(2016, 12, 11, 16, 0), 0],
#    [datetime.datetime(2016, 12, 11, 20, 0), 0],
#    [datetime.datetime(2016, 12, 12, 0, 0), 0],
#    [datetime.datetime(2016, 12, 12, 4, 0), 0],
#    [datetime.datetime(2016, 12, 12, 8, 0), 0],
#    [datetime.datetime(2016, 12, 12, 12, 0), 0],
#    [datetime.datetime(2016, 12, 12, 16, 0), 0],
#    [datetime.datetime(2016, 12, 12, 20, 0), 0],
#    [datetime.datetime(2016, 12, 13, 0, 0), 0],
#    [datetime.datetime(2016, 12, 13, 4, 0), 0],
#    [datetime.datetime(2016, 12, 13, 8, 0), 0],
#    [datetime.datetime(2016, 12, 13, 12, 0), 0],
#    [datetime.datetime(2016, 12, 13, 16, 0), 0],
#    [datetime.datetime(2016, 12, 13, 20, 0), 0],
#    [datetime.datetime(2016, 12, 14, 0, 0), 0],
#    [datetime.datetime(2016, 12, 14, 4, 0), 0],
#    [datetime.datetime(2016, 12, 14, 8, 0), 0],
#    [datetime.datetime(2016, 12, 14, 12, 0), 0],
#    [datetime.datetime(2016, 12, 14, 16, 0), 0],
#    [datetime.datetime(2016, 12, 14, 20, 0), 0],
#    [datetime.datetime(2016, 12, 15, 0, 0), 0],
#    [datetime.datetime(2016, 12, 15, 4, 0), 0],
#    [datetime.datetime(2016, 12, 15, 8, 0), 0],
#    [datetime.datetime(2016, 12, 15, 12, 0), 0],
#    [datetime.datetime(2016, 12, 15, 16, 0), 0],
#    [datetime.datetime(2016, 12, 15, 20, 0), 0],
#    [datetime.datetime(2016, 12, 16, 0, 0), 0],
#    [datetime.datetime(2016, 12, 16, 4, 0), 0],
#    [datetime.datetime(2016, 12, 16, 8, 0), 0],
#    [datetime.datetime(2016, 12, 16, 12, 0), 0],
#    [datetime.datetime(2016, 12, 16, 16, 0), 0],
#    [datetime.datetime(2016, 12, 16, 20, 0), 0],
#    [datetime.datetime(2016, 12, 17, 0, 0), 0],
#    [datetime.datetime(2016, 12, 17, 4, 0), 0],
#    [datetime.datetime(2016, 12, 17, 8, 0), 0],
#    [datetime.datetime(2016, 12, 17, 12, 0), 0],
#    [datetime.datetime(2016, 12, 17, 16, 0), 0],
#    [datetime.datetime(2016, 12, 17, 20, 0), 0],
#    [datetime.datetime(2016, 12, 18, 0, 0), 0],
#    [datetime.datetime(2016, 12, 18, 4, 0), 0],
#    [datetime.datetime(2016, 12, 18, 8, 0), 0],
#    [datetime.datetime(2016, 12, 18, 12, 0), 0],
#    [datetime.datetime(2016, 12, 18, 16, 0), 0],
#    [datetime.datetime(2016, 12, 18, 20, 0), 0],
#    [datetime.datetime(2016, 12, 19, 0, 0), 0],
#    [datetime.datetime(2016, 12, 19, 4, 0), 0],
#    [datetime.datetime(2016, 12, 19, 8, 0), 0],
#    [datetime.datetime(2016, 12, 19, 12, 0), 0],
#    [datetime.datetime(2016, 12, 19, 16, 0), 0],
#    [datetime.datetime(2016, 12, 19, 20, 0), 0],
#    [datetime.datetime(2016, 12, 20, 0, 0), 0],
#    [datetime.datetime(2016, 12, 20, 4, 0), 0],
#    [datetime.datetime(2016, 12, 20, 8, 0), 0],
#    [datetime.datetime(2016, 12, 20, 12, 0), 0],
#    [datetime.datetime(2016, 12, 20, 16, 0), 0],
#    [datetime.datetime(2016, 12, 20, 20, 0), 0],
#    [datetime.datetime(2016, 12, 21, 0, 0), 0],
#    [datetime.datetime(2016, 12, 21, 4, 0), 0],
#    [datetime.datetime(2016, 12, 21, 8, 0), 0],
#    [datetime.datetime(2016, 12, 21, 12, 0), 0],
#    [datetime.datetime(2016, 12, 21, 16, 0), 0],
#    [datetime.datetime(2016, 12, 21, 20, 0), 0],
#    [datetime.datetime(2016, 12, 22, 0, 0), 0],
#    [datetime.datetime(2016, 12, 22, 4, 0), 0],
#    [datetime.datetime(2016, 12, 22, 8, 0), 0],
#    [datetime.datetime(2016, 12, 22, 12, 0), 0],
#    [datetime.datetime(2016, 12, 22, 16, 0), 0],
#    [datetime.datetime(2016, 12, 22, 20, 0), 0],
#    [datetime.datetime(2016, 12, 23, 0, 0), 0],
#    [datetime.datetime(2016, 12, 23, 4, 0), 0],
#    [datetime.datetime(2016, 12, 23, 8, 0), 0],
#    [datetime.datetime(2016, 12, 23, 12, 0), 0],
#    [datetime.datetime(2016, 12, 23, 16, 0), 0],
#    [datetime.datetime(2016, 12, 23, 20, 0), 0],
#    [datetime.datetime(2016, 12, 24, 0, 0), 0],
#    [datetime.datetime(2016, 12, 24, 4, 0), 0],
#    [datetime.datetime(2016, 12, 24, 8, 0), 0],
#    [datetime.datetime(2016, 12, 24, 12, 0), 0],
#    [datetime.datetime(2016, 12, 24, 16, 0), 0],
#    [datetime.datetime(2016, 12, 24, 20, 0), 0],
#    [datetime.datetime(2016, 12, 25, 0, 0), 0],
#    [datetime.datetime(2016, 12, 25, 4, 0), 0],
#    [datetime.datetime(2016, 12, 25, 8, 0), 0],
#    [datetime.datetime(2016, 12, 25, 12, 0), 0],
#    [datetime.datetime(2016, 12, 25, 16, 0), 0],
#    [datetime.datetime(2016, 12, 25, 20, 0), 0],
#    [datetime.datetime(2016, 12, 26, 0, 0), 0],
#    [datetime.datetime(2016, 12, 26, 4, 0), 0],
#    [datetime.datetime(2016, 12, 26, 8, 0), 0],
#    [datetime.datetime(2016, 12, 26, 12, 0), 0],
#    [datetime.datetime(2016, 12, 26, 16, 0), 0],
#    [datetime.datetime(2016, 12, 26, 20, 0), 0],
#    [datetime.datetime(2016, 12, 27, 0, 0), 0],
#    [datetime.datetime(2016, 12, 27, 4, 0), 0],
#    [datetime.datetime(2016, 12, 27, 8, 0), 0],
#    [datetime.datetime(2016, 12, 27, 12, 0), 0],
#    [datetime.datetime(2016, 12, 27, 16, 0), 0],
#    [datetime.datetime(2016, 12, 27, 20, 0), 0],
#    [datetime.datetime(2016, 12, 28, 0, 0), 0],
#    [datetime.datetime(2016, 12, 28, 4, 0), 0],
#    [datetime.datetime(2016, 12, 28, 8, 0), 0],
#    [datetime.datetime(2016, 12, 28, 12, 0), 0],
#    [datetime.datetime(2016, 12, 28, 16, 0), 0],
#    [datetime.datetime(2016, 12, 28, 20, 0), 0],
#    [datetime.datetime(2016, 12, 29, 0, 0), 0],
#    [datetime.datetime(2016, 12, 29, 4, 0), 0],
#    [datetime.datetime(2016, 12, 29, 8, 0), 0],
#    [datetime.datetime(2016, 12, 29, 12, 0), 0],
#    [datetime.datetime(2016, 12, 29, 16, 0), 0],
#    [datetime.datetime(2016, 12, 29, 20, 0), 0],
#    [datetime.datetime(2016, 12, 30, 0, 0), 0],
#    [datetime.datetime(2016, 12, 30, 4, 0), 0],
#    [datetime.datetime(2016, 12, 30, 8, 0), 0],
#    [datetime.datetime(2016, 12, 30, 12, 0), 0],
#    [datetime.datetime(2016, 12, 30, 16, 0), 0],
#    [datetime.datetime(2016, 12, 30, 20, 0), 0]])]

# %%
def convert_turnstile_to_high_res_time_series_to_daily(turnstile_to_time_series):
    turnstile_to_daily_time_series = {}
    for i, (turnstile, time_series) in enumerate(turnstile_to_time_series.items()):
        print('Processing turnstile', turnstile)
        turnstile_to_daily_time_series[turnstile] = convert_time_series_to_daily(time_series)
    
    return turnstile_to_daily_time_series

# %%
from itertools import groupby

def count_within_normal_bounds(count):
    if count is None:
        return True
    else:
        return 10000 > count >= 0

def convert_time_series_to_daily(high_res_time_series):
    daily_time_series = []
    
    def day_of_timestamp(time_series_entry):
        timestamp, tot_entries = time_series_entry
        return timestamp.date()
    
    count_on_previous_day = None
    for day, entries_on_this_day in groupby(high_res_time_series, key=day_of_timestamp):
        cum_entry_count_on_day = max([count for time, count in entries_on_this_day])
        
        if count_on_previous_day is None:
            daily_entries = None
        else:
            daily_entries = cum_entry_count_on_day - count_on_previous_day
            
        count_on_previous_day = cum_entry_count_on_day
        
        if count_within_normal_bounds(daily_entries):
            daily_time_series.append((day, daily_entries))
        else:
            print('WARNING. Abnormal entry count found on day %s: %s' % (day, daily_entries))
            daily_time_series.append((day, None))
            
    return daily_time_series

# %%
turnstile_to_daily_time_series = convert_turnstile_to_high_res_time_series_to_daily(turnstile_to_full_time_series)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-382b1e082f07> in <module>()
# ----> 1 turnstile_to_daily_time_series = convert_turnstile_to_high_res_time_series_to_daily(turnstile_to_full_time_series)
#
# NameError: name 'turnstile_to_full_time_series' is not defined

# %%
pprint(turnstile_to_daily_time_series[('H001', 'R175', '00-06-01', '8 AV')])
# Out:
# [(datetime.date(2016, 12, 3), None),
#  (datetime.date(2016, 12, 4), 1586),
#  (datetime.date(2016, 12, 5), 1715),
#  (datetime.date(2016, 12, 6), 1882),
#  (datetime.date(2016, 12, 7), 1862),
#  (datetime.date(2016, 12, 8), 2111),
#  (datetime.date(2016, 12, 9), 2184),
#  (datetime.date(2016, 12, 10), 1874),
#  (datetime.date(2016, 12, 11), 1455),
#  (datetime.date(2016, 12, 12), 1858),
#  (datetime.date(2016, 12, 13), 1907),
#  (datetime.date(2016, 12, 14), 2103),
#  (datetime.date(2016, 12, 15), 1773),
#  (datetime.date(2016, 12, 16), 1802),
#  (datetime.date(2016, 12, 17), 1575),
#  (datetime.date(2016, 12, 18), 1387),
#  (datetime.date(2016, 12, 19), 1535),
#  (datetime.date(2016, 12, 20), 1639),
#  (datetime.date(2016, 12, 21), 1904),
#  (datetime.date(2016, 12, 22), 1851),
#  (datetime.date(2016, 12, 23), 1602),
#  (datetime.date(2016, 12, 24), 964),
#  (datetime.date(2016, 12, 25), 584),
#  (datetime.date(2016, 12, 26), 787),
#  (datetime.date(2016, 12, 27), 1349),
#  (datetime.date(2016, 12, 28), 1565),
#  (datetime.date(2016, 12, 29), 1483),
#  (datetime.date(2016, 12, 30), 1586)]

# %% [markdown]
# ## Exercise 4
# - We will plot the daily time series for a turnstile.
#
# In ipython notebook, add this to the beginning of your next cell:
#
#     %matplotlib inline
#
# This will make your matplotlib graphs integrate nicely with the notebook.
# To plot the time series, import matplotlib with
#
#     import matplotlib.pyplot as plt
#
# Take the list of [(date1, count1), (date2, count2), ...], for the turnstile and turn it into two lists:
# dates and counts. This should plot it:
#
#     plt.figure(figsize=(10,3))
#     plt.plot(dates,counts)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

time_series = turnstile_to_daily_time_series[('H001', 'R175', '00-06-01', '8 AV')]
days, counts = zip(*time_series)
plt.figure(figsize=(15,5))
plt.plot(days, counts)

# %% [markdown]
# ## Exercise 5
# - So far we've been operating on a single turnstile level, let's combine turnstiles in the same ControlArea/Unit/Station combo. There are some ControlArea/Unit/Station groups that have a single turnstile, but most have multiple turnstilea-- same value for the C/A, UNIT and STATION columns, different values for the SCP column.
#
# We want to combine the numbers together -- for each ControlArea/UNIT/STATION combo, for each day, add the counts from each turnstile belonging to that combo.

# %%
from collections import Counter

def booth_of_a_time_series_item(item):
    turnstile, time_series = item
    control_area, unit, device_id, station = turnstile
    return (control_area, unit, station)

def reduce_turnstile_time_series_to_booths(turnstile_to_daily_time_series):
    turnstile_time_series_items = sorted(turnstile_to_daily_time_series.items())
    booth_to_time_series = {}
    
    for booth, item_list_of_booth in groupby(turnstile_time_series_items, key=booth_of_a_time_series_item):
        daily_counter = Counter()
        for turnstile, time_series in item_list_of_booth:
            for day, count in time_series:
                if count is not None:
                    daily_counter[day] += count
                    
        booth_to_time_series[booth] = sorted(daily_counter.items())
        
    return booth_to_time_series
    
    
booth_to_daily_time_series = reduce_turnstile_time_series_to_booths(turnstile_to_daily_time_series)

# %%
pprint(booth_to_daily_time_series[('H001', 'R175', '8 AV')])

# %% [markdown]
# ## Exercise 6
# - Similarly, combine everything in each station, and come up with a time series of `[(date1, count1),(date2,count2),...]` type of time series for each STATION, by adding up all the turnstiles in a station.

# %%
def station_of_a_time_series_item(item):
    booth, time_series = item
    control_area, unit, station = booth
    return station

def reduce_booth_time_series_to_stations(booth_to_daily_time_series):
    booth_time_series_items = sorted(booth_to_daily_time_series.items())
    station_to_time_series = {}
    
    for station, item_list_of_station in groupby(booth_time_series_items, key=station_of_a_time_series_item):
        daily_counter = Counter()
        for turnstile, time_series in item_list_of_station:
            for day, count in time_series:
                daily_counter[day] += count
        station_to_time_series[station] = sorted(daily_counter.items())
        
    return station_to_time_series
    
    
station_to_daily_time_series = reduce_booth_time_series_to_stations(booth_to_daily_time_series)

# %%
pprint(station_to_daily_time_series['8 AV'])

# %% [markdown]
# ## Exercise 7
# - Plot the time series for a station

# %%
def plot_station_time_series(station_name, station_to_daily_time_series):
    time_series = station_to_daily_time_series[station_name]
    days, counts = zip(*time_series)
    plt.figure(figsize=(15,5))
    plt.plot(days, counts)
    plt.xlabel('Date')
    plt.ylabel('Number of Turnstile Entries')
    plt.title('Daily Entries for Station %s' % station_name)
    
    
plot_station_time_series('8 AV', station_to_daily_time_series)

# %% [markdown]
# ## Exercise 8
# - Make one list of counts for **one** week for one station. Monday's count, Tuesday's count, etc. so it's a list of 7 counts.
# Make the same list for another week, and another week, and another week.
# `plt.plot(week_count_list)` for every `week_count_list` you created this way. You should get a rainbow plot of weekly commute numbers on top of each other.

# %%
import numpy as np

def separate_weeks(time_series):
    time_series_for_each_week = []
    week = []
    
    for i, (day, count) in enumerate(time_series):
        week.append((day, count))
        if i % 7 == 6:
            time_series_for_each_week.append(week)
            week = []
            
    time_series_for_each_week.append(week)
    return time_series_for_each_week
    
def rainbow_plot_for_station(station_name, station_to_daily_time_series):
    time_series = station_to_daily_time_series[station_name]
    time_series_for_each_week = separate_weeks(time_series)

    plt.figure(figsize=(15,5))
    for week in time_series_for_each_week:
        days, counts = zip(*week)
        days = range(len(counts))
        plt.plot(days, counts)
        
    plt.xlabel('Day of the Week')
    plt.ylabel('Number of Turnstile Entries')
    plt.title('Ridership per Day for Station %s' % station_name)
    plt.xticks(np.arange(7), ['St', 'Sn', 'Mo', 'Tu', 'We', 'Th', 'Fr'])
    
rainbow_plot_for_station('8 AV', station_to_daily_time_series)

# %% [markdown]
# ## Exercise 9
# - Over multiple weeks, sum total ridership for each station and sort them, so you can find out the stations with the highest traffic during the time you investigate

# %%
def station_time_series_item_to_station_total_traffic(item):
    station, time_series = item
    total_traffic = sum([count for day, count in time_series])
    return total_traffic, station

traffic_report = list(map(station_time_series_item_to_station_total_traffic, station_to_daily_time_series.items()))

for total_traffic, station in sorted(traffic_report, reverse=True)[:30]:
    print('%-18s %s' % (station, total_traffic))

# %% [markdown]
# ## Exercise 10
# - Make a single list of these total ridership values and plot it with `plt.hist(total_ridership_counts)` to get an idea about the distribution of total ridership among different stations.
# This should show you that most stations have a small traffic, and the histogram bins for large traffic volumes have small bars.
#
# *Additional Hint*:
# If you want to see which stations take the meat of the traffic, you can sort the total ridership counts and make a `plt.bar` graph. For this, you want to have two lists: the indices of each bar, and the values. The indices can just be `0,1,2,3,...`, so you can do
#
#     indices = range(len(total_ridership_values))
#     plt.bar(indices, total_ridership_values)

# %%
total_ridership_counts = [ridership for ridership, station in traffic_report]
plt.figure(figsize=(15,5))
hist = plt.hist(total_ridership_counts, bins=20)

# %%
import math

log_counts = []

for count in total_ridership_counts:
    try:
        log_result = math.log10(count)
    except:
        pass
    
    log_counts.append(log_result)
    
plt.figure(figsize=(15,5))
n, bins, patches = hist = plt.hist(log_counts, bins=15)

def log_count_to_label(log_count):
    if log_count <= 6:
        return '%.0f Thousand' % 10**(log_count-3)
    else:
        return '%.1f Million' % 10**(log_count-6)


tick_labels = map(log_count_to_label, bins)
ticks = plt.xticks(bins, tick_labels, rotation=70)
plt.xlabel('Total Ridership Count (log 10)')
plt.ylabel('Number of Stations with this Total Count')
plt.title('Distribution of ridership among NYC Subway Stations')

# %%
top_stations = sorted(traffic_report, reverse=True)[:30]
counts, stations = zip(*top_stations)
indices = range(len(counts))
plt.figure(figsize=(15,5))
plt.bar(indices, counts)
ticks = plt.xticks(indices, stations, rotation=70)

# %%
top_stations = sorted(traffic_report, reverse=True)[:15]
counts, stations = zip(*top_stations)
indices = range(len(counts))
plt.figure(figsize=(15,5))
plt.bar(indices, counts)
ticks = plt.xticks(indices, stations, rotation=70)
plt.title('Top 15 Busiest Subway Stations in December 2016')
plt.ylabel('Cumulative Turnstile Entries')
plt.xlabel('Station')
plt.savefig('images/top15.jpg')

# %%
rainbow_plot_for_station('34 ST-PENN STA', station_to_daily_time_series)
plt.savefig('images/weekly_var.jpg')
